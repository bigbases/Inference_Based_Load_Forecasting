# %%
# from google.colab import drive
import sys

sys.path.append('/content/drive/MyDrive/Colab Notebooks/Capstone')

import pandas as pd
import numpy as np

import json
from datetime import datetime
import torch.nn as nn

from utils import *
from mtad_gat import MTAD_GAT

import os
import time
import numpy as np
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter

# %%
class CustomDataset(Dataset):
    def __init__(self, data, target):
        self.data = data
        self.target = target

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index], self.target[index]

class Trainer:
    """Trainer class for MTAD-GAT model.

    :param model: MTAD-GAT model
    :param optimizer: Optimizer used to minimize the loss function
    :param window_size: Length of the input sequence
    :param n_features: Number of input features
    :param target_dims: dimension of input features to forecast and reconstruct
    :param n_epochs: Number of iterations/epochs
    :param batch_size: Number of windows in a single batch
    :param init_lr: Initial learning rate of the module
    :param forecast_criterion: Loss to be used for forecasting.
    :param recon_criterion: Loss to be used for reconstruction.
    :param boolean use_cuda: To be run on GPU or not
    :param dload: Download directory where models are to be dumped
    :param log_dir: Directory where SummaryWriter logs are written to
    :param print_every: At what epoch interval to print losses
    :param log_tensorboard: Whether to log loss++ to tensorboard
    :param args_summary: Summary of args that will also be written to tensorboard if log_tensorboard
    """

    def __init__(
        self,
        model,
        optimizer,
        window_size,
        n_features,
        target_dims=None,
        n_epochs=200,
        batch_size=32,
        init_lr=0.001,
        forecast_criterion=nn.MSELoss(),
        recon_criterion=nn.MSELoss(),
        use_cuda=True,
        dload="",
        log_dir="output/",
        print_every=1,
        log_tensorboard=True,
        args_summary="",
    ):

        self.model = model
        self.optimizer = optimizer
        self.window_size = window_size
        self.n_features = n_features
        self.target_dims = target_dims
        self.n_epochs = n_epochs
        self.batch_size = batch_size
        self.init_lr = init_lr
        self.forecast_criterion = forecast_criterion
        self.recon_criterion = recon_criterion
        self.device = "cuda" if use_cuda and torch.cuda.is_available() else "cpu"
        self.dload = dload
        self.log_dir = log_dir
        self.print_every = print_every
        self.log_tensorboard = log_tensorboard

        self.losses = {
            "train_total": [],
            "train_forecast": [],
            "train_recon": [],
            "val_total": [],
            "val_forecast": [],
            "val_recon": [],
        }
        self.epoch_times = []

        if self.device == "cuda":
            self.model.cuda()

        if self.log_tensorboard:
            self.writer = SummaryWriter(f"{log_dir}")
            self.writer.add_text("args_summary", args_summary)

    def fit(self, train_loader, val_loader=None):
        """Train model for self.n_epochs.
        Train and validation (if validation loader given) losses stored in self.losses

        :param train_loader: train loader of input data
        :param val_loader: validation loader of input data
        """

        init_train_loss = self.evaluate(train_loader)
        print(f"Init total train loss: {init_train_loss[2]:5f}")

        if val_loader is not None:
            init_val_loss = self.evaluate(val_loader)
            print(f"Init total val loss: {init_val_loss[2]:.5f}")

        print(f"Training model for {self.n_epochs} epochs..")
        train_start = time.time()
        for epoch in range(self.n_epochs):
            epoch_start = time.time()
            self.model.train()
            forecast_b_losses = []
            recon_b_losses = []

            for x, y in train_loader:
                x = x.to(self.device).float() # 32,56,1080?????
                y = y.to(self.device).float()
                self.optimizer.zero_grad()

                preds, recons, _, _ = self.model(x)
                # print('pp')
                if self.target_dims is not None:
                    x = x[:, :, self.target_dims]
                    y = y[:, :, self.target_dims].squeeze(-1)

                if preds.ndim == 3:
                    preds = preds.squeeze(1)
                if y.ndim == 3:
                    y = y.squeeze(1)

                forecast_loss = torch.sqrt(self.forecast_criterion(y, preds))
                recon_loss = torch.sqrt(self.recon_criterion(x, recons))
                loss = forecast_loss + recon_loss

                loss.backward()
                self.optimizer.step()

                forecast_b_losses.append(forecast_loss.item())
                recon_b_losses.append(recon_loss.item())

            forecast_b_losses = np.array(forecast_b_losses)
            recon_b_losses = np.array(recon_b_losses)

            forecast_epoch_loss = np.sqrt((forecast_b_losses ** 2).mean())
            recon_epoch_loss = np.sqrt((recon_b_losses ** 2).mean())

            total_epoch_loss = forecast_epoch_loss + recon_epoch_loss

            self.losses["train_forecast"].append(forecast_epoch_loss)
            self.losses["train_recon"].append(recon_epoch_loss)
            self.losses["train_total"].append(total_epoch_loss)

            # Evaluate on validation set
            forecast_val_loss, recon_val_loss, total_val_loss = "NA", "NA", "NA"
            if val_loader is not None:
                forecast_val_loss, recon_val_loss, total_val_loss = self.evaluate(val_loader)
                self.losses["val_forecast"].append(forecast_val_loss)
                self.losses["val_recon"].append(recon_val_loss)
                self.losses["val_total"].append(total_val_loss)

                if total_val_loss <= self.losses["val_total"][-1]:
                    self.save(f"model.pt")

            if self.log_tensorboard:
                self.write_loss(epoch)

            epoch_time = time.time() - epoch_start
            self.epoch_times.append(epoch_time)

            if epoch % self.print_every == 0:
                s = (
                    f"[Epoch {epoch + 1}] "
                    f"forecast_loss = {forecast_epoch_loss:.5f}, "
                    f"recon_loss = {recon_epoch_loss:.5f}, "
                    f"total_loss = {total_epoch_loss:.5f}"
                )

                if val_loader is not None:
                    s += (
                        f" ---- val_forecast_loss = {forecast_val_loss:.5f}, "
                        f"val_recon_loss = {recon_val_loss:.5f}, "
                        f"val_total_loss = {total_val_loss:.5f}"
                    )

                s += f" [{epoch_time:.1f}s]"
                print(s)

        if val_loader is None:
            self.save(f"model.pt")

        train_time = int(time.time() - train_start)
        if self.log_tensorboard:
            self.writer.add_text("total_train_time", str(train_time))
        print(f"-- Training done in {train_time}s.")

    def evaluate(self, data_loader):
        """Evaluate model

        :param data_loader: data loader of input data
        :return forecasting loss, reconstruction loss, total loss
        """

        self.model.eval()

        forecast_losses = []
        recon_losses = []

        with torch.no_grad():
            for x, y in data_loader:
                x = x.to(self.device)
                y = y.to(self.device)
                x = x.to(self.device).float() # 32,56,1080?????
                y = y.to(self.device).float()

                preds, recons, _, _ = self.model(x)

                if self.target_dims is not None:
                    x = x[:, :, self.target_dims]
                    y = y[:, :, self.target_dims].squeeze(-1)

                if preds.ndim == 3:
                    preds = preds.squeeze(1)
                if y.ndim == 3:
                    y = y.squeeze(1)
                # print('aa')
#                 print(y.shape, preds.shape)
#                 print(y.shape) # 32,1
#                 print(preds.shape) # 32,1
#                 print(recons.shape) # 32,28,3
                forecast_loss = torch.sqrt(self.forecast_criterion(y, preds))
                recon_loss = torch.sqrt(self.recon_criterion(x, recons))

                forecast_losses.append(forecast_loss.item())
                recon_losses.append(recon_loss.item())

        forecast_losses = np.array(forecast_losses)
        recon_losses = np.array(recon_losses)

        forecast_loss = np.sqrt((forecast_losses ** 2).mean())
        recon_loss = np.sqrt((recon_losses ** 2).mean())

        total_loss = forecast_loss + recon_loss

        return forecast_loss, recon_loss, total_loss

    def save(self, file_name):
        """
        Pickles the model parameters to be retrieved later
        :param file_name: the filename to be saved as,`dload` serves as the download directory
        """
        PATH = self.dload + "/" + file_name
        if os.path.exists(self.dload):
            pass
        else:
            os.mkdir(self.dload)
        torch.save(self.model.state_dict(), PATH)

    def load(self, PATH):
        """
        Loads the model's parameters from the path mentioned
        :param PATH: Should contain pickle file
        """
        self.model.load_state_dict(torch.load(PATH, map_location=self.device))

    def write_loss(self, epoch):
        for key, value in self.losses.items():
            if len(value) != 0:
                self.writer.add_scalar(key, value[-1], epoch)

# %%
# dataset load
# 전기
elec_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/elec_clustering_train.csv', index_col=0)
elec_train.index = pd.to_datetime(elec_train.index)
elec_train = elec_train.resample(rule='12H').sum()
elec_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/elec_clustering_test.csv', index_col=0)
elec_test.index = pd.to_datetime(elec_test.index)
elec_test = elec_test.resample(rule='12H').sum()
elec_total = pd.concat([elec_train,elec_test],axis=1)
# 수도
water_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/water_clustering_train.csv', index_col=0)
water_train.index = pd.to_datetime(water_train.index)
water_train = water_train.resample(rule='12H').sum()
water_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/water_clustering_test.csv', index_col=0)
water_test.index = pd.to_datetime(water_test.index)
water_test = water_test.resample(rule='12H').sum()
water_total = pd.concat([water_train,water_test],axis=1)
#가스
gas_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/gas_clustering_train.csv', index_col=0)
gas_train.index = pd.to_datetime(gas_train.index)
gas_train = gas_train.resample(rule='12H').sum()
gas_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/gas_clustering_test.csv', index_col=0)
gas_test.index = pd.to_datetime(gas_test.index)
gas_test = gas_test.resample(rule='12H').sum()
gas_total = pd.concat([gas_train,gas_test],axis=1)
#온수
hotwater_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/hotwater_clustering_train.csv', index_col=0)
hotwater_train.index = pd.to_datetime(hotwater_train.index)
hotwater_train = hotwater_train.resample(rule='12H').sum()
hotwater_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/hotwater_clustering_test.csv', index_col=0)
hotwater_test.index = pd.to_datetime(hotwater_test.index)
hotwater_test = hotwater_test.resample(rule='12H').sum()
hotwater_total = pd.concat([hotwater_train,hotwater_test],axis=1)

# %%
region_A = elec_train.columns
region_B = elec_test.columns

train_index = 504*2
test_index = (504+28)*2
cluster_index = (504+28+28)*2

energy_A = elec_total.reset_index(drop=True)
energy_B = gas_total.reset_index(drop=True)
energy_C = water_total.reset_index(drop=True)
energy_target = hotwater_total.reset_index(drop=True)

train_A = energy_A[:train_index]
train_B = energy_B[:train_index]
train_C = energy_C[:train_index]
train_target = energy_target[:train_index+1]
test_A = energy_A[train_index:test_index+1]
test_B = energy_B[train_index:test_index+1]
test_C = energy_C[train_index:test_index+1]
test_target = energy_target[train_index:test_index+1]
cluster_A = energy_A[test_index:cluster_index+1]
cluster_B = energy_B[test_index:cluster_index+1]
cluster_C = energy_C[test_index:cluster_index+1]
cluster_target = energy_target[test_index:cluster_index+1]

scaler_A = MinMaxScaler()
scaler_B = MinMaxScaler()
scaler_C = MinMaxScaler()
scaler_target = MinMaxScaler()
train_A = pd.DataFrame(scaler_A.fit_transform(train_A))
train_B = pd.DataFrame(scaler_B.fit_transform(train_B))
train_C = pd.DataFrame(scaler_C.fit_transform(train_C))
train_target = pd.DataFrame(scaler_target.fit_transform(train_target))
test_A = pd.DataFrame(scaler_A.transform(test_A))
test_B = pd.DataFrame(scaler_B.transform(test_B))
test_C = pd.DataFrame(scaler_C.transform(test_C))
test_target = pd.DataFrame(scaler_target.transform(test_target))
cluster_A = pd.DataFrame(scaler_A.transform(cluster_A))
cluster_B = pd.DataFrame(scaler_B.transform(cluster_B))
cluster_C = pd.DataFrame(scaler_C.transform(cluster_C))
cluster_target = pd.DataFrame(scaler_target.transform(cluster_target))

# 2-5 표현 생성
idx = 14
repr1_A = energy_A[train_index+idx:test_index+1+idx]
repr1_B = energy_B[train_index+idx:test_index+1+idx]
repr1_C = energy_C[train_index+idx:test_index+1+idx]
repr1_target = energy_target[train_index+idx:test_index+1+idx]

repr1_A = pd.DataFrame(scaler_A.transform(repr1_A))
repr1_B = pd.DataFrame(scaler_B.transform(repr1_B))
repr1_C = pd.DataFrame(scaler_C.transform(repr1_C))
repr1_target = pd.DataFrame(scaler_target.transform(repr1_target))

X_repr1 = []
y_repr1 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr1_A.iloc[period,user],repr1_B.iloc[period,user],repr1_C.iloc[period,user]])
        y_window.append(repr1_A.iloc[period+1,user])
        X_repr1.append(X_window)
        y_repr1.append(y_window)

# 3-6 표현 생성
repr2_A = energy_A[train_index+idx*2:test_index+1+idx*2]
repr2_B = energy_B[train_index+idx*2:test_index+1+idx*2]
repr2_C = energy_C[train_index+idx*2:test_index+1+idx*2]
repr2_target = energy_target[train_index+idx*2:test_index+1+idx*2]

repr2_A = pd.DataFrame(scaler_A.transform(repr2_A))
repr2_B = pd.DataFrame(scaler_B.transform(repr2_B))
repr2_C = pd.DataFrame(scaler_C.transform(repr2_C))
repr2_target = pd.DataFrame(scaler_target.transform(repr2_target))

X_repr2 = []
y_repr2 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr2_A.iloc[period,user],repr2_B.iloc[period,user],repr2_C.iloc[period,user]])
        y_window.append(repr2_A.iloc[period+1,user])
        X_repr2.append(X_window)
        y_repr2.append(y_window)

# 4-7 표현 생성
repr3_A = energy_A[train_index+idx*3:test_index+1+idx*3]
repr3_B = energy_B[train_index+idx*3:test_index+1+idx*3]
repr3_C = energy_C[train_index+idx*3:test_index+1+idx*3]
repr3_target = energy_target[train_index+idx*3:test_index+1+idx*3]

repr3_A = pd.DataFrame(scaler_A.transform(repr3_A))
repr3_B = pd.DataFrame(scaler_B.transform(repr3_B))
repr3_C = pd.DataFrame(scaler_C.transform(repr3_C))
repr3_target = pd.DataFrame(scaler_target.transform(repr3_target))

X_repr3 = []
y_repr3 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr3_A.iloc[period,user],repr3_B.iloc[period,user],repr3_C.iloc[period,user]])
        y_window.append(repr3_A.iloc[period+1,user])
        X_repr3.append(X_window)
        y_repr3.append(y_window)

X_train = []
y_train = []
for user in range(elec_total.shape[1]):
    for index in range(0,elec_total.shape[0]//(28*2)-3):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([train_A.iloc[period,user],train_B.iloc[period,user],train_C.iloc[period,user]])
        y_window.append(train_A.iloc[period+1,user])
        X_train.append(X_window)
        y_train.append(y_window)

X_test = []
y_test = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([test_A.iloc[period,user],test_B.iloc[period,user],test_C.iloc[period,user]])
        y_window.append(test_A.iloc[period+1,user])
        X_test.append(X_window)
        y_test.append(y_window)

X_cluster = []
y_cluster = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([cluster_A.iloc[period,user],cluster_B.iloc[period,user],cluster_C.iloc[period,user]])
        y_window.append(cluster_A.iloc[period+1,user])
        X_cluster.append(X_window)
        y_cluster.append(y_window)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
X_cluster = np.array(X_cluster)
y_cluster = np.array(y_cluster)

X_repr1 = np.array(X_repr1)
y_repr1 = np.array(y_repr1)
X_repr2 = np.array(X_repr2)
y_repr2 = np.array(y_repr2)
X_repr3 = np.array(X_repr3)
y_repr3 = np.array(y_repr3)

train_ds = CustomDataset(X_train, y_train)
valid_ds = CustomDataset(X_test, y_test) # 이게 test set

train_loader, val_loader, test_loader = create_data_loaders(
        train_ds, batch_size=32, val_split=0.2, shuffle=False, test_dataset=valid_ds
    )

id = datetime.now().strftime("%d%m%Y_%H%M%S")
# Out:
# train_size: 14688
# validation_size: 3672
# test_size: 1080

# %%
window_size = 28*2
n_epochs = 500 #30
batch_size = 32
init_lr = 1e-3
print_every = 1
log_tensorboard = True

n_features=X_train.shape[2]
window_size=window_size
out_dim=X_train.shape[2]
kernel_size=3
use_gatv2=True
feat_gat_embed_dim=None
time_gat_embed_dim=None
gru_n_layers=1
gru_hid_dim=256
forecast_n_layers=2
forecast_hid_dim=512
recon_n_layers=2
recon_hid_dim=128
dropout=0.2
alpha=0.2

num = 0
model = MTAD_GAT(
    n_features=n_features,
    window_size=window_size,
    out_dim=out_dim,
    kernel_size=kernel_size,
    use_gatv2=True,
    feat_gat_embed_dim=None,
    time_gat_embed_dim=None,
    gru_n_layers=gru_n_layers,
    gru_hid_dim=gru_hid_dim,
    forecast_n_layers=forecast_n_layers,
    forecast_hid_dim=forecast_hid_dim,
    recon_n_layers=recon_n_layers,
    recon_hid_dim=recon_hid_dim,
    dropout=0.2,
    alpha=0.2
)

optimizer = torch.optim.Adam(model.parameters(), lr=init_lr)
forecast_criterion = nn.MSELoss()
recon_criterion = nn.MSELoss()

trainer = Trainer(
    model=model,
    optimizer=optimizer,
    window_size=window_size,
    n_features=n_features,
    n_epochs=n_epochs,
    batch_size=batch_size,
    init_lr=init_lr,
    forecast_criterion=forecast_criterion,
    recon_criterion=recon_criterion,
    use_cuda=True,
    print_every=1,
    log_dir="/logs",
    dload="/result"
)

trainer.fit(train_loader, val_loader)

# hidden representations생성
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
forecast_criterion=nn.MSELoss()
recon_criterion=nn.MSELoss()

repr1_ds = CustomDataset(X_repr1, y_repr1) # 이게 repr1 set
repr1set_loader = torch.utils.data.DataLoader(repr1_ds, batch_size=32)

repr2_ds = CustomDataset(X_repr2, y_repr2) # 이게 repr2 set
repr2set_loader = torch.utils.data.DataLoader(repr2_ds, batch_size=32)

repr3_ds = CustomDataset(X_repr3, y_repr3) # 이게 repr3 set
repr3set_loader = torch.utils.data.DataLoader(repr3_ds, batch_size=32)

for idx, loader in enumerate([repr1set_loader, repr2set_loader, repr3set_loader]):

    hidden_test = []
    h_r_test = []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device).float()
            y = y.to(device).float()

            preds, recons, h, h_r = model(x)

            if preds.ndim == 3:
                preds = preds.squeeze(1)
            if y.ndim == 3:
                y = y.squeeze(1)

            hidden_test.append(h.cpu())
            h_r_test.append(h_r.cpu())

    hidden_test_ = [np.array(i.cpu().squeeze()) for j in hidden_test for i in j]
    hidden_test_ = np.array(hidden_test_)
    hidden_test_ = pd.DataFrame(hidden_test_, index = elec_total.columns)
    h_r_test_ = [np.array(i.cpu().squeeze()) for j in h_r_test for i in j]
    h_r_test_ = np.array(h_r_test_).reshape(1080,-1)
    h_r_test_ = pd.DataFrame(h_r_test_, index = elec_total.columns)
    hidden_test_.to_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/result/graph_hw/arr_hidden_{}_{}.csv'.format(idx, num))
    h_r_test_.to_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/result/graph_hw/h_r_{}_{}.csv'.format(idx, num))
# Out:
# Init total train loss: 0.433765
# Init total val loss: 0.43483
# Training model for 500 epochs..
# [Epoch 1] forecast_loss = 0.10156, recon_loss = 0.13690, total_loss = 0.23846 ---- val_forecast_loss = 0.08764, val_recon_loss = 0.13457, val_total_loss = 0.22220 [4.5s]
# [Epoch 2] forecast_loss = 0.08785, recon_loss = 0.12571, total_loss = 0.21356 ---- val_forecast_loss = 0.08477, val_recon_loss = 0.12343, val_total_loss = 0.20820 [4.6s]
# [Epoch 3] forecast_loss = 0.08336, recon_loss = 0.11869, total_loss = 0.20205 ---- val_forecast_loss = 0.08767, val_recon_loss = 0.11827, val_total_loss = 0.20594 [4.6s]
# [Epoch 4] forecast_loss = 0.08069, recon_loss = 0.11499, total_loss = 0.19567 ---- val_forecast_loss = 0.08651, val_recon_loss = 0.11678, val_total_loss = 0.20329 [4.6s]
# [Epoch 5] forecast_loss = 0.07927, recon_loss = 0.11275, total_loss = 0.19202 ---- val_forecast_loss = 0.07864, val_recon_loss = 0.11382, val_total_loss = 0.19246 [4.6s]
# [Epoch 6] forecast_loss = 0.07857, recon_loss = 0.11095, total_loss = 0.18952 ---- val_forecast_loss = 0.07816, val_recon_loss = 0.11352, val_total_loss = 0.19168 [4.6s]
# [Epoch 7] forecast_loss = 0.07841, recon_loss = 0.11011, total_loss = 0.18852 ---- val_forecast_loss = 0.08157, val_recon_loss = 0.11206, val_total_loss = 0.19363 [4.6s]
# [Epoch 8] forecast_loss = 0.07808, recon_loss = 0.10892, total_loss = 0.18701 ---- val_forecast_loss = 0.07967, val_recon_loss = 0.11019, val_total_loss = 0.18985 [4.6s]
# [Epoch 9] forecast_loss = 0.07748, recon_loss = 0.10797, total_loss = 0.18545 ---- val_forecast_loss = 0.07893, val_recon_loss = 0.10932, val_total_loss = 0.18825 [4.5s]
# [Epoch 10] forecast_loss = 0.07738, recon_loss = 0.10726, total_loss = 0.18464 ---- val_forecast_loss = 0.07959, val_recon_loss = 0.10853, val_total_loss = 0.18811 [4.5s]
# [Epoch 11] forecast_loss = 0.07778, recon_loss = 0.10671, total_loss = 0.18449 ---- val_forecast_loss = 0.07934, val_recon_loss = 0.10971, val_total_loss = 0.18905 [4.6s]
# [Epoch 12] forecast_loss = 0.07666, recon_loss = 0.10610, total_loss = 0.18275 ---- val_forecast_loss = 0.08058, val_recon_loss = 0.11014, val_total_loss = 0.19073 [4.5s]
# [Epoch 13] forecast_loss = 0.07652, recon_loss = 0.10514, total_loss = 0.18166 ---- val_forecast_loss = 0.07996, val_recon_loss = 0.10680, val_total_loss = 0.18676 [4.6s]
# [Epoch 14] forecast_loss = 0.07625, recon_loss = 0.10389, total_loss = 0.18014 ---- val_forecast_loss = 0.07887, val_recon_loss = 0.10432, val_total_loss = 0.18319 [4.6s]
# [Epoch 15] forecast_loss = 0.07591, recon_loss = 0.10086, total_loss = 0.17676 ---- val_forecast_loss = 0.07942, val_recon_loss = 0.10136, val_total_loss = 0.18078 [4.5s]
# [Epoch 16] forecast_loss = 0.07531, recon_loss = 0.09853, total_loss = 0.17383 ---- val_forecast_loss = 0.07842, val_recon_loss = 0.09931, val_total_loss = 0.17773 [4.6s]
# [Epoch 17] forecast_loss = 0.07464, recon_loss = 0.09759, total_loss = 0.17223 ---- val_forecast_loss = 0.07911, val_recon_loss = 0.09932, val_total_loss = 0.17843 [4.6s]
# [Epoch 18] forecast_loss = 0.07434, recon_loss = 0.09686, total_loss = 0.17119 ---- val_forecast_loss = 0.07869, val_recon_loss = 0.09710, val_total_loss = 0.17579 [4.6s]
# [Epoch 19] forecast_loss = 0.07375, recon_loss = 0.09578, total_loss = 0.16953 ---- val_forecast_loss = 0.07893, val_recon_loss = 0.09865, val_total_loss = 0.17758 [4.6s]
# [Epoch 20] forecast_loss = 0.07265, recon_loss = 0.09480, total_loss = 0.16745 ---- val_forecast_loss = 0.07830, val_recon_loss = 0.09545, val_total_loss = 0.17376 [4.6s]
# [Epoch 21] forecast_loss = 0.07239, recon_loss = 0.09454, total_loss = 0.16692 ---- val_forecast_loss = 0.07834, val_recon_loss = 0.09522, val_total_loss = 0.17355 [4.6s]
# [Epoch 22] forecast_loss = 0.07233, recon_loss = 0.09372, total_loss = 0.16606 ---- val_forecast_loss = 0.07794, val_recon_loss = 0.09439, val_total_loss = 0.17234 [4.6s]
# [Epoch 23] forecast_loss = 0.07078, recon_loss = 0.09274, total_loss = 0.16352 ---- val_forecast_loss = 0.07844, val_recon_loss = 0.09427, val_total_loss = 0.17271 [4.6s]
# [Epoch 24] forecast_loss = 0.07028, recon_loss = 0.09262, total_loss = 0.16289 ---- val_forecast_loss = 0.07874, val_recon_loss = 0.09401, val_total_loss = 0.17275 [4.6s]
# [Epoch 25] forecast_loss = 0.07010, recon_loss = 0.09180, total_loss = 0.16190 ---- val_forecast_loss = 0.07930, val_recon_loss = 0.09338, val_total_loss = 0.17268 [4.5s]
# [Epoch 26] forecast_loss = 0.06951, recon_loss = 0.09142, total_loss = 0.16093 ---- val_forecast_loss = 0.08225, val_recon_loss = 0.09164, val_total_loss = 0.17389 [4.6s]
# [Epoch 27] forecast_loss = 0.06888, recon_loss = 0.09107, total_loss = 0.15995 ---- val_forecast_loss = 0.07927, val_recon_loss = 0.09174, val_total_loss = 0.17102 [4.6s]
# [Epoch 28] forecast_loss = 0.06823, recon_loss = 0.09041, total_loss = 0.15864 ---- val_forecast_loss = 0.08083, val_recon_loss = 0.09091, val_total_loss = 0.17174 [4.5s]
# [Epoch 29] forecast_loss = 0.06742, recon_loss = 0.08977, total_loss = 0.15719 ---- val_forecast_loss = 0.07966, val_recon_loss = 0.09193, val_total_loss = 0.17159 [4.6s]
# [Epoch 30] forecast_loss = 0.06657, recon_loss = 0.08912, total_loss = 0.15569 ---- val_forecast_loss = 0.08122, val_recon_loss = 0.09003, val_total_loss = 0.17125 [4.6s]
# [Epoch 31] forecast_loss = 0.06554, recon_loss = 0.08882, total_loss = 0.15436 ---- val_forecast_loss = 0.08171, val_recon_loss = 0.09022, val_total_loss = 0.17194 [4.5s]
# [Epoch 32] forecast_loss = 0.06544, recon_loss = 0.08831, total_loss = 0.15375 ---- val_forecast_loss = 0.08168, val_recon_loss = 0.08974, val_total_loss = 0.17143 [4.6s]
# [Epoch 33] forecast_loss = 0.06447, recon_loss = 0.08756, total_loss = 0.15202 ---- val_forecast_loss = 0.08062, val_recon_loss = 0.09060, val_total_loss = 0.17122 [4.6s]
# [Epoch 34] forecast_loss = 0.06459, recon_loss = 0.08750, total_loss = 0.15209 ---- val_forecast_loss = 0.08582, val_recon_loss = 0.08836, val_total_loss = 0.17418 [4.6s]
# [Epoch 35] forecast_loss = 0.06303, recon_loss = 0.08645, total_loss = 0.14948 ---- val_forecast_loss = 0.08140, val_recon_loss = 0.08875, val_total_loss = 0.17015 [4.6s]
# [Epoch 36] forecast_loss = 0.06306, recon_loss = 0.08596, total_loss = 0.14902 ---- val_forecast_loss = 0.07981, val_recon_loss = 0.08924, val_total_loss = 0.16905 [4.6s]
# [Epoch 37] forecast_loss = 0.06250, recon_loss = 0.08556, total_loss = 0.14806 ---- val_forecast_loss = 0.08052, val_recon_loss = 0.08659, val_total_loss = 0.16710 [4.6s]
# [Epoch 38] forecast_loss = 0.06155, recon_loss = 0.08505, total_loss = 0.14660 ---- val_forecast_loss = 0.08008, val_recon_loss = 0.08601, val_total_loss = 0.16608 [4.6s]
# [Epoch 39] forecast_loss = 0.06076, recon_loss = 0.08443, total_loss = 0.14519 ---- val_forecast_loss = 0.08150, val_recon_loss = 0.08616, val_total_loss = 0.16766 [4.6s]
# [Epoch 40] forecast_loss = 0.06021, recon_loss = 0.08379, total_loss = 0.14399 ---- val_forecast_loss = 0.07940, val_recon_loss = 0.08677, val_total_loss = 0.16618 [4.6s]
# [Epoch 41] forecast_loss = 0.06004, recon_loss = 0.08366, total_loss = 0.14371 ---- val_forecast_loss = 0.07959, val_recon_loss = 0.08520, val_total_loss = 0.16479 [4.6s]
# [Epoch 42] forecast_loss = 0.05918, recon_loss = 0.08331, total_loss = 0.14249 ---- val_forecast_loss = 0.08325, val_recon_loss = 0.08525, val_total_loss = 0.16849 [4.6s]
# [Epoch 43] forecast_loss = 0.05844, recon_loss = 0.08260, total_loss = 0.14104 ---- val_forecast_loss = 0.08146, val_recon_loss = 0.08435, val_total_loss = 0.16581 [4.6s]
# [Epoch 44] forecast_loss = 0.05783, recon_loss = 0.08221, total_loss = 0.14004 ---- val_forecast_loss = 0.08098, val_recon_loss = 0.08499, val_total_loss = 0.16597 [4.6s]
# [Epoch 45] forecast_loss = 0.05767, recon_loss = 0.08169, total_loss = 0.13935 ---- val_forecast_loss = 0.08131, val_recon_loss = 0.08437, val_total_loss = 0.16568 [4.6s]
# [Epoch 46] forecast_loss = 0.05682, recon_loss = 0.08097, total_loss = 0.13780 ---- val_forecast_loss = 0.08031, val_recon_loss = 0.08247, val_total_loss = 0.16278 [4.5s]
# [Epoch 47] forecast_loss = 0.05682, recon_loss = 0.08081, total_loss = 0.13763 ---- val_forecast_loss = 0.08233, val_recon_loss = 0.08349, val_total_loss = 0.16582 [4.5s]
# [Epoch 48] forecast_loss = 0.05595, recon_loss = 0.08041, total_loss = 0.13636 ---- val_forecast_loss = 0.08352, val_recon_loss = 0.08258, val_total_loss = 0.16610 [4.6s]
# [Epoch 49] forecast_loss = 0.05541, recon_loss = 0.07977, total_loss = 0.13518 ---- val_forecast_loss = 0.08195, val_recon_loss = 0.08236, val_total_loss = 0.16431 [4.6s]
# [Epoch 50] forecast_loss = 0.05565, recon_loss = 0.07955, total_loss = 0.13520 ---- val_forecast_loss = 0.08182, val_recon_loss = 0.08162, val_total_loss = 0.16344 [4.6s]
# [Epoch 51] forecast_loss = 0.05483, recon_loss = 0.07909, total_loss = 0.13392 ---- val_forecast_loss = 0.08168, val_recon_loss = 0.08107, val_total_loss = 0.16275 [4.6s]
# [Epoch 52] forecast_loss = 0.05418, recon_loss = 0.07896, total_loss = 0.13313 ---- val_forecast_loss = 0.08081, val_recon_loss = 0.08177, val_total_loss = 0.16257 [4.5s]
# [Epoch 53] forecast_loss = 0.05363, recon_loss = 0.07858, total_loss = 0.13221 ---- val_forecast_loss = 0.08321, val_recon_loss = 0.08103, val_total_loss = 0.16423 [4.6s]
# [Epoch 54] forecast_loss = 0.05320, recon_loss = 0.07831, total_loss = 0.13150 ---- val_forecast_loss = 0.08195, val_recon_loss = 0.08035, val_total_loss = 0.16230 [4.6s]
# [Epoch 55] forecast_loss = 0.05306, recon_loss = 0.07792, total_loss = 0.13098 ---- val_forecast_loss = 0.08354, val_recon_loss = 0.08042, val_total_loss = 0.16396 [4.6s]
# [Epoch 56] forecast_loss = 0.05209, recon_loss = 0.07744, total_loss = 0.12952 ---- val_forecast_loss = 0.08212, val_recon_loss = 0.07980, val_total_loss = 0.16192 [4.6s]
# [Epoch 57] forecast_loss = 0.05181, recon_loss = 0.07714, total_loss = 0.12895 ---- val_forecast_loss = 0.08144, val_recon_loss = 0.08026, val_total_loss = 0.16169 [4.6s]
# [Epoch 58] forecast_loss = 0.05158, recon_loss = 0.07686, total_loss = 0.12844 ---- val_forecast_loss = 0.08267, val_recon_loss = 0.07927, val_total_loss = 0.16194 [4.6s]
# [Epoch 59] forecast_loss = 0.05119, recon_loss = 0.07636, total_loss = 0.12755 ---- val_forecast_loss = 0.08459, val_recon_loss = 0.07905, val_total_loss = 0.16364 [4.6s]
# [Epoch 60] forecast_loss = 0.05114, recon_loss = 0.07611, total_loss = 0.12725 ---- val_forecast_loss = 0.08153, val_recon_loss = 0.07840, val_total_loss = 0.15993 [4.6s]
# [Epoch 61] forecast_loss = 0.05060, recon_loss = 0.07572, total_loss = 0.12631 ---- val_forecast_loss = 0.08164, val_recon_loss = 0.07863, val_total_loss = 0.16028 [4.7s]
# [Epoch 62] forecast_loss = 0.04936, recon_loss = 0.07535, total_loss = 0.12471 ---- val_forecast_loss = 0.08123, val_recon_loss = 0.07778, val_total_loss = 0.15901 [4.6s]
# [Epoch 63] forecast_loss = 0.04982, recon_loss = 0.07512, total_loss = 0.12495 ---- val_forecast_loss = 0.08180, val_recon_loss = 0.07848, val_total_loss = 0.16027 [4.6s]
# [Epoch 64] forecast_loss = 0.04877, recon_loss = 0.07484, total_loss = 0.12361 ---- val_forecast_loss = 0.08461, val_recon_loss = 0.07782, val_total_loss = 0.16243 [4.7s]
# [Epoch 65] forecast_loss = 0.04801, recon_loss = 0.07473, total_loss = 0.12273 ---- val_forecast_loss = 0.08322, val_recon_loss = 0.07797, val_total_loss = 0.16119 [4.6s]
# [Epoch 66] forecast_loss = 0.04799, recon_loss = 0.07434, total_loss = 0.12233 ---- val_forecast_loss = 0.08333, val_recon_loss = 0.07699, val_total_loss = 0.16031 [4.6s]
# [Epoch 67] forecast_loss = 0.04753, recon_loss = 0.07401, total_loss = 0.12155 ---- val_forecast_loss = 0.08393, val_recon_loss = 0.07685, val_total_loss = 0.16078 [4.6s]
# [Epoch 68] forecast_loss = 0.04768, recon_loss = 0.07379, total_loss = 0.12147 ---- val_forecast_loss = 0.08509, val_recon_loss = 0.07652, val_total_loss = 0.16161 [4.6s]
# [Epoch 69] forecast_loss = 0.04631, recon_loss = 0.07341, total_loss = 0.11972 ---- val_forecast_loss = 0.08187, val_recon_loss = 0.07642, val_total_loss = 0.15829 [4.6s]
# [Epoch 70] forecast_loss = 0.04680, recon_loss = 0.07342, total_loss = 0.12022 ---- val_forecast_loss = 0.08284, val_recon_loss = 0.07692, val_total_loss = 0.15976 [4.6s]
# [Epoch 71] forecast_loss = 0.04638, recon_loss = 0.07286, total_loss = 0.11925 ---- val_forecast_loss = 0.08294, val_recon_loss = 0.07595, val_total_loss = 0.15889 [4.6s]
# [Epoch 72] forecast_loss = 0.04559, recon_loss = 0.07251, total_loss = 0.11809 ---- val_forecast_loss = 0.08298, val_recon_loss = 0.07566, val_total_loss = 0.15864 [4.6s]
# [Epoch 73] forecast_loss = 0.04590, recon_loss = 0.07247, total_loss = 0.11837 ---- val_forecast_loss = 0.08250, val_recon_loss = 0.07526, val_total_loss = 0.15776 [4.6s]
# [Epoch 74] forecast_loss = 0.04633, recon_loss = 0.07228, total_loss = 0.11861 ---- val_forecast_loss = 0.08362, val_recon_loss = 0.07577, val_total_loss = 0.15939 [4.6s]
# [Epoch 75] forecast_loss = 0.04501, recon_loss = 0.07327, total_loss = 0.11827 ---- val_forecast_loss = 0.08275, val_recon_loss = 0.07529, val_total_loss = 0.15804 [4.7s]
# [Epoch 76] forecast_loss = 0.04481, recon_loss = 0.07177, total_loss = 0.11658 ---- val_forecast_loss = 0.08305, val_recon_loss = 0.07509, val_total_loss = 0.15813 [5.3s]
# [Epoch 77] forecast_loss = 0.04425, recon_loss = 0.07159, total_loss = 0.11585 ---- val_forecast_loss = 0.08351, val_recon_loss = 0.07600, val_total_loss = 0.15951 [4.6s]
# [Epoch 78] forecast_loss = 0.04425, recon_loss = 0.07149, total_loss = 0.11575 ---- val_forecast_loss = 0.08300, val_recon_loss = 0.07405, val_total_loss = 0.15705 [4.6s]
# [Epoch 79] forecast_loss = 0.04423, recon_loss = 0.07114, total_loss = 0.11537 ---- val_forecast_loss = 0.08428, val_recon_loss = 0.07473, val_total_loss = 0.15901 [4.6s]
# [Epoch 80] forecast_loss = 0.04373, recon_loss = 0.07093, total_loss = 0.11466 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.07437, val_total_loss = 0.15808 [4.6s]
# [Epoch 81] forecast_loss = 0.04245, recon_loss = 0.07061, total_loss = 0.11307 ---- val_forecast_loss = 0.08396, val_recon_loss = 0.07417, val_total_loss = 0.15813 [4.6s]
# [Epoch 82] forecast_loss = 0.04276, recon_loss = 0.07046, total_loss = 0.11322 ---- val_forecast_loss = 0.08438, val_recon_loss = 0.07405, val_total_loss = 0.15843 [4.6s]
# [Epoch 83] forecast_loss = 0.04219, recon_loss = 0.07014, total_loss = 0.11232 ---- val_forecast_loss = 0.08339, val_recon_loss = 0.07353, val_total_loss = 0.15692 [4.6s]
# [Epoch 84] forecast_loss = 0.04230, recon_loss = 0.06999, total_loss = 0.11229 ---- val_forecast_loss = 0.08412, val_recon_loss = 0.07401, val_total_loss = 0.15813 [4.6s]
# [Epoch 85] forecast_loss = 0.04169, recon_loss = 0.06971, total_loss = 0.11141 ---- val_forecast_loss = 0.08257, val_recon_loss = 0.07278, val_total_loss = 0.15535 [4.6s]
# [Epoch 86] forecast_loss = 0.04255, recon_loss = 0.06969, total_loss = 0.11224 ---- val_forecast_loss = 0.08341, val_recon_loss = 0.07277, val_total_loss = 0.15618 [4.6s]
# [Epoch 87] forecast_loss = 0.04210, recon_loss = 0.06941, total_loss = 0.11151 ---- val_forecast_loss = 0.08261, val_recon_loss = 0.07194, val_total_loss = 0.15455 [4.6s]
# [Epoch 88] forecast_loss = 0.04172, recon_loss = 0.06914, total_loss = 0.11086 ---- val_forecast_loss = 0.08341, val_recon_loss = 0.07245, val_total_loss = 0.15586 [4.6s]
# [Epoch 89] forecast_loss = 0.04109, recon_loss = 0.06899, total_loss = 0.11009 ---- val_forecast_loss = 0.08640, val_recon_loss = 0.07281, val_total_loss = 0.15921 [4.6s]
# [Epoch 90] forecast_loss = 0.04207, recon_loss = 0.06878, total_loss = 0.11085 ---- val_forecast_loss = 0.08427, val_recon_loss = 0.07241, val_total_loss = 0.15668 [4.6s]
# [Epoch 91] forecast_loss = 0.04166, recon_loss = 0.06872, total_loss = 0.11038 ---- val_forecast_loss = 0.08528, val_recon_loss = 0.07178, val_total_loss = 0.15706 [4.6s]
# [Epoch 92] forecast_loss = 0.04072, recon_loss = 0.06831, total_loss = 0.10903 ---- val_forecast_loss = 0.08403, val_recon_loss = 0.07248, val_total_loss = 0.15651 [4.6s]
# [Epoch 93] forecast_loss = 0.03996, recon_loss = 0.06814, total_loss = 0.10810 ---- val_forecast_loss = 0.08456, val_recon_loss = 0.07193, val_total_loss = 0.15650 [4.6s]
# [Epoch 94] forecast_loss = 0.04017, recon_loss = 0.06795, total_loss = 0.10812 ---- val_forecast_loss = 0.08387, val_recon_loss = 0.07154, val_total_loss = 0.15541 [4.6s]
# [Epoch 95] forecast_loss = 0.04035, recon_loss = 0.06769, total_loss = 0.10805 ---- val_forecast_loss = 0.08353, val_recon_loss = 0.07097, val_total_loss = 0.15450 [4.6s]
# [Epoch 96] forecast_loss = 0.03991, recon_loss = 0.06756, total_loss = 0.10747 ---- val_forecast_loss = 0.08356, val_recon_loss = 0.07124, val_total_loss = 0.15480 [4.6s]
# [Epoch 97] forecast_loss = 0.04001, recon_loss = 0.06745, total_loss = 0.10746 ---- val_forecast_loss = 0.08545, val_recon_loss = 0.07158, val_total_loss = 0.15702 [4.6s]
# [Epoch 98] forecast_loss = 0.04003, recon_loss = 0.06714, total_loss = 0.10717 ---- val_forecast_loss = 0.08388, val_recon_loss = 0.07115, val_total_loss = 0.15502 [4.6s]
# [Epoch 99] forecast_loss = 0.03892, recon_loss = 0.06686, total_loss = 0.10577 ---- val_forecast_loss = 0.08341, val_recon_loss = 0.07051, val_total_loss = 0.15392 [4.6s]
# [Epoch 100] forecast_loss = 0.03977, recon_loss = 0.06699, total_loss = 0.10676 ---- val_forecast_loss = 0.08463, val_recon_loss = 0.07075, val_total_loss = 0.15538 [4.6s]
# [Epoch 101] forecast_loss = 0.03883, recon_loss = 0.06652, total_loss = 0.10535 ---- val_forecast_loss = 0.08374, val_recon_loss = 0.06972, val_total_loss = 0.15346 [4.7s]
# [Epoch 102] forecast_loss = 0.03827, recon_loss = 0.06611, total_loss = 0.10438 ---- val_forecast_loss = 0.08309, val_recon_loss = 0.07047, val_total_loss = 0.15356 [4.6s]
# [Epoch 103] forecast_loss = 0.03899, recon_loss = 0.06636, total_loss = 0.10535 ---- val_forecast_loss = 0.08415, val_recon_loss = 0.06984, val_total_loss = 0.15400 [4.6s]
# [Epoch 104] forecast_loss = 0.03805, recon_loss = 0.06593, total_loss = 0.10398 ---- val_forecast_loss = 0.08524, val_recon_loss = 0.06993, val_total_loss = 0.15517 [4.6s]
# [Epoch 105] forecast_loss = 0.03834, recon_loss = 0.06600, total_loss = 0.10433 ---- val_forecast_loss = 0.08415, val_recon_loss = 0.07000, val_total_loss = 0.15415 [4.5s]
# [Epoch 106] forecast_loss = 0.03792, recon_loss = 0.06564, total_loss = 0.10355 ---- val_forecast_loss = 0.08594, val_recon_loss = 0.06945, val_total_loss = 0.15540 [4.6s]
# [Epoch 107] forecast_loss = 0.03806, recon_loss = 0.06541, total_loss = 0.10347 ---- val_forecast_loss = 0.08274, val_recon_loss = 0.06934, val_total_loss = 0.15208 [4.6s]
# [Epoch 108] forecast_loss = 0.03704, recon_loss = 0.06518, total_loss = 0.10222 ---- val_forecast_loss = 0.08395, val_recon_loss = 0.06918, val_total_loss = 0.15314 [4.6s]
# [Epoch 109] forecast_loss = 0.03820, recon_loss = 0.06555, total_loss = 0.10375 ---- val_forecast_loss = 0.08368, val_recon_loss = 0.06941, val_total_loss = 0.15309 [4.6s]
# [Epoch 110] forecast_loss = 0.03775, recon_loss = 0.06576, total_loss = 0.10351 ---- val_forecast_loss = 0.08402, val_recon_loss = 0.07002, val_total_loss = 0.15404 [4.6s]
# [Epoch 111] forecast_loss = 0.03741, recon_loss = 0.06504, total_loss = 0.10246 ---- val_forecast_loss = 0.08337, val_recon_loss = 0.06894, val_total_loss = 0.15231 [4.6s]
# [Epoch 112] forecast_loss = 0.03687, recon_loss = 0.06452, total_loss = 0.10139 ---- val_forecast_loss = 0.08517, val_recon_loss = 0.06922, val_total_loss = 0.15440 [4.6s]
# [Epoch 113] forecast_loss = 0.03653, recon_loss = 0.06456, total_loss = 0.10109 ---- val_forecast_loss = 0.08340, val_recon_loss = 0.06756, val_total_loss = 0.15096 [4.6s]
# [Epoch 114] forecast_loss = 0.03639, recon_loss = 0.06422, total_loss = 0.10061 ---- val_forecast_loss = 0.08517, val_recon_loss = 0.06826, val_total_loss = 0.15343 [4.7s]
# [Epoch 115] forecast_loss = 0.03638, recon_loss = 0.06412, total_loss = 0.10049 ---- val_forecast_loss = 0.08327, val_recon_loss = 0.06811, val_total_loss = 0.15139 [4.6s]
# [Epoch 116] forecast_loss = 0.03648, recon_loss = 0.06402, total_loss = 0.10049 ---- val_forecast_loss = 0.08300, val_recon_loss = 0.06842, val_total_loss = 0.15142 [4.6s]
# [Epoch 117] forecast_loss = 0.03650, recon_loss = 0.06372, total_loss = 0.10022 ---- val_forecast_loss = 0.08432, val_recon_loss = 0.06771, val_total_loss = 0.15203 [4.6s]
# [Epoch 118] forecast_loss = 0.03604, recon_loss = 0.06374, total_loss = 0.09979 ---- val_forecast_loss = 0.08487, val_recon_loss = 0.06823, val_total_loss = 0.15310 [4.6s]
# [Epoch 119] forecast_loss = 0.03576, recon_loss = 0.06353, total_loss = 0.09929 ---- val_forecast_loss = 0.08361, val_recon_loss = 0.06728, val_total_loss = 0.15089 [4.6s]
# [Epoch 120] forecast_loss = 0.03562, recon_loss = 0.06333, total_loss = 0.09896 ---- val_forecast_loss = 0.08282, val_recon_loss = 0.06721, val_total_loss = 0.15003 [4.6s]
# [Epoch 121] forecast_loss = 0.03604, recon_loss = 0.06334, total_loss = 0.09937 ---- val_forecast_loss = 0.08357, val_recon_loss = 0.06818, val_total_loss = 0.15175 [4.6s]
# [Epoch 122] forecast_loss = 0.03538, recon_loss = 0.06324, total_loss = 0.09862 ---- val_forecast_loss = 0.08324, val_recon_loss = 0.06678, val_total_loss = 0.15002 [4.6s]
# [Epoch 123] forecast_loss = 0.03498, recon_loss = 0.06302, total_loss = 0.09800 ---- val_forecast_loss = 0.08577, val_recon_loss = 0.06680, val_total_loss = 0.15257 [4.6s]
# [Epoch 124] forecast_loss = 0.03523, recon_loss = 0.06285, total_loss = 0.09808 ---- val_forecast_loss = 0.08445, val_recon_loss = 0.06749, val_total_loss = 0.15193 [4.6s]
# [Epoch 125] forecast_loss = 0.03559, recon_loss = 0.06287, total_loss = 0.09846 ---- val_forecast_loss = 0.08345, val_recon_loss = 0.06699, val_total_loss = 0.15044 [4.6s]
# [Epoch 126] forecast_loss = 0.03531, recon_loss = 0.06263, total_loss = 0.09794 ---- val_forecast_loss = 0.08394, val_recon_loss = 0.06663, val_total_loss = 0.15057 [4.6s]
# [Epoch 127] forecast_loss = 0.03493, recon_loss = 0.06239, total_loss = 0.09733 ---- val_forecast_loss = 0.08354, val_recon_loss = 0.06656, val_total_loss = 0.15010 [4.6s]
# [Epoch 128] forecast_loss = 0.03500, recon_loss = 0.06251, total_loss = 0.09751 ---- val_forecast_loss = 0.08564, val_recon_loss = 0.06743, val_total_loss = 0.15307 [4.6s]
# [Epoch 129] forecast_loss = 0.03520, recon_loss = 0.06226, total_loss = 0.09746 ---- val_forecast_loss = 0.08336, val_recon_loss = 0.06625, val_total_loss = 0.14961 [4.6s]
# [Epoch 130] forecast_loss = 0.03530, recon_loss = 0.06228, total_loss = 0.09758 ---- val_forecast_loss = 0.08423, val_recon_loss = 0.06661, val_total_loss = 0.15083 [4.6s]
# [Epoch 131] forecast_loss = 0.03451, recon_loss = 0.06197, total_loss = 0.09648 ---- val_forecast_loss = 0.08468, val_recon_loss = 0.06633, val_total_loss = 0.15101 [4.6s]
# [Epoch 132] forecast_loss = 0.03368, recon_loss = 0.06185, total_loss = 0.09553 ---- val_forecast_loss = 0.08491, val_recon_loss = 0.06606, val_total_loss = 0.15097 [4.6s]
# [Epoch 133] forecast_loss = 0.03406, recon_loss = 0.06171, total_loss = 0.09576 ---- val_forecast_loss = 0.08365, val_recon_loss = 0.06607, val_total_loss = 0.14972 [4.6s]
# [Epoch 134] forecast_loss = 0.03406, recon_loss = 0.06163, total_loss = 0.09568 ---- val_forecast_loss = 0.08488, val_recon_loss = 0.06583, val_total_loss = 0.15071 [4.6s]
# [Epoch 135] forecast_loss = 0.03400, recon_loss = 0.06157, total_loss = 0.09557 ---- val_forecast_loss = 0.08475, val_recon_loss = 0.06638, val_total_loss = 0.15113 [4.6s]
# [Epoch 136] forecast_loss = 0.03418, recon_loss = 0.06152, total_loss = 0.09570 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.06562, val_total_loss = 0.14932 [4.6s]
# [Epoch 137] forecast_loss = 0.03353, recon_loss = 0.06134, total_loss = 0.09487 ---- val_forecast_loss = 0.08411, val_recon_loss = 0.06672, val_total_loss = 0.15083 [4.6s]
# [Epoch 138] forecast_loss = 0.03409, recon_loss = 0.06157, total_loss = 0.09567 ---- val_forecast_loss = 0.08458, val_recon_loss = 0.06600, val_total_loss = 0.15058 [4.6s]
# [Epoch 139] forecast_loss = 0.03238, recon_loss = 0.06102, total_loss = 0.09340 ---- val_forecast_loss = 0.08408, val_recon_loss = 0.06553, val_total_loss = 0.14961 [4.6s]
# [Epoch 140] forecast_loss = 0.03281, recon_loss = 0.06092, total_loss = 0.09373 ---- val_forecast_loss = 0.08555, val_recon_loss = 0.06531, val_total_loss = 0.15086 [4.6s]
# [Epoch 141] forecast_loss = 0.03280, recon_loss = 0.06059, total_loss = 0.09340 ---- val_forecast_loss = 0.08508, val_recon_loss = 0.06565, val_total_loss = 0.15073 [4.6s]
# [Epoch 142] forecast_loss = 0.03265, recon_loss = 0.06137, total_loss = 0.09402 ---- val_forecast_loss = 0.08481, val_recon_loss = 0.06507, val_total_loss = 0.14988 [4.5s]
# [Epoch 143] forecast_loss = 0.03317, recon_loss = 0.06068, total_loss = 0.09384 ---- val_forecast_loss = 0.08481, val_recon_loss = 0.06508, val_total_loss = 0.14990 [4.6s]
# [Epoch 144] forecast_loss = 0.03314, recon_loss = 0.06061, total_loss = 0.09375 ---- val_forecast_loss = 0.08379, val_recon_loss = 0.06494, val_total_loss = 0.14873 [4.6s]
# [Epoch 145] forecast_loss = 0.03310, recon_loss = 0.06033, total_loss = 0.09343 ---- val_forecast_loss = 0.08436, val_recon_loss = 0.06527, val_total_loss = 0.14964 [4.6s]
# [Epoch 146] forecast_loss = 0.03263, recon_loss = 0.06035, total_loss = 0.09298 ---- val_forecast_loss = 0.08393, val_recon_loss = 0.06510, val_total_loss = 0.14903 [4.6s]
# [Epoch 147] forecast_loss = 0.03198, recon_loss = 0.06008, total_loss = 0.09206 ---- val_forecast_loss = 0.08551, val_recon_loss = 0.06492, val_total_loss = 0.15043 [4.6s]
# [Epoch 148] forecast_loss = 0.03286, recon_loss = 0.06013, total_loss = 0.09299 ---- val_forecast_loss = 0.08440, val_recon_loss = 0.06479, val_total_loss = 0.14920 [4.6s]
# [Epoch 149] forecast_loss = 0.03250, recon_loss = 0.06006, total_loss = 0.09256 ---- val_forecast_loss = 0.08411, val_recon_loss = 0.06480, val_total_loss = 0.14891 [4.6s]
# [Epoch 150] forecast_loss = 0.03251, recon_loss = 0.05980, total_loss = 0.09231 ---- val_forecast_loss = 0.08507, val_recon_loss = 0.06453, val_total_loss = 0.14960 [4.6s]
# [Epoch 151] forecast_loss = 0.03285, recon_loss = 0.05997, total_loss = 0.09282 ---- val_forecast_loss = 0.08442, val_recon_loss = 0.06466, val_total_loss = 0.14908 [4.6s]
# [Epoch 152] forecast_loss = 0.03254, recon_loss = 0.05968, total_loss = 0.09222 ---- val_forecast_loss = 0.08450, val_recon_loss = 0.06419, val_total_loss = 0.14869 [4.6s]
# [Epoch 153] forecast_loss = 0.03229, recon_loss = 0.05947, total_loss = 0.09177 ---- val_forecast_loss = 0.08409, val_recon_loss = 0.06389, val_total_loss = 0.14797 [4.6s]
# [Epoch 154] forecast_loss = 0.03192, recon_loss = 0.05930, total_loss = 0.09122 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.06395, val_total_loss = 0.14767 [4.6s]
# [Epoch 155] forecast_loss = 0.03194, recon_loss = 0.05939, total_loss = 0.09133 ---- val_forecast_loss = 0.08288, val_recon_loss = 0.06422, val_total_loss = 0.14710 [4.6s]
# [Epoch 156] forecast_loss = 0.03212, recon_loss = 0.05931, total_loss = 0.09143 ---- val_forecast_loss = 0.08406, val_recon_loss = 0.06419, val_total_loss = 0.14825 [4.7s]
# [Epoch 157] forecast_loss = 0.03164, recon_loss = 0.05923, total_loss = 0.09087 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.06422, val_total_loss = 0.14794 [4.6s]
# [Epoch 158] forecast_loss = 0.03239, recon_loss = 0.05908, total_loss = 0.09147 ---- val_forecast_loss = 0.08329, val_recon_loss = 0.06316, val_total_loss = 0.14645 [4.6s]
# [Epoch 159] forecast_loss = 0.03161, recon_loss = 0.05879, total_loss = 0.09041 ---- val_forecast_loss = 0.08418, val_recon_loss = 0.06325, val_total_loss = 0.14743 [4.6s]
# [Epoch 160] forecast_loss = 0.03140, recon_loss = 0.05874, total_loss = 0.09014 ---- val_forecast_loss = 0.08443, val_recon_loss = 0.06407, val_total_loss = 0.14850 [4.6s]
# [Epoch 161] forecast_loss = 0.03103, recon_loss = 0.05870, total_loss = 0.08972 ---- val_forecast_loss = 0.08294, val_recon_loss = 0.06369, val_total_loss = 0.14663 [4.6s]
# [Epoch 162] forecast_loss = 0.03175, recon_loss = 0.05869, total_loss = 0.09044 ---- val_forecast_loss = 0.08498, val_recon_loss = 0.06350, val_total_loss = 0.14847 [4.6s]
# [Epoch 163] forecast_loss = 0.03134, recon_loss = 0.05861, total_loss = 0.08995 ---- val_forecast_loss = 0.08393, val_recon_loss = 0.06375, val_total_loss = 0.14769 [4.6s]
# [Epoch 164] forecast_loss = 0.03183, recon_loss = 0.05844, total_loss = 0.09027 ---- val_forecast_loss = 0.08470, val_recon_loss = 0.06300, val_total_loss = 0.14770 [4.6s]
# [Epoch 165] forecast_loss = 0.03141, recon_loss = 0.05845, total_loss = 0.08986 ---- val_forecast_loss = 0.08437, val_recon_loss = 0.06386, val_total_loss = 0.14823 [4.6s]
# [Epoch 166] forecast_loss = 0.03153, recon_loss = 0.05814, total_loss = 0.08967 ---- val_forecast_loss = 0.08445, val_recon_loss = 0.06294, val_total_loss = 0.14740 [4.6s]
# [Epoch 167] forecast_loss = 0.03164, recon_loss = 0.05813, total_loss = 0.08976 ---- val_forecast_loss = 0.08464, val_recon_loss = 0.06321, val_total_loss = 0.14785 [4.6s]
# [Epoch 168] forecast_loss = 0.03167, recon_loss = 0.05816, total_loss = 0.08983 ---- val_forecast_loss = 0.08588, val_recon_loss = 0.06281, val_total_loss = 0.14869 [4.6s]
# [Epoch 169] forecast_loss = 0.03143, recon_loss = 0.05790, total_loss = 0.08932 ---- val_forecast_loss = 0.08449, val_recon_loss = 0.06319, val_total_loss = 0.14768 [4.6s]
# [Epoch 170] forecast_loss = 0.03098, recon_loss = 0.05780, total_loss = 0.08878 ---- val_forecast_loss = 0.08331, val_recon_loss = 0.06234, val_total_loss = 0.14565 [4.6s]
# [Epoch 171] forecast_loss = 0.03049, recon_loss = 0.05768, total_loss = 0.08817 ---- val_forecast_loss = 0.08476, val_recon_loss = 0.06310, val_total_loss = 0.14786 [4.6s]
# [Epoch 172] forecast_loss = 0.03076, recon_loss = 0.05778, total_loss = 0.08853 ---- val_forecast_loss = 0.08401, val_recon_loss = 0.06263, val_total_loss = 0.14663 [4.6s]
# [Epoch 173] forecast_loss = 0.03054, recon_loss = 0.05746, total_loss = 0.08800 ---- val_forecast_loss = 0.08504, val_recon_loss = 0.06272, val_total_loss = 0.14776 [4.6s]
# [Epoch 174] forecast_loss = 0.03075, recon_loss = 0.05739, total_loss = 0.08813 ---- val_forecast_loss = 0.08345, val_recon_loss = 0.06211, val_total_loss = 0.14555 [4.5s]
# [Epoch 175] forecast_loss = 0.03037, recon_loss = 0.05737, total_loss = 0.08774 ---- val_forecast_loss = 0.08283, val_recon_loss = 0.06219, val_total_loss = 0.14502 [4.6s]
# [Epoch 176] forecast_loss = 0.03026, recon_loss = 0.05717, total_loss = 0.08742 ---- val_forecast_loss = 0.08237, val_recon_loss = 0.06203, val_total_loss = 0.14439 [4.6s]
# [Epoch 177] forecast_loss = 0.03014, recon_loss = 0.05709, total_loss = 0.08722 ---- val_forecast_loss = 0.08292, val_recon_loss = 0.06200, val_total_loss = 0.14492 [5.3s]
# [Epoch 178] forecast_loss = 0.03056, recon_loss = 0.05757, total_loss = 0.08813 ---- val_forecast_loss = 0.08384, val_recon_loss = 0.06251, val_total_loss = 0.14635 [4.6s]
# [Epoch 179] forecast_loss = 0.02986, recon_loss = 0.05730, total_loss = 0.08717 ---- val_forecast_loss = 0.08368, val_recon_loss = 0.06197, val_total_loss = 0.14566 [4.6s]
# [Epoch 180] forecast_loss = 0.03049, recon_loss = 0.05692, total_loss = 0.08742 ---- val_forecast_loss = 0.08452, val_recon_loss = 0.06202, val_total_loss = 0.14654 [4.6s]
# [Epoch 181] forecast_loss = 0.03033, recon_loss = 0.05693, total_loss = 0.08727 ---- val_forecast_loss = 0.08515, val_recon_loss = 0.06184, val_total_loss = 0.14699 [4.6s]
# [Epoch 182] forecast_loss = 0.03012, recon_loss = 0.05662, total_loss = 0.08674 ---- val_forecast_loss = 0.08335, val_recon_loss = 0.06169, val_total_loss = 0.14504 [4.6s]
# [Epoch 183] forecast_loss = 0.03090, recon_loss = 0.05665, total_loss = 0.08755 ---- val_forecast_loss = 0.08495, val_recon_loss = 0.06199, val_total_loss = 0.14694 [4.6s]
# [Epoch 184] forecast_loss = 0.02974, recon_loss = 0.05653, total_loss = 0.08628 ---- val_forecast_loss = 0.08356, val_recon_loss = 0.06116, val_total_loss = 0.14472 [4.6s]
# [Epoch 185] forecast_loss = 0.03060, recon_loss = 0.05632, total_loss = 0.08692 ---- val_forecast_loss = 0.08502, val_recon_loss = 0.06131, val_total_loss = 0.14633 [4.6s]
# [Epoch 186] forecast_loss = 0.02944, recon_loss = 0.05627, total_loss = 0.08571 ---- val_forecast_loss = 0.08482, val_recon_loss = 0.06200, val_total_loss = 0.14682 [4.6s]
# [Epoch 187] forecast_loss = 0.03061, recon_loss = 0.05625, total_loss = 0.08686 ---- val_forecast_loss = 0.08447, val_recon_loss = 0.06093, val_total_loss = 0.14539 [4.6s]
# [Epoch 188] forecast_loss = 0.03011, recon_loss = 0.05616, total_loss = 0.08627 ---- val_forecast_loss = 0.08284, val_recon_loss = 0.06087, val_total_loss = 0.14372 [4.6s]
# [Epoch 189] forecast_loss = 0.03014, recon_loss = 0.05603, total_loss = 0.08617 ---- val_forecast_loss = 0.08363, val_recon_loss = 0.06226, val_total_loss = 0.14589 [4.6s]
# [Epoch 190] forecast_loss = 0.03068, recon_loss = 0.05619, total_loss = 0.08687 ---- val_forecast_loss = 0.08373, val_recon_loss = 0.06106, val_total_loss = 0.14479 [4.6s]
# [Epoch 191] forecast_loss = 0.02906, recon_loss = 0.05576, total_loss = 0.08481 ---- val_forecast_loss = 0.08440, val_recon_loss = 0.06086, val_total_loss = 0.14526 [4.6s]
# [Epoch 192] forecast_loss = 0.02942, recon_loss = 0.05576, total_loss = 0.08518 ---- val_forecast_loss = 0.08437, val_recon_loss = 0.06097, val_total_loss = 0.14534 [4.6s]
# [Epoch 193] forecast_loss = 0.02938, recon_loss = 0.05570, total_loss = 0.08508 ---- val_forecast_loss = 0.08417, val_recon_loss = 0.06142, val_total_loss = 0.14559 [4.6s]
# [Epoch 194] forecast_loss = 0.02955, recon_loss = 0.05574, total_loss = 0.08529 ---- val_forecast_loss = 0.08357, val_recon_loss = 0.06090, val_total_loss = 0.14446 [4.6s]
# [Epoch 195] forecast_loss = 0.02947, recon_loss = 0.05564, total_loss = 0.08512 ---- val_forecast_loss = 0.08408, val_recon_loss = 0.06090, val_total_loss = 0.14498 [4.6s]
# [Epoch 196] forecast_loss = 0.02954, recon_loss = 0.05542, total_loss = 0.08495 ---- val_forecast_loss = 0.08385, val_recon_loss = 0.06030, val_total_loss = 0.14415 [4.7s]
# [Epoch 197] forecast_loss = 0.02931, recon_loss = 0.05531, total_loss = 0.08461 ---- val_forecast_loss = 0.08439, val_recon_loss = 0.06007, val_total_loss = 0.14446 [4.6s]
# [Epoch 198] forecast_loss = 0.02959, recon_loss = 0.05542, total_loss = 0.08501 ---- val_forecast_loss = 0.08545, val_recon_loss = 0.06072, val_total_loss = 0.14618 [4.6s]
# [Epoch 199] forecast_loss = 0.02848, recon_loss = 0.05515, total_loss = 0.08364 ---- val_forecast_loss = 0.08288, val_recon_loss = 0.05952, val_total_loss = 0.14241 [4.6s]
# [Epoch 200] forecast_loss = 0.02877, recon_loss = 0.05497, total_loss = 0.08375 ---- val_forecast_loss = 0.08474, val_recon_loss = 0.05977, val_total_loss = 0.14450 [4.6s]
# [Epoch 201] forecast_loss = 0.02877, recon_loss = 0.05497, total_loss = 0.08374 ---- val_forecast_loss = 0.08375, val_recon_loss = 0.06017, val_total_loss = 0.14392 [4.6s]
# [Epoch 202] forecast_loss = 0.02939, recon_loss = 0.05506, total_loss = 0.08445 ---- val_forecast_loss = 0.08437, val_recon_loss = 0.06070, val_total_loss = 0.14507 [4.6s]
# [Epoch 203] forecast_loss = 0.02906, recon_loss = 0.05496, total_loss = 0.08402 ---- val_forecast_loss = 0.08443, val_recon_loss = 0.05977, val_total_loss = 0.14420 [4.6s]
# [Epoch 204] forecast_loss = 0.02956, recon_loss = 0.05475, total_loss = 0.08432 ---- val_forecast_loss = 0.08367, val_recon_loss = 0.05998, val_total_loss = 0.14365 [4.6s]
# [Epoch 205] forecast_loss = 0.02880, recon_loss = 0.05456, total_loss = 0.08335 ---- val_forecast_loss = 0.08344, val_recon_loss = 0.05961, val_total_loss = 0.14304 [4.6s]
# [Epoch 206] forecast_loss = 0.02848, recon_loss = 0.05455, total_loss = 0.08303 ---- val_forecast_loss = 0.08470, val_recon_loss = 0.05980, val_total_loss = 0.14450 [4.6s]
# [Epoch 207] forecast_loss = 0.02933, recon_loss = 0.05458, total_loss = 0.08391 ---- val_forecast_loss = 0.08448, val_recon_loss = 0.06009, val_total_loss = 0.14457 [4.6s]
# [Epoch 208] forecast_loss = 0.02844, recon_loss = 0.05439, total_loss = 0.08283 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.05974, val_total_loss = 0.14394 [4.6s]
# [Epoch 209] forecast_loss = 0.02883, recon_loss = 0.05438, total_loss = 0.08320 ---- val_forecast_loss = 0.08354, val_recon_loss = 0.05975, val_total_loss = 0.14329 [4.6s]
# [Epoch 210] forecast_loss = 0.02842, recon_loss = 0.05411, total_loss = 0.08252 ---- val_forecast_loss = 0.08354, val_recon_loss = 0.05917, val_total_loss = 0.14271 [4.5s]
# [Epoch 211] forecast_loss = 0.02859, recon_loss = 0.05431, total_loss = 0.08290 ---- val_forecast_loss = 0.08384, val_recon_loss = 0.05965, val_total_loss = 0.14349 [4.5s]
# [Epoch 212] forecast_loss = 0.02938, recon_loss = 0.05406, total_loss = 0.08343 ---- val_forecast_loss = 0.08384, val_recon_loss = 0.05927, val_total_loss = 0.14310 [4.7s]
# [Epoch 213] forecast_loss = 0.02821, recon_loss = 0.05390, total_loss = 0.08211 ---- val_forecast_loss = 0.08314, val_recon_loss = 0.05888, val_total_loss = 0.14203 [4.6s]
# [Epoch 214] forecast_loss = 0.02878, recon_loss = 0.05404, total_loss = 0.08282 ---- val_forecast_loss = 0.08459, val_recon_loss = 0.05884, val_total_loss = 0.14343 [4.6s]
# [Epoch 215] forecast_loss = 0.02861, recon_loss = 0.05388, total_loss = 0.08248 ---- val_forecast_loss = 0.08390, val_recon_loss = 0.05877, val_total_loss = 0.14267 [4.6s]
# [Epoch 216] forecast_loss = 0.02824, recon_loss = 0.05372, total_loss = 0.08196 ---- val_forecast_loss = 0.08510, val_recon_loss = 0.05970, val_total_loss = 0.14480 [4.5s]
# [Epoch 217] forecast_loss = 0.02898, recon_loss = 0.05356, total_loss = 0.08254 ---- val_forecast_loss = 0.08356, val_recon_loss = 0.05885, val_total_loss = 0.14241 [4.6s]
# [Epoch 218] forecast_loss = 0.02798, recon_loss = 0.05351, total_loss = 0.08149 ---- val_forecast_loss = 0.08485, val_recon_loss = 0.05930, val_total_loss = 0.14415 [4.6s]
# [Epoch 219] forecast_loss = 0.02731, recon_loss = 0.05341, total_loss = 0.08072 ---- val_forecast_loss = 0.08281, val_recon_loss = 0.05892, val_total_loss = 0.14173 [4.5s]
# [Epoch 220] forecast_loss = 0.02830, recon_loss = 0.05345, total_loss = 0.08175 ---- val_forecast_loss = 0.08480, val_recon_loss = 0.05865, val_total_loss = 0.14345 [4.6s]
# [Epoch 221] forecast_loss = 0.02819, recon_loss = 0.05334, total_loss = 0.08153 ---- val_forecast_loss = 0.08434, val_recon_loss = 0.05818, val_total_loss = 0.14252 [4.6s]
# [Epoch 222] forecast_loss = 0.02795, recon_loss = 0.05330, total_loss = 0.08125 ---- val_forecast_loss = 0.08411, val_recon_loss = 0.05808, val_total_loss = 0.14219 [4.6s]
# [Epoch 223] forecast_loss = 0.02820, recon_loss = 0.05314, total_loss = 0.08134 ---- val_forecast_loss = 0.08369, val_recon_loss = 0.05848, val_total_loss = 0.14216 [4.6s]
# [Epoch 224] forecast_loss = 0.02749, recon_loss = 0.05308, total_loss = 0.08057 ---- val_forecast_loss = 0.08358, val_recon_loss = 0.05781, val_total_loss = 0.14139 [4.6s]
# [Epoch 225] forecast_loss = 0.02763, recon_loss = 0.05294, total_loss = 0.08057 ---- val_forecast_loss = 0.08335, val_recon_loss = 0.05808, val_total_loss = 0.14143 [4.6s]
# [Epoch 226] forecast_loss = 0.02823, recon_loss = 0.05294, total_loss = 0.08117 ---- val_forecast_loss = 0.08281, val_recon_loss = 0.05783, val_total_loss = 0.14064 [4.6s]
# [Epoch 227] forecast_loss = 0.02752, recon_loss = 0.05294, total_loss = 0.08046 ---- val_forecast_loss = 0.08352, val_recon_loss = 0.05774, val_total_loss = 0.14126 [4.6s]
# [Epoch 228] forecast_loss = 0.02815, recon_loss = 0.05302, total_loss = 0.08117 ---- val_forecast_loss = 0.08297, val_recon_loss = 0.05745, val_total_loss = 0.14042 [4.6s]
# [Epoch 229] forecast_loss = 0.02810, recon_loss = 0.05263, total_loss = 0.08073 ---- val_forecast_loss = 0.08385, val_recon_loss = 0.05752, val_total_loss = 0.14137 [4.6s]
# [Epoch 230] forecast_loss = 0.02799, recon_loss = 0.05254, total_loss = 0.08053 ---- val_forecast_loss = 0.08323, val_recon_loss = 0.05789, val_total_loss = 0.14111 [4.6s]
# [Epoch 231] forecast_loss = 0.02763, recon_loss = 0.05279, total_loss = 0.08042 ---- val_forecast_loss = 0.08496, val_recon_loss = 0.05778, val_total_loss = 0.14273 [4.6s]
# [Epoch 232] forecast_loss = 0.02778, recon_loss = 0.05255, total_loss = 0.08033 ---- val_forecast_loss = 0.08428, val_recon_loss = 0.05821, val_total_loss = 0.14249 [4.5s]
# [Epoch 233] forecast_loss = 0.02765, recon_loss = 0.05253, total_loss = 0.08017 ---- val_forecast_loss = 0.08370, val_recon_loss = 0.05809, val_total_loss = 0.14179 [4.6s]
# [Epoch 234] forecast_loss = 0.02797, recon_loss = 0.05257, total_loss = 0.08055 ---- val_forecast_loss = 0.08432, val_recon_loss = 0.05768, val_total_loss = 0.14200 [4.6s]
# [Epoch 235] forecast_loss = 0.02705, recon_loss = 0.05230, total_loss = 0.07935 ---- val_forecast_loss = 0.08440, val_recon_loss = 0.05783, val_total_loss = 0.14223 [4.6s]
# [Epoch 236] forecast_loss = 0.02776, recon_loss = 0.05222, total_loss = 0.07998 ---- val_forecast_loss = 0.08459, val_recon_loss = 0.05784, val_total_loss = 0.14244 [4.6s]
# [Epoch 237] forecast_loss = 0.02697, recon_loss = 0.05211, total_loss = 0.07908 ---- val_forecast_loss = 0.08362, val_recon_loss = 0.05705, val_total_loss = 0.14067 [4.6s]
# [Epoch 238] forecast_loss = 0.02751, recon_loss = 0.05221, total_loss = 0.07973 ---- val_forecast_loss = 0.08280, val_recon_loss = 0.05754, val_total_loss = 0.14034 [4.6s]
# [Epoch 239] forecast_loss = 0.02706, recon_loss = 0.05195, total_loss = 0.07901 ---- val_forecast_loss = 0.08268, val_recon_loss = 0.05672, val_total_loss = 0.13940 [4.6s]
# [Epoch 240] forecast_loss = 0.02770, recon_loss = 0.05185, total_loss = 0.07954 ---- val_forecast_loss = 0.08395, val_recon_loss = 0.05752, val_total_loss = 0.14147 [4.6s]
# [Epoch 241] forecast_loss = 0.02809, recon_loss = 0.05196, total_loss = 0.08005 ---- val_forecast_loss = 0.08395, val_recon_loss = 0.05683, val_total_loss = 0.14078 [4.6s]
# [Epoch 242] forecast_loss = 0.02710, recon_loss = 0.05169, total_loss = 0.07879 ---- val_forecast_loss = 0.08332, val_recon_loss = 0.05682, val_total_loss = 0.14014 [4.6s]
# [Epoch 243] forecast_loss = 0.02772, recon_loss = 0.05167, total_loss = 0.07939 ---- val_forecast_loss = 0.08497, val_recon_loss = 0.05664, val_total_loss = 0.14161 [4.6s]
# [Epoch 244] forecast_loss = 0.02713, recon_loss = 0.05172, total_loss = 0.07884 ---- val_forecast_loss = 0.08433, val_recon_loss = 0.05619, val_total_loss = 0.14052 [4.6s]
# [Epoch 245] forecast_loss = 0.02696, recon_loss = 0.05178, total_loss = 0.07874 ---- val_forecast_loss = 0.08430, val_recon_loss = 0.05690, val_total_loss = 0.14120 [4.6s]
# [Epoch 246] forecast_loss = 0.02734, recon_loss = 0.05154, total_loss = 0.07888 ---- val_forecast_loss = 0.08473, val_recon_loss = 0.05668, val_total_loss = 0.14141 [4.6s]
# [Epoch 247] forecast_loss = 0.02710, recon_loss = 0.05143, total_loss = 0.07853 ---- val_forecast_loss = 0.08477, val_recon_loss = 0.05716, val_total_loss = 0.14192 [4.6s]
# [Epoch 248] forecast_loss = 0.02756, recon_loss = 0.05170, total_loss = 0.07927 ---- val_forecast_loss = 0.08468, val_recon_loss = 0.05715, val_total_loss = 0.14183 [4.6s]
# [Epoch 249] forecast_loss = 0.02687, recon_loss = 0.05148, total_loss = 0.07835 ---- val_forecast_loss = 0.08432, val_recon_loss = 0.05657, val_total_loss = 0.14088 [4.6s]
# [Epoch 250] forecast_loss = 0.02672, recon_loss = 0.05136, total_loss = 0.07808 ---- val_forecast_loss = 0.08417, val_recon_loss = 0.05646, val_total_loss = 0.14063 [4.6s]
# [Epoch 251] forecast_loss = 0.02672, recon_loss = 0.05126, total_loss = 0.07797 ---- val_forecast_loss = 0.08407, val_recon_loss = 0.05669, val_total_loss = 0.14076 [4.6s]
# [Epoch 252] forecast_loss = 0.02749, recon_loss = 0.05131, total_loss = 0.07880 ---- val_forecast_loss = 0.08346, val_recon_loss = 0.05638, val_total_loss = 0.13985 [4.6s]
# [Epoch 253] forecast_loss = 0.02697, recon_loss = 0.05112, total_loss = 0.07810 ---- val_forecast_loss = 0.08381, val_recon_loss = 0.05641, val_total_loss = 0.14023 [4.5s]
# [Epoch 254] forecast_loss = 0.02712, recon_loss = 0.05110, total_loss = 0.07822 ---- val_forecast_loss = 0.08340, val_recon_loss = 0.05601, val_total_loss = 0.13941 [4.6s]
# [Epoch 255] forecast_loss = 0.02644, recon_loss = 0.05085, total_loss = 0.07729 ---- val_forecast_loss = 0.08338, val_recon_loss = 0.05572, val_total_loss = 0.13910 [4.6s]
# [Epoch 256] forecast_loss = 0.02712, recon_loss = 0.05079, total_loss = 0.07791 ---- val_forecast_loss = 0.08347, val_recon_loss = 0.05648, val_total_loss = 0.13995 [4.5s]
# [Epoch 257] forecast_loss = 0.02670, recon_loss = 0.05091, total_loss = 0.07761 ---- val_forecast_loss = 0.08321, val_recon_loss = 0.05609, val_total_loss = 0.13930 [4.6s]
# [Epoch 258] forecast_loss = 0.02628, recon_loss = 0.05083, total_loss = 0.07711 ---- val_forecast_loss = 0.08485, val_recon_loss = 0.05642, val_total_loss = 0.14127 [4.6s]
# [Epoch 259] forecast_loss = 0.02719, recon_loss = 0.05069, total_loss = 0.07787 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.05558, val_total_loss = 0.13931 [4.6s]
# [Epoch 260] forecast_loss = 0.02650, recon_loss = 0.05072, total_loss = 0.07723 ---- val_forecast_loss = 0.08433, val_recon_loss = 0.05571, val_total_loss = 0.14003 [4.6s]
# [Epoch 261] forecast_loss = 0.02701, recon_loss = 0.05072, total_loss = 0.07772 ---- val_forecast_loss = 0.08491, val_recon_loss = 0.05568, val_total_loss = 0.14058 [4.5s]
# [Epoch 262] forecast_loss = 0.02650, recon_loss = 0.05057, total_loss = 0.07707 ---- val_forecast_loss = 0.08278, val_recon_loss = 0.05526, val_total_loss = 0.13804 [4.6s]
# [Epoch 263] forecast_loss = 0.02651, recon_loss = 0.05044, total_loss = 0.07695 ---- val_forecast_loss = 0.08448, val_recon_loss = 0.05601, val_total_loss = 0.14049 [4.6s]
# [Epoch 264] forecast_loss = 0.02635, recon_loss = 0.05030, total_loss = 0.07666 ---- val_forecast_loss = 0.08317, val_recon_loss = 0.05540, val_total_loss = 0.13857 [4.5s]
# [Epoch 265] forecast_loss = 0.02718, recon_loss = 0.05066, total_loss = 0.07784 ---- val_forecast_loss = 0.08506, val_recon_loss = 0.05569, val_total_loss = 0.14075 [4.6s]
# [Epoch 266] forecast_loss = 0.02703, recon_loss = 0.05029, total_loss = 0.07733 ---- val_forecast_loss = 0.08417, val_recon_loss = 0.05531, val_total_loss = 0.13948 [4.6s]
# [Epoch 267] forecast_loss = 0.02609, recon_loss = 0.05012, total_loss = 0.07620 ---- val_forecast_loss = 0.08483, val_recon_loss = 0.05483, val_total_loss = 0.13967 [4.6s]
# [Epoch 268] forecast_loss = 0.02597, recon_loss = 0.05013, total_loss = 0.07610 ---- val_forecast_loss = 0.08276, val_recon_loss = 0.05533, val_total_loss = 0.13809 [4.6s]
# [Epoch 269] forecast_loss = 0.02651, recon_loss = 0.05012, total_loss = 0.07663 ---- val_forecast_loss = 0.08313, val_recon_loss = 0.05576, val_total_loss = 0.13889 [4.6s]
# [Epoch 270] forecast_loss = 0.02704, recon_loss = 0.05002, total_loss = 0.07706 ---- val_forecast_loss = 0.08473, val_recon_loss = 0.05485, val_total_loss = 0.13958 [4.6s]
# [Epoch 271] forecast_loss = 0.02619, recon_loss = 0.04992, total_loss = 0.07611 ---- val_forecast_loss = 0.08404, val_recon_loss = 0.05485, val_total_loss = 0.13889 [4.6s]
# [Epoch 272] forecast_loss = 0.02715, recon_loss = 0.05012, total_loss = 0.07727 ---- val_forecast_loss = 0.08330, val_recon_loss = 0.05493, val_total_loss = 0.13823 [4.6s]
# [Epoch 273] forecast_loss = 0.02623, recon_loss = 0.04996, total_loss = 0.07619 ---- val_forecast_loss = 0.08330, val_recon_loss = 0.05519, val_total_loss = 0.13849 [4.6s]
# [Epoch 274] forecast_loss = 0.02575, recon_loss = 0.04984, total_loss = 0.07559 ---- val_forecast_loss = 0.08457, val_recon_loss = 0.05538, val_total_loss = 0.13995 [4.6s]
# [Epoch 275] forecast_loss = 0.02603, recon_loss = 0.04991, total_loss = 0.07594 ---- val_forecast_loss = 0.08362, val_recon_loss = 0.05488, val_total_loss = 0.13850 [4.6s]
# [Epoch 276] forecast_loss = 0.02635, recon_loss = 0.04971, total_loss = 0.07606 ---- val_forecast_loss = 0.08488, val_recon_loss = 0.05502, val_total_loss = 0.13990 [4.6s]
# [Epoch 277] forecast_loss = 0.02552, recon_loss = 0.04953, total_loss = 0.07505 ---- val_forecast_loss = 0.08370, val_recon_loss = 0.05439, val_total_loss = 0.13809 [4.6s]
# [Epoch 278] forecast_loss = 0.02659, recon_loss = 0.04946, total_loss = 0.07605 ---- val_forecast_loss = 0.08650, val_recon_loss = 0.05465, val_total_loss = 0.14115 [4.6s]
# [Epoch 279] forecast_loss = 0.02549, recon_loss = 0.04987, total_loss = 0.07536 ---- val_forecast_loss = 0.08367, val_recon_loss = 0.05524, val_total_loss = 0.13890 [4.6s]
# ...
# [Epoch 409] forecast_loss = 0.02301, recon_loss = 0.04353, total_loss = 0.06655 ---- val_forecast_loss = 0.08416, val_recon_loss = 0.04823, val_total_loss = 0.13240 [4.6s]
# [Epoch 410] forecast_loss = 0.02269, recon_loss = 0.04324, total_loss = 0.06593 ---- val_forecast_loss = 0.08391, val_recon_loss = 0.04799, val_total_loss = 0.13190 [4.6s]
# [Epoch 411] forecast_loss = 0.02419, recon_loss = 0.04329, total_loss = 0.06748 ---- val_forecast_loss = 0.08442, val_recon_loss = 0.04830, val_total_loss = 0.13272 [4.6s]
# [Epoch 412] forecast_loss = 0.02266, recon_loss = 0.04320, total_loss = 0.06585 ---- val_forecast_loss = 0.08330, val_recon_loss = 0.04795, val_total_loss = 0.13126 [4.6s]
# [Epoch 413] forecast_loss = 0.02285, recon_loss = 0.04328, total_loss = 0.06613 ---- val_forecast_loss = 0.08429, val_recon_loss = 0.04817, val_total_loss = 0.13246 [4.6s]
# [Epoch 414] forecast_loss = 0.02265, recon_loss = 0.04341, total_loss = 0.06606 ---- val_forecast_loss = 0.08391, val_recon_loss = 0.04835, val_total_loss = 0.13227 [4.6s]
# [Epoch 415] forecast_loss = 0.02260, recon_loss = 0.04299, total_loss = 0.06558 ---- val_forecast_loss = 0.08466, val_recon_loss = 0.04811, val_total_loss = 0.13277 [4.6s]
# [Epoch 416] forecast_loss = 0.02276, recon_loss = 0.04322, total_loss = 0.06598 ---- val_forecast_loss = 0.08405, val_recon_loss = 0.04789, val_total_loss = 0.13194 [4.6s]
# [Epoch 417] forecast_loss = 0.02233, recon_loss = 0.04295, total_loss = 0.06528 ---- val_forecast_loss = 0.08384, val_recon_loss = 0.04762, val_total_loss = 0.13145 [4.6s]
# [Epoch 418] forecast_loss = 0.02343, recon_loss = 0.04304, total_loss = 0.06646 ---- val_forecast_loss = 0.08408, val_recon_loss = 0.04750, val_total_loss = 0.13157 [4.6s]
# [Epoch 419] forecast_loss = 0.02202, recon_loss = 0.04295, total_loss = 0.06497 ---- val_forecast_loss = 0.08368, val_recon_loss = 0.04763, val_total_loss = 0.13131 [4.6s]
# [Epoch 420] forecast_loss = 0.02275, recon_loss = 0.04284, total_loss = 0.06559 ---- val_forecast_loss = 0.08349, val_recon_loss = 0.04820, val_total_loss = 0.13169 [4.5s]
# [Epoch 421] forecast_loss = 0.02288, recon_loss = 0.04299, total_loss = 0.06587 ---- val_forecast_loss = 0.08334, val_recon_loss = 0.04914, val_total_loss = 0.13248 [4.6s]
# [Epoch 422] forecast_loss = 0.02307, recon_loss = 0.04304, total_loss = 0.06611 ---- val_forecast_loss = 0.08434, val_recon_loss = 0.04826, val_total_loss = 0.13260 [4.6s]
# [Epoch 423] forecast_loss = 0.02289, recon_loss = 0.04280, total_loss = 0.06569 ---- val_forecast_loss = 0.08401, val_recon_loss = 0.04773, val_total_loss = 0.13174 [4.5s]
# [Epoch 424] forecast_loss = 0.02264, recon_loss = 0.04280, total_loss = 0.06544 ---- val_forecast_loss = 0.08408, val_recon_loss = 0.04809, val_total_loss = 0.13217 [4.6s]
# [Epoch 425] forecast_loss = 0.02254, recon_loss = 0.04277, total_loss = 0.06531 ---- val_forecast_loss = 0.08426, val_recon_loss = 0.04781, val_total_loss = 0.13207 [4.6s]
# [Epoch 426] forecast_loss = 0.02285, recon_loss = 0.04301, total_loss = 0.06586 ---- val_forecast_loss = 0.08468, val_recon_loss = 0.04776, val_total_loss = 0.13244 [4.6s]
# [Epoch 427] forecast_loss = 0.02338, recon_loss = 0.04270, total_loss = 0.06608 ---- val_forecast_loss = 0.08346, val_recon_loss = 0.04765, val_total_loss = 0.13111 [4.6s]
# [Epoch 428] forecast_loss = 0.02311, recon_loss = 0.04258, total_loss = 0.06569 ---- val_forecast_loss = 0.08327, val_recon_loss = 0.04761, val_total_loss = 0.13088 [4.6s]
# [Epoch 429] forecast_loss = 0.02271, recon_loss = 0.04270, total_loss = 0.06540 ---- val_forecast_loss = 0.08350, val_recon_loss = 0.04766, val_total_loss = 0.13116 [4.6s]
# [Epoch 430] forecast_loss = 0.02300, recon_loss = 0.04364, total_loss = 0.06664 ---- val_forecast_loss = 0.08426, val_recon_loss = 0.04831, val_total_loss = 0.13256 [4.6s]
# [Epoch 431] forecast_loss = 0.02212, recon_loss = 0.04284, total_loss = 0.06496 ---- val_forecast_loss = 0.08355, val_recon_loss = 0.04698, val_total_loss = 0.13053 [4.5s]
# [Epoch 432] forecast_loss = 0.02335, recon_loss = 0.04274, total_loss = 0.06608 ---- val_forecast_loss = 0.08451, val_recon_loss = 0.04728, val_total_loss = 0.13179 [4.6s]
# [Epoch 433] forecast_loss = 0.02195, recon_loss = 0.04228, total_loss = 0.06423 ---- val_forecast_loss = 0.08368, val_recon_loss = 0.04738, val_total_loss = 0.13106 [4.6s]
# [Epoch 434] forecast_loss = 0.02288, recon_loss = 0.04244, total_loss = 0.06533 ---- val_forecast_loss = 0.08332, val_recon_loss = 0.04663, val_total_loss = 0.12995 [4.6s]
# [Epoch 435] forecast_loss = 0.02213, recon_loss = 0.04237, total_loss = 0.06450 ---- val_forecast_loss = 0.08387, val_recon_loss = 0.04710, val_total_loss = 0.13097 [4.7s]
# [Epoch 436] forecast_loss = 0.02263, recon_loss = 0.04235, total_loss = 0.06498 ---- val_forecast_loss = 0.08470, val_recon_loss = 0.04727, val_total_loss = 0.13197 [4.6s]
# [Epoch 437] forecast_loss = 0.02199, recon_loss = 0.04249, total_loss = 0.06448 ---- val_forecast_loss = 0.08431, val_recon_loss = 0.04696, val_total_loss = 0.13126 [4.6s]
# [Epoch 438] forecast_loss = 0.02224, recon_loss = 0.04210, total_loss = 0.06434 ---- val_forecast_loss = 0.08503, val_recon_loss = 0.04670, val_total_loss = 0.13173 [4.6s]
# [Epoch 439] forecast_loss = 0.02236, recon_loss = 0.04246, total_loss = 0.06483 ---- val_forecast_loss = 0.08546, val_recon_loss = 0.04803, val_total_loss = 0.13349 [4.6s]
# [Epoch 440] forecast_loss = 0.02553, recon_loss = 0.04802, total_loss = 0.07355 ---- val_forecast_loss = 0.08410, val_recon_loss = 0.04867, val_total_loss = 0.13277 [4.6s]
# [Epoch 441] forecast_loss = 0.02294, recon_loss = 0.04354, total_loss = 0.06648 ---- val_forecast_loss = 0.08410, val_recon_loss = 0.04677, val_total_loss = 0.13087 [4.6s]
# [Epoch 442] forecast_loss = 0.02213, recon_loss = 0.04223, total_loss = 0.06435 ---- val_forecast_loss = 0.08486, val_recon_loss = 0.04680, val_total_loss = 0.13166 [4.6s]
# [Epoch 443] forecast_loss = 0.02183, recon_loss = 0.04204, total_loss = 0.06387 ---- val_forecast_loss = 0.08435, val_recon_loss = 0.04661, val_total_loss = 0.13095 [4.6s]
# [Epoch 444] forecast_loss = 0.02328, recon_loss = 0.04217, total_loss = 0.06544 ---- val_forecast_loss = 0.08431, val_recon_loss = 0.04668, val_total_loss = 0.13099 [4.6s]
# [Epoch 445] forecast_loss = 0.02204, recon_loss = 0.04199, total_loss = 0.06403 ---- val_forecast_loss = 0.08427, val_recon_loss = 0.04660, val_total_loss = 0.13087 [4.6s]
# [Epoch 446] forecast_loss = 0.02174, recon_loss = 0.04176, total_loss = 0.06351 ---- val_forecast_loss = 0.08555, val_recon_loss = 0.04668, val_total_loss = 0.13222 [4.6s]
# [Epoch 447] forecast_loss = 0.02318, recon_loss = 0.04207, total_loss = 0.06525 ---- val_forecast_loss = 0.08434, val_recon_loss = 0.04714, val_total_loss = 0.13148 [4.6s]
# [Epoch 448] forecast_loss = 0.02186, recon_loss = 0.04205, total_loss = 0.06391 ---- val_forecast_loss = 0.08500, val_recon_loss = 0.04733, val_total_loss = 0.13233 [4.6s]
# [Epoch 449] forecast_loss = 0.02260, recon_loss = 0.04226, total_loss = 0.06486 ---- val_forecast_loss = 0.08456, val_recon_loss = 0.04664, val_total_loss = 0.13120 [4.6s]
# [Epoch 450] forecast_loss = 0.02274, recon_loss = 0.04211, total_loss = 0.06486 ---- val_forecast_loss = 0.08444, val_recon_loss = 0.04691, val_total_loss = 0.13135 [4.6s]
# [Epoch 451] forecast_loss = 0.02265, recon_loss = 0.04190, total_loss = 0.06456 ---- val_forecast_loss = 0.08334, val_recon_loss = 0.04604, val_total_loss = 0.12938 [4.6s]
# [Epoch 452] forecast_loss = 0.02198, recon_loss = 0.04174, total_loss = 0.06372 ---- val_forecast_loss = 0.08339, val_recon_loss = 0.04592, val_total_loss = 0.12932 [4.6s]
# [Epoch 453] forecast_loss = 0.02290, recon_loss = 0.04184, total_loss = 0.06474 ---- val_forecast_loss = 0.08413, val_recon_loss = 0.04641, val_total_loss = 0.13054 [4.6s]
# [Epoch 454] forecast_loss = 0.02227, recon_loss = 0.04184, total_loss = 0.06411 ---- val_forecast_loss = 0.08462, val_recon_loss = 0.04806, val_total_loss = 0.13268 [4.6s]
# [Epoch 455] forecast_loss = 0.02226, recon_loss = 0.04173, total_loss = 0.06399 ---- val_forecast_loss = 0.08490, val_recon_loss = 0.04622, val_total_loss = 0.13113 [4.6s]
# [Epoch 456] forecast_loss = 0.02261, recon_loss = 0.04186, total_loss = 0.06447 ---- val_forecast_loss = 0.08409, val_recon_loss = 0.04662, val_total_loss = 0.13071 [4.6s]
# [Epoch 457] forecast_loss = 0.02222, recon_loss = 0.04171, total_loss = 0.06393 ---- val_forecast_loss = 0.08384, val_recon_loss = 0.04714, val_total_loss = 0.13098 [4.6s]
# [Epoch 458] forecast_loss = 0.02190, recon_loss = 0.04170, total_loss = 0.06361 ---- val_forecast_loss = 0.08423, val_recon_loss = 0.04591, val_total_loss = 0.13014 [4.6s]
# [Epoch 459] forecast_loss = 0.02229, recon_loss = 0.04163, total_loss = 0.06392 ---- val_forecast_loss = 0.08499, val_recon_loss = 0.04622, val_total_loss = 0.13122 [4.6s]
# [Epoch 460] forecast_loss = 0.02294, recon_loss = 0.04155, total_loss = 0.06449 ---- val_forecast_loss = 0.08451, val_recon_loss = 0.04612, val_total_loss = 0.13063 [4.6s]
# [Epoch 461] forecast_loss = 0.02251, recon_loss = 0.04165, total_loss = 0.06416 ---- val_forecast_loss = 0.08492, val_recon_loss = 0.04735, val_total_loss = 0.13227 [4.6s]
# [Epoch 462] forecast_loss = 0.02116, recon_loss = 0.04136, total_loss = 0.06252 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.04611, val_total_loss = 0.12983 [4.6s]
# [Epoch 463] forecast_loss = 0.02198, recon_loss = 0.04139, total_loss = 0.06337 ---- val_forecast_loss = 0.08474, val_recon_loss = 0.04665, val_total_loss = 0.13139 [4.6s]
# [Epoch 464] forecast_loss = 0.02239, recon_loss = 0.04133, total_loss = 0.06371 ---- val_forecast_loss = 0.08432, val_recon_loss = 0.04615, val_total_loss = 0.13047 [4.6s]
# [Epoch 465] forecast_loss = 0.02300, recon_loss = 0.04172, total_loss = 0.06471 ---- val_forecast_loss = 0.08407, val_recon_loss = 0.04601, val_total_loss = 0.13008 [4.6s]
# [Epoch 466] forecast_loss = 0.02296, recon_loss = 0.04141, total_loss = 0.06437 ---- val_forecast_loss = 0.08529, val_recon_loss = 0.04669, val_total_loss = 0.13199 [4.6s]
# [Epoch 467] forecast_loss = 0.02192, recon_loss = 0.04123, total_loss = 0.06315 ---- val_forecast_loss = 0.08400, val_recon_loss = 0.04602, val_total_loss = 0.13001 [4.6s]
# [Epoch 468] forecast_loss = 0.02220, recon_loss = 0.04139, total_loss = 0.06359 ---- val_forecast_loss = 0.08496, val_recon_loss = 0.04650, val_total_loss = 0.13146 [4.5s]
# [Epoch 469] forecast_loss = 0.02210, recon_loss = 0.04126, total_loss = 0.06336 ---- val_forecast_loss = 0.08363, val_recon_loss = 0.04605, val_total_loss = 0.12968 [4.6s]
# [Epoch 470] forecast_loss = 0.02193, recon_loss = 0.04123, total_loss = 0.06317 ---- val_forecast_loss = 0.08497, val_recon_loss = 0.04629, val_total_loss = 0.13126 [4.5s]
# [Epoch 471] forecast_loss = 0.02218, recon_loss = 0.04118, total_loss = 0.06336 ---- val_forecast_loss = 0.08383, val_recon_loss = 0.04573, val_total_loss = 0.12956 [4.6s]
# [Epoch 472] forecast_loss = 0.02190, recon_loss = 0.04114, total_loss = 0.06304 ---- val_forecast_loss = 0.08361, val_recon_loss = 0.04565, val_total_loss = 0.12927 [4.6s]
# [Epoch 473] forecast_loss = 0.02237, recon_loss = 0.04091, total_loss = 0.06328 ---- val_forecast_loss = 0.08368, val_recon_loss = 0.04557, val_total_loss = 0.12924 [4.6s]
# [Epoch 474] forecast_loss = 0.02244, recon_loss = 0.04101, total_loss = 0.06345 ---- val_forecast_loss = 0.08404, val_recon_loss = 0.04549, val_total_loss = 0.12954 [4.6s]
# [Epoch 475] forecast_loss = 0.02276, recon_loss = 0.04116, total_loss = 0.06392 ---- val_forecast_loss = 0.08457, val_recon_loss = 0.04595, val_total_loss = 0.13051 [4.6s]
# [Epoch 476] forecast_loss = 0.02245, recon_loss = 0.04123, total_loss = 0.06367 ---- val_forecast_loss = 0.08354, val_recon_loss = 0.04573, val_total_loss = 0.12927 [4.5s]
# [Epoch 477] forecast_loss = 0.02220, recon_loss = 0.04084, total_loss = 0.06304 ---- val_forecast_loss = 0.08365, val_recon_loss = 0.04588, val_total_loss = 0.12953 [4.6s]
# [Epoch 478] forecast_loss = 0.02233, recon_loss = 0.04087, total_loss = 0.06320 ---- val_forecast_loss = 0.08387, val_recon_loss = 0.04566, val_total_loss = 0.12953 [4.6s]
# [Epoch 479] forecast_loss = 0.02211, recon_loss = 0.04087, total_loss = 0.06298 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.04530, val_total_loss = 0.12901 [4.6s]
# [Epoch 480] forecast_loss = 0.02255, recon_loss = 0.04089, total_loss = 0.06344 ---- val_forecast_loss = 0.08400, val_recon_loss = 0.04559, val_total_loss = 0.12960 [4.6s]
# [Epoch 481] forecast_loss = 0.02213, recon_loss = 0.04098, total_loss = 0.06311 ---- val_forecast_loss = 0.08359, val_recon_loss = 0.04533, val_total_loss = 0.12892 [4.6s]
# [Epoch 482] forecast_loss = 0.02225, recon_loss = 0.04091, total_loss = 0.06316 ---- val_forecast_loss = 0.08399, val_recon_loss = 0.04557, val_total_loss = 0.12956 [4.6s]
# [Epoch 483] forecast_loss = 0.02370, recon_loss = 0.04147, total_loss = 0.06517 ---- val_forecast_loss = 0.08387, val_recon_loss = 0.04548, val_total_loss = 0.12935 [4.5s]
# [Epoch 484] forecast_loss = 0.02232, recon_loss = 0.04066, total_loss = 0.06298 ---- val_forecast_loss = 0.08349, val_recon_loss = 0.04503, val_total_loss = 0.12852 [4.6s]
# [Epoch 485] forecast_loss = 0.02139, recon_loss = 0.04068, total_loss = 0.06207 ---- val_forecast_loss = 0.08327, val_recon_loss = 0.04516, val_total_loss = 0.12842 [4.6s]
# [Epoch 486] forecast_loss = 0.02202, recon_loss = 0.04069, total_loss = 0.06270 ---- val_forecast_loss = 0.08474, val_recon_loss = 0.04557, val_total_loss = 0.13032 [4.6s]
# [Epoch 487] forecast_loss = 0.02218, recon_loss = 0.04064, total_loss = 0.06282 ---- val_forecast_loss = 0.08375, val_recon_loss = 0.04509, val_total_loss = 0.12884 [4.6s]
# [Epoch 488] forecast_loss = 0.02171, recon_loss = 0.04066, total_loss = 0.06237 ---- val_forecast_loss = 0.08406, val_recon_loss = 0.04544, val_total_loss = 0.12950 [5.3s]
# [Epoch 489] forecast_loss = 0.02140, recon_loss = 0.04050, total_loss = 0.06189 ---- val_forecast_loss = 0.08259, val_recon_loss = 0.04532, val_total_loss = 0.12791 [4.6s]
# [Epoch 490] forecast_loss = 0.02175, recon_loss = 0.04053, total_loss = 0.06229 ---- val_forecast_loss = 0.08346, val_recon_loss = 0.04542, val_total_loss = 0.12887 [4.6s]
# [Epoch 491] forecast_loss = 0.02227, recon_loss = 0.04055, total_loss = 0.06282 ---- val_forecast_loss = 0.08350, val_recon_loss = 0.04533, val_total_loss = 0.12883 [4.6s]
# [Epoch 492] forecast_loss = 0.02141, recon_loss = 0.04058, total_loss = 0.06199 ---- val_forecast_loss = 0.08410, val_recon_loss = 0.04600, val_total_loss = 0.13010 [4.6s]
# [Epoch 493] forecast_loss = 0.02240, recon_loss = 0.04062, total_loss = 0.06302 ---- val_forecast_loss = 0.08510, val_recon_loss = 0.04573, val_total_loss = 0.13083 [4.6s]
# [Epoch 494] forecast_loss = 0.02195, recon_loss = 0.04045, total_loss = 0.06240 ---- val_forecast_loss = 0.08358, val_recon_loss = 0.04502, val_total_loss = 0.12860 [4.5s]
# [Epoch 495] forecast_loss = 0.02189, recon_loss = 0.04025, total_loss = 0.06214 ---- val_forecast_loss = 0.08412, val_recon_loss = 0.04516, val_total_loss = 0.12927 [4.6s]
# [Epoch 496] forecast_loss = 0.02162, recon_loss = 0.04043, total_loss = 0.06205 ---- val_forecast_loss = 0.08404, val_recon_loss = 0.04504, val_total_loss = 0.12908 [4.5s]
# [Epoch 497] forecast_loss = 0.02143, recon_loss = 0.04033, total_loss = 0.06177 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.04528, val_total_loss = 0.12948 [4.5s]
# [Epoch 498] forecast_loss = 0.02118, recon_loss = 0.04027, total_loss = 0.06145 ---- val_forecast_loss = 0.08398, val_recon_loss = 0.04484, val_total_loss = 0.12881 [4.6s]
# [Epoch 499] forecast_loss = 0.02185, recon_loss = 0.04049, total_loss = 0.06235 ---- val_forecast_loss = 0.08389, val_recon_loss = 0.04555, val_total_loss = 0.12944 [4.5s]
# [Epoch 500] forecast_loss = 0.02232, recon_loss = 0.04039, total_loss = 0.06271 ---- val_forecast_loss = 0.08401, val_recon_loss = 0.04495, val_total_loss = 0.12896 [4.6s]
# -- Training done in 2297s.
