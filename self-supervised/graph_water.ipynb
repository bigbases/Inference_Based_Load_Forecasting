# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/Capstone')

import pandas as pd
import numpy as np

import json
from datetime import datetime
import torch.nn as nn

from mtad_gat import MTAD_GAT
from utils import *

import os
import time
import numpy as np
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class CustomDataset(Dataset):
    def __init__(self, data, target):
        self.data = data
        self.target = target

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index], self.target[index]

class Trainer:
    """Trainer class for MTAD-GAT model.

    :param model: MTAD-GAT model
    :param optimizer: Optimizer used to minimize the loss function
    :param window_size: Length of the input sequence
    :param n_features: Number of input features
    :param target_dims: dimension of input features to forecast and reconstruct
    :param n_epochs: Number of iterations/epochs
    :param batch_size: Number of windows in a single batch
    :param init_lr: Initial learning rate of the module
    :param forecast_criterion: Loss to be used for forecasting.
    :param recon_criterion: Loss to be used for reconstruction.
    :param boolean use_cuda: To be run on GPU or not
    :param dload: Download directory where models are to be dumped
    :param log_dir: Directory where SummaryWriter logs are written to
    :param print_every: At what epoch interval to print losses
    :param log_tensorboard: Whether to log loss++ to tensorboard
    :param args_summary: Summary of args that will also be written to tensorboard if log_tensorboard
    """

    def __init__(
        self,
        model,
        optimizer,
        window_size,
        n_features,
        target_dims=None,
        n_epochs=200,
        batch_size=32,
        init_lr=0.001,
        forecast_criterion=nn.MSELoss(),
        recon_criterion=nn.MSELoss(),
        use_cuda=True,
        dload="",
        log_dir="output/",
        print_every=1,
        log_tensorboard=True,
        args_summary="",
    ):

        self.model = model
        self.optimizer = optimizer
        self.window_size = window_size
        self.n_features = n_features
        self.target_dims = target_dims
        self.n_epochs = n_epochs
        self.batch_size = batch_size
        self.init_lr = init_lr
        self.forecast_criterion = forecast_criterion
        self.recon_criterion = recon_criterion
        self.device = "cuda" if use_cuda and torch.cuda.is_available() else "cpu"
        self.dload = dload
        self.log_dir = log_dir
        self.print_every = print_every
        self.log_tensorboard = log_tensorboard

        self.losses = {
            "train_total": [],
            "train_forecast": [],
            "train_recon": [],
            "val_total": [],
            "val_forecast": [],
            "val_recon": [],
        }
        self.epoch_times = []

        if self.device == "cuda":
            self.model.cuda()

        if self.log_tensorboard:
            self.writer = SummaryWriter(f"{log_dir}")
            self.writer.add_text("args_summary", args_summary)

    def fit(self, train_loader, val_loader=None):
        """Train model for self.n_epochs.
        Train and validation (if validation loader given) losses stored in self.losses

        :param train_loader: train loader of input data
        :param val_loader: validation loader of input data
        """

        init_train_loss = self.evaluate(train_loader)
        print(f"Init total train loss: {init_train_loss[2]:5f}")

        if val_loader is not None:
            init_val_loss = self.evaluate(val_loader)
            print(f"Init total val loss: {init_val_loss[2]:.5f}")

        print(f"Training model for {self.n_epochs} epochs..")
        train_start = time.time()
        for epoch in range(self.n_epochs):
            epoch_start = time.time()
            self.model.train()
            forecast_b_losses = []
            recon_b_losses = []

            for x, y in train_loader:
                x = x.to(self.device).float() # 32,56,1080?????
                y = y.to(self.device).float()
                self.optimizer.zero_grad()

                preds, recons, _, _ = self.model(x)
                # print('pp')
                if self.target_dims is not None:
                    x = x[:, :, self.target_dims]
                    y = y[:, :, self.target_dims].squeeze(-1)

                if preds.ndim == 3:
                    preds = preds.squeeze(1)
                if y.ndim == 3:
                    y = y.squeeze(1)

                forecast_loss = torch.sqrt(self.forecast_criterion(y, preds))
                recon_loss = torch.sqrt(self.recon_criterion(x, recons))
                loss = forecast_loss + recon_loss

                loss.backward()
                self.optimizer.step()

                forecast_b_losses.append(forecast_loss.item())
                recon_b_losses.append(recon_loss.item())

            forecast_b_losses = np.array(forecast_b_losses)
            recon_b_losses = np.array(recon_b_losses)

            forecast_epoch_loss = np.sqrt((forecast_b_losses ** 2).mean())
            recon_epoch_loss = np.sqrt((recon_b_losses ** 2).mean())

            total_epoch_loss = forecast_epoch_loss + recon_epoch_loss

            self.losses["train_forecast"].append(forecast_epoch_loss)
            self.losses["train_recon"].append(recon_epoch_loss)
            self.losses["train_total"].append(total_epoch_loss)

            # Evaluate on validation set
            forecast_val_loss, recon_val_loss, total_val_loss = "NA", "NA", "NA"
            if val_loader is not None:
                forecast_val_loss, recon_val_loss, total_val_loss = self.evaluate(val_loader)
                self.losses["val_forecast"].append(forecast_val_loss)
                self.losses["val_recon"].append(recon_val_loss)
                self.losses["val_total"].append(total_val_loss)

                if total_val_loss <= self.losses["val_total"][-1]:
                    self.save(f"model.pt")

            if self.log_tensorboard:
                self.write_loss(epoch)

            epoch_time = time.time() - epoch_start
            self.epoch_times.append(epoch_time)

            if epoch % self.print_every == 0:
                s = (
                    f"[Epoch {epoch + 1}] "
                    f"forecast_loss = {forecast_epoch_loss:.5f}, "
                    f"recon_loss = {recon_epoch_loss:.5f}, "
                    f"total_loss = {total_epoch_loss:.5f}"
                )

                if val_loader is not None:
                    s += (
                        f" ---- val_forecast_loss = {forecast_val_loss:.5f}, "
                        f"val_recon_loss = {recon_val_loss:.5f}, "
                        f"val_total_loss = {total_val_loss:.5f}"
                    )

                s += f" [{epoch_time:.1f}s]"
                print(s)

        if val_loader is None:
            self.save(f"model.pt")

        train_time = int(time.time() - train_start)
        if self.log_tensorboard:
            self.writer.add_text("total_train_time", str(train_time))
        print(f"-- Training done in {train_time}s.")

    def evaluate(self, data_loader):
        """Evaluate model

        :param data_loader: data loader of input data
        :return forecasting loss, reconstruction loss, total loss
        """

        self.model.eval()

        forecast_losses = []
        recon_losses = []

        with torch.no_grad():
            for x, y in data_loader:
                x = x.to(self.device)
                y = y.to(self.device)
                x = x.to(self.device).float() # 32,56,1080?????
                y = y.to(self.device).float()

                preds, recons, _, _ = self.model(x)

                if self.target_dims is not None:
                    x = x[:, :, self.target_dims]
                    y = y[:, :, self.target_dims].squeeze(-1)

                if preds.ndim == 3:
                    preds = preds.squeeze(1)
                if y.ndim == 3:
                    y = y.squeeze(1)
                # print('aa')
#                 print(y.shape, preds.shape)
#                 print(y.shape) # 32,1
#                 print(preds.shape) # 32,1
#                 print(recons.shape) # 32,28,3
                forecast_loss = torch.sqrt(self.forecast_criterion(y, preds))
                recon_loss = torch.sqrt(self.recon_criterion(x, recons))

                forecast_losses.append(forecast_loss.item())
                recon_losses.append(recon_loss.item())

        forecast_losses = np.array(forecast_losses)
        recon_losses = np.array(recon_losses)

        forecast_loss = np.sqrt((forecast_losses ** 2).mean())
        recon_loss = np.sqrt((recon_losses ** 2).mean())

        total_loss = forecast_loss + recon_loss

        return forecast_loss, recon_loss, total_loss

    def save(self, file_name):
        """
        Pickles the model parameters to be retrieved later
        :param file_name: the filename to be saved as,`dload` serves as the download directory
        """
        PATH = self.dload + "/" + file_name
        if os.path.exists(self.dload):
            pass
        else:
            os.mkdir(self.dload)
        torch.save(self.model.state_dict(), PATH)

    def load(self, PATH):
        """
        Loads the model's parameters from the path mentioned
        :param PATH: Should contain pickle file
        """
        self.model.load_state_dict(torch.load(PATH, map_location=self.device))

    def write_loss(self, epoch):
        for key, value in self.losses.items():
            if len(value) != 0:
                self.writer.add_scalar(key, value[-1], epoch)

# %%
# dataset load
# 전기
elec_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/elec_clustering_train.csv', index_col=0)
elec_train.index = pd.to_datetime(elec_train.index)
elec_train = elec_train.resample(rule='12H').sum()
elec_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/elec_clustering_test.csv', index_col=0)
elec_test.index = pd.to_datetime(elec_test.index)
elec_test = elec_test.resample(rule='12H').sum()
elec_total = pd.concat([elec_train,elec_test],axis=1)
# 수도
water_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/water_clustering_train.csv', index_col=0)
water_train.index = pd.to_datetime(water_train.index)
water_train = water_train.resample(rule='12H').sum()
water_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/water_clustering_test.csv', index_col=0)
water_test.index = pd.to_datetime(water_test.index)
water_test = water_test.resample(rule='12H').sum()
water_total = pd.concat([water_train,water_test],axis=1)
#가스
gas_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/gas_clustering_train.csv', index_col=0)
gas_train.index = pd.to_datetime(gas_train.index)
gas_train = gas_train.resample(rule='12H').sum()
gas_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/gas_clustering_test.csv', index_col=0)
gas_test.index = pd.to_datetime(gas_test.index)
gas_test = gas_test.resample(rule='12H').sum()
gas_total = pd.concat([gas_train,gas_test],axis=1)
#온수
hotwater_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/hotwater_clustering_train.csv', index_col=0)
hotwater_train.index = pd.to_datetime(hotwater_train.index)
hotwater_train = hotwater_train.resample(rule='12H').sum()
hotwater_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/hotwater_clustering_test.csv', index_col=0)
hotwater_test.index = pd.to_datetime(hotwater_test.index)
hotwater_test = hotwater_test.resample(rule='12H').sum()
hotwater_total = pd.concat([hotwater_train,hotwater_test],axis=1)

# %%
region_A = elec_train.columns
region_B = elec_test.columns

train_index = 504*2
test_index = (504+28)*2
cluster_index = (504+28+28)*2

energy_A = elec_total.reset_index(drop=True)
energy_B = gas_total.reset_index(drop=True)
energy_C = hotwater_total.reset_index(drop=True)
energy_target = water_total.reset_index(drop=True)

train_A = energy_A[:train_index]
train_B = energy_B[:train_index]
train_C = energy_C[:train_index]
train_target = energy_target[:train_index+1]
test_A = energy_A[train_index:test_index+1]
test_B = energy_B[train_index:test_index+1]
test_C = energy_C[train_index:test_index+1]
test_target = energy_target[train_index:test_index+1]
cluster_A = energy_A[test_index:cluster_index+1]
cluster_B = energy_B[test_index:cluster_index+1]
cluster_C = energy_C[test_index:cluster_index+1]
cluster_target = energy_target[test_index:cluster_index+1]

scaler_A = MinMaxScaler()
scaler_B = MinMaxScaler()
scaler_C = MinMaxScaler()
scaler_target = MinMaxScaler()
train_A = pd.DataFrame(scaler_A.fit_transform(train_A))
train_B = pd.DataFrame(scaler_B.fit_transform(train_B))
train_C = pd.DataFrame(scaler_C.fit_transform(train_C))
train_target = pd.DataFrame(scaler_target.fit_transform(train_target))
test_A = pd.DataFrame(scaler_A.transform(test_A))
test_B = pd.DataFrame(scaler_B.transform(test_B))
test_C = pd.DataFrame(scaler_C.transform(test_C))
test_target = pd.DataFrame(scaler_target.transform(test_target))
cluster_A = pd.DataFrame(scaler_A.transform(cluster_A))
cluster_B = pd.DataFrame(scaler_B.transform(cluster_B))
cluster_C = pd.DataFrame(scaler_C.transform(cluster_C))
cluster_target = pd.DataFrame(scaler_target.transform(cluster_target))

# 2-5 표현 생성
idx = 14
repr1_A = energy_A[train_index+idx:test_index+1+idx]
repr1_B = energy_B[train_index+idx:test_index+1+idx]
repr1_C = energy_C[train_index+idx:test_index+1+idx]
repr1_target = energy_target[train_index+idx:test_index+1+idx]

repr1_A = pd.DataFrame(scaler_A.transform(repr1_A))
repr1_B = pd.DataFrame(scaler_B.transform(repr1_B))
repr1_C = pd.DataFrame(scaler_C.transform(repr1_C))
repr1_target = pd.DataFrame(scaler_target.transform(repr1_target))

X_repr1 = []
y_repr1 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr1_A.iloc[period,user],repr1_B.iloc[period,user],repr1_C.iloc[period,user]])
        y_window.append(repr1_A.iloc[period+1,user])
        X_repr1.append(X_window)
        y_repr1.append(y_window)

# 3-6 표현 생성
repr2_A = energy_A[train_index+idx*2:test_index+1+idx*2]
repr2_B = energy_B[train_index+idx*2:test_index+1+idx*2]
repr2_C = energy_C[train_index+idx*2:test_index+1+idx*2]
repr2_target = energy_target[train_index+idx*2:test_index+1+idx*2]

repr2_A = pd.DataFrame(scaler_A.transform(repr2_A))
repr2_B = pd.DataFrame(scaler_B.transform(repr2_B))
repr2_C = pd.DataFrame(scaler_C.transform(repr2_C))
repr2_target = pd.DataFrame(scaler_target.transform(repr2_target))

X_repr2 = []
y_repr2 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr2_A.iloc[period,user],repr2_B.iloc[period,user],repr2_C.iloc[period,user]])
        y_window.append(repr2_A.iloc[period+1,user])
        X_repr2.append(X_window)
        y_repr2.append(y_window)

# 4-7 표현 생성
repr3_A = energy_A[train_index+idx*3:test_index+1+idx*3]
repr3_B = energy_B[train_index+idx*3:test_index+1+idx*3]
repr3_C = energy_C[train_index+idx*3:test_index+1+idx*3]
repr3_target = energy_target[train_index+idx*3:test_index+1+idx*3]

repr3_A = pd.DataFrame(scaler_A.transform(repr3_A))
repr3_B = pd.DataFrame(scaler_B.transform(repr3_B))
repr3_C = pd.DataFrame(scaler_C.transform(repr3_C))
repr3_target = pd.DataFrame(scaler_target.transform(repr3_target))

X_repr3 = []
y_repr3 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr3_A.iloc[period,user],repr3_B.iloc[period,user],repr3_C.iloc[period,user]])
        y_window.append(repr3_A.iloc[period+1,user])
        X_repr3.append(X_window)
        y_repr3.append(y_window)

X_train = []
y_train = []
for user in range(elec_total.shape[1]):
    for index in range(0,elec_total.shape[0]//(28*2)-3):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([train_A.iloc[period,user],train_B.iloc[period,user],train_C.iloc[period,user]])
        y_window.append(train_A.iloc[period+1,user])
        X_train.append(X_window)
        y_train.append(y_window)

X_test = []
y_test = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([test_A.iloc[period,user],test_B.iloc[period,user],test_C.iloc[period,user]])
        y_window.append(test_A.iloc[period+1,user])
        X_test.append(X_window)
        y_test.append(y_window)

X_cluster = []
y_cluster = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([cluster_A.iloc[period,user],cluster_B.iloc[period,user],cluster_C.iloc[period,user]])
        y_window.append(cluster_A.iloc[period+1,user])
        X_cluster.append(X_window)
        y_cluster.append(y_window)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
X_cluster = np.array(X_cluster)
y_cluster = np.array(y_cluster)

X_repr1 = np.array(X_repr1)
y_repr1 = np.array(y_repr1)
X_repr2 = np.array(X_repr2)
y_repr2 = np.array(y_repr2)
X_repr3 = np.array(X_repr3)
y_repr3 = np.array(y_repr3)

train_ds = CustomDataset(X_train, y_train)
valid_ds = CustomDataset(X_test, y_test) # 이게 test set

train_loader, val_loader, test_loader = create_data_loaders(
        train_ds, batch_size=32, val_split=0.2, shuffle=False, test_dataset=valid_ds
    )

id = datetime.now().strftime("%d%m%Y_%H%M%S")
# Out:
# train_size: 14688
# validation_size: 3672
# test_size: 1080

# %%
window_size = 28*2
n_epochs = 500 #30
batch_size = 32
init_lr = 1e-3
print_every = 1
log_tensorboard = True

n_features=X_train.shape[2]
window_size=window_size
out_dim=X_train.shape[2]
kernel_size=3
use_gatv2=True
feat_gat_embed_dim=None
time_gat_embed_dim=None
gru_n_layers=1
gru_hid_dim=256
forecast_n_layers=2
forecast_hid_dim=512
recon_n_layers=2
recon_hid_dim=128
dropout=0.2
alpha=0.2

num = 0
model = MTAD_GAT(
    n_features=n_features,
    window_size=window_size,
    out_dim=out_dim,
    kernel_size=kernel_size,
    use_gatv2=True,
    feat_gat_embed_dim=None,
    time_gat_embed_dim=None,
    gru_n_layers=gru_n_layers,
    gru_hid_dim=gru_hid_dim,
    forecast_n_layers=forecast_n_layers,
    forecast_hid_dim=forecast_hid_dim,
    recon_n_layers=recon_n_layers,
    recon_hid_dim=recon_hid_dim,
    dropout=0.2,
    alpha=0.2
)

optimizer = torch.optim.Adam(model.parameters(), lr=init_lr)
forecast_criterion = nn.MSELoss()
recon_criterion = nn.MSELoss()

trainer = Trainer(
    model=model,
    optimizer=optimizer,
    window_size=window_size,
    n_features=n_features,
    n_epochs=n_epochs,
    batch_size=batch_size,
    init_lr=init_lr,
    forecast_criterion=forecast_criterion,
    recon_criterion=recon_criterion,
    use_cuda=True,
    print_every=1,
    log_dir="/logs",
    dload="/result"
)

trainer.fit(train_loader, val_loader)

# hidden representations생성
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
forecast_criterion=nn.MSELoss()
recon_criterion=nn.MSELoss()

repr1_ds = CustomDataset(X_repr1, y_repr1) # 이게 repr1 set
repr1set_loader = torch.utils.data.DataLoader(repr1_ds, batch_size=32)

repr2_ds = CustomDataset(X_repr2, y_repr2) # 이게 repr2 set
repr2set_loader = torch.utils.data.DataLoader(repr2_ds, batch_size=32)

repr3_ds = CustomDataset(X_repr3, y_repr3) # 이게 repr3 set
repr3set_loader = torch.utils.data.DataLoader(repr3_ds, batch_size=32)

for idx, loader in enumerate([repr1set_loader, repr2set_loader, repr3set_loader]):

    hidden_test = []
    h_r_test = []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device).float()
            y = y.to(device).float()

            preds, recons, h, h_r = model(x)

            if preds.ndim == 3:
                preds = preds.squeeze(1)
            if y.ndim == 3:
                y = y.squeeze(1)

            hidden_test.append(h.cpu())
            h_r_test.append(h_r.cpu())

    hidden_test_ = [np.array(i.cpu().squeeze()) for j in hidden_test for i in j]
    hidden_test_ = np.array(hidden_test_)
    hidden_test_ = pd.DataFrame(hidden_test_, index = elec_total.columns)
    h_r_test_ = [np.array(i.cpu().squeeze()) for j in h_r_test for i in j]
    h_r_test_ = np.array(h_r_test_).reshape(1080,-1)
    h_r_test_ = pd.DataFrame(h_r_test_, index = elec_total.columns)
    hidden_test_.to_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/result/graph_water/arr_hidden_{}_{}.csv'.format(idx, num))
    h_r_test_.to_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/result/graph_water/h_r_{}_{}.csv'.format(idx, num))
# Out:
# Init total train loss: 0.425351
# Init total val loss: 0.42115
# Training model for 500 epochs..
# [Epoch 1] forecast_loss = 0.10600, recon_loss = 0.14983, total_loss = 0.25583 ---- val_forecast_loss = 0.08999, val_recon_loss = 0.13746, val_total_loss = 0.22745 [6.2s]
# [Epoch 2] forecast_loss = 0.08546, recon_loss = 0.13190, total_loss = 0.21736 ---- val_forecast_loss = 0.08364, val_recon_loss = 0.12927, val_total_loss = 0.21291 [4.9s]
# [Epoch 3] forecast_loss = 0.08166, recon_loss = 0.12714, total_loss = 0.20880 ---- val_forecast_loss = 0.08131, val_recon_loss = 0.12412, val_total_loss = 0.20543 [4.7s]
# [Epoch 4] forecast_loss = 0.08054, recon_loss = 0.12361, total_loss = 0.20415 ---- val_forecast_loss = 0.08082, val_recon_loss = 0.12186, val_total_loss = 0.20269 [4.8s]
# [Epoch 5] forecast_loss = 0.07960, recon_loss = 0.12100, total_loss = 0.20060 ---- val_forecast_loss = 0.07883, val_recon_loss = 0.11858, val_total_loss = 0.19741 [4.7s]
# [Epoch 6] forecast_loss = 0.07899, recon_loss = 0.11928, total_loss = 0.19827 ---- val_forecast_loss = 0.07914, val_recon_loss = 0.11765, val_total_loss = 0.19679 [4.8s]
# [Epoch 7] forecast_loss = 0.07893, recon_loss = 0.11831, total_loss = 0.19724 ---- val_forecast_loss = 0.07926, val_recon_loss = 0.11740, val_total_loss = 0.19666 [4.7s]
# [Epoch 8] forecast_loss = 0.07811, recon_loss = 0.11656, total_loss = 0.19467 ---- val_forecast_loss = 0.07745, val_recon_loss = 0.11489, val_total_loss = 0.19234 [4.6s]
# [Epoch 9] forecast_loss = 0.07816, recon_loss = 0.11562, total_loss = 0.19378 ---- val_forecast_loss = 0.07952, val_recon_loss = 0.11359, val_total_loss = 0.19311 [4.8s]
# [Epoch 10] forecast_loss = 0.07724, recon_loss = 0.11457, total_loss = 0.19181 ---- val_forecast_loss = 0.08018, val_recon_loss = 0.11289, val_total_loss = 0.19307 [4.7s]
# [Epoch 11] forecast_loss = 0.07740, recon_loss = 0.11348, total_loss = 0.19088 ---- val_forecast_loss = 0.07907, val_recon_loss = 0.11295, val_total_loss = 0.19202 [4.6s]
# [Epoch 12] forecast_loss = 0.07685, recon_loss = 0.11208, total_loss = 0.18893 ---- val_forecast_loss = 0.08123, val_recon_loss = 0.11074, val_total_loss = 0.19197 [4.6s]
# [Epoch 13] forecast_loss = 0.07602, recon_loss = 0.11045, total_loss = 0.18646 ---- val_forecast_loss = 0.07797, val_recon_loss = 0.10898, val_total_loss = 0.18695 [4.8s]
# [Epoch 14] forecast_loss = 0.07543, recon_loss = 0.10896, total_loss = 0.18439 ---- val_forecast_loss = 0.07951, val_recon_loss = 0.10630, val_total_loss = 0.18581 [4.8s]
# [Epoch 15] forecast_loss = 0.07599, recon_loss = 0.10754, total_loss = 0.18353 ---- val_forecast_loss = 0.07968, val_recon_loss = 0.10422, val_total_loss = 0.18391 [4.6s]
# [Epoch 16] forecast_loss = 0.07497, recon_loss = 0.10618, total_loss = 0.18115 ---- val_forecast_loss = 0.07869, val_recon_loss = 0.10291, val_total_loss = 0.18160 [4.7s]
# [Epoch 17] forecast_loss = 0.07416, recon_loss = 0.10399, total_loss = 0.17815 ---- val_forecast_loss = 0.08009, val_recon_loss = 0.10083, val_total_loss = 0.18092 [4.7s]
# [Epoch 18] forecast_loss = 0.07434, recon_loss = 0.10246, total_loss = 0.17680 ---- val_forecast_loss = 0.07828, val_recon_loss = 0.09816, val_total_loss = 0.17644 [4.6s]
# [Epoch 19] forecast_loss = 0.07343, recon_loss = 0.09983, total_loss = 0.17326 ---- val_forecast_loss = 0.07874, val_recon_loss = 0.09719, val_total_loss = 0.17593 [4.7s]
# [Epoch 20] forecast_loss = 0.07229, recon_loss = 0.09744, total_loss = 0.16972 ---- val_forecast_loss = 0.07984, val_recon_loss = 0.09476, val_total_loss = 0.17460 [4.6s]
# [Epoch 21] forecast_loss = 0.07218, recon_loss = 0.09576, total_loss = 0.16795 ---- val_forecast_loss = 0.07971, val_recon_loss = 0.09461, val_total_loss = 0.17433 [4.7s]
# [Epoch 22] forecast_loss = 0.07127, recon_loss = 0.09323, total_loss = 0.16451 ---- val_forecast_loss = 0.07996, val_recon_loss = 0.09260, val_total_loss = 0.17256 [4.8s]
# [Epoch 23] forecast_loss = 0.07014, recon_loss = 0.09141, total_loss = 0.16155 ---- val_forecast_loss = 0.08182, val_recon_loss = 0.08953, val_total_loss = 0.17135 [4.7s]
# [Epoch 24] forecast_loss = 0.06953, recon_loss = 0.08984, total_loss = 0.15937 ---- val_forecast_loss = 0.08082, val_recon_loss = 0.08744, val_total_loss = 0.16825 [4.7s]
# [Epoch 25] forecast_loss = 0.06834, recon_loss = 0.08784, total_loss = 0.15618 ---- val_forecast_loss = 0.08155, val_recon_loss = 0.08835, val_total_loss = 0.16990 [4.6s]
# [Epoch 26] forecast_loss = 0.06763, recon_loss = 0.08617, total_loss = 0.15380 ---- val_forecast_loss = 0.08108, val_recon_loss = 0.08647, val_total_loss = 0.16755 [4.7s]
# [Epoch 27] forecast_loss = 0.06770, recon_loss = 0.08475, total_loss = 0.15246 ---- val_forecast_loss = 0.08003, val_recon_loss = 0.08285, val_total_loss = 0.16288 [4.8s]
# [Epoch 28] forecast_loss = 0.06680, recon_loss = 0.08389, total_loss = 0.15068 ---- val_forecast_loss = 0.08244, val_recon_loss = 0.08291, val_total_loss = 0.16536 [4.7s]
# [Epoch 29] forecast_loss = 0.06543, recon_loss = 0.08183, total_loss = 0.14725 ---- val_forecast_loss = 0.08288, val_recon_loss = 0.07950, val_total_loss = 0.16238 [4.6s]
# [Epoch 30] forecast_loss = 0.06483, recon_loss = 0.08066, total_loss = 0.14549 ---- val_forecast_loss = 0.08077, val_recon_loss = 0.07866, val_total_loss = 0.15944 [4.6s]
# [Epoch 31] forecast_loss = 0.06317, recon_loss = 0.07883, total_loss = 0.14200 ---- val_forecast_loss = 0.08361, val_recon_loss = 0.07809, val_total_loss = 0.16170 [4.9s]
# [Epoch 32] forecast_loss = 0.06380, recon_loss = 0.07824, total_loss = 0.14204 ---- val_forecast_loss = 0.08237, val_recon_loss = 0.07935, val_total_loss = 0.16172 [4.9s]
# [Epoch 33] forecast_loss = 0.06352, recon_loss = 0.07687, total_loss = 0.14039 ---- val_forecast_loss = 0.08122, val_recon_loss = 0.07598, val_total_loss = 0.15720 [4.7s]
# [Epoch 34] forecast_loss = 0.06217, recon_loss = 0.07722, total_loss = 0.13939 ---- val_forecast_loss = 0.08261, val_recon_loss = 0.08716, val_total_loss = 0.16978 [4.7s]
# [Epoch 35] forecast_loss = 0.06091, recon_loss = 0.07575, total_loss = 0.13666 ---- val_forecast_loss = 0.08172, val_recon_loss = 0.07308, val_total_loss = 0.15479 [4.7s]
# [Epoch 36] forecast_loss = 0.06043, recon_loss = 0.07383, total_loss = 0.13426 ---- val_forecast_loss = 0.08053, val_recon_loss = 0.07339, val_total_loss = 0.15392 [4.6s]
# [Epoch 37] forecast_loss = 0.06330, recon_loss = 0.07592, total_loss = 0.13922 ---- val_forecast_loss = 0.08540, val_recon_loss = 0.07438, val_total_loss = 0.15978 [4.7s]
# [Epoch 38] forecast_loss = 0.06178, recon_loss = 0.07183, total_loss = 0.13361 ---- val_forecast_loss = 0.08194, val_recon_loss = 0.07008, val_total_loss = 0.15202 [4.6s]
# [Epoch 39] forecast_loss = 0.05821, recon_loss = 0.06988, total_loss = 0.12809 ---- val_forecast_loss = 0.08229, val_recon_loss = 0.07002, val_total_loss = 0.15230 [4.7s]
# [Epoch 40] forecast_loss = 0.05833, recon_loss = 0.06899, total_loss = 0.12732 ---- val_forecast_loss = 0.08169, val_recon_loss = 0.06862, val_total_loss = 0.15031 [4.7s]
# [Epoch 41] forecast_loss = 0.05726, recon_loss = 0.06782, total_loss = 0.12508 ---- val_forecast_loss = 0.08392, val_recon_loss = 0.06778, val_total_loss = 0.15170 [4.6s]
# [Epoch 42] forecast_loss = 0.05634, recon_loss = 0.06719, total_loss = 0.12352 ---- val_forecast_loss = 0.08741, val_recon_loss = 0.06658, val_total_loss = 0.15398 [4.6s]
# [Epoch 43] forecast_loss = 0.05650, recon_loss = 0.06652, total_loss = 0.12302 ---- val_forecast_loss = 0.08195, val_recon_loss = 0.06722, val_total_loss = 0.14917 [4.7s]
# [Epoch 44] forecast_loss = 0.05582, recon_loss = 0.06554, total_loss = 0.12136 ---- val_forecast_loss = 0.08161, val_recon_loss = 0.06539, val_total_loss = 0.14700 [4.6s]
# [Epoch 45] forecast_loss = 0.05506, recon_loss = 0.06477, total_loss = 0.11984 ---- val_forecast_loss = 0.08114, val_recon_loss = 0.06491, val_total_loss = 0.14605 [4.9s]
# [Epoch 46] forecast_loss = 0.05430, recon_loss = 0.06405, total_loss = 0.11835 ---- val_forecast_loss = 0.08270, val_recon_loss = 0.06389, val_total_loss = 0.14659 [4.6s]
# [Epoch 47] forecast_loss = 0.05370, recon_loss = 0.06383, total_loss = 0.11753 ---- val_forecast_loss = 0.08167, val_recon_loss = 0.06428, val_total_loss = 0.14595 [4.6s]
# [Epoch 48] forecast_loss = 0.05342, recon_loss = 0.06279, total_loss = 0.11621 ---- val_forecast_loss = 0.08200, val_recon_loss = 0.06416, val_total_loss = 0.14617 [4.8s]
# [Epoch 49] forecast_loss = 0.05295, recon_loss = 0.06236, total_loss = 0.11531 ---- val_forecast_loss = 0.08272, val_recon_loss = 0.06320, val_total_loss = 0.14592 [4.6s]
# [Epoch 50] forecast_loss = 0.05241, recon_loss = 0.06162, total_loss = 0.11403 ---- val_forecast_loss = 0.08474, val_recon_loss = 0.06183, val_total_loss = 0.14657 [4.6s]
# [Epoch 51] forecast_loss = 0.05194, recon_loss = 0.06090, total_loss = 0.11283 ---- val_forecast_loss = 0.08382, val_recon_loss = 0.06089, val_total_loss = 0.14471 [4.6s]
# [Epoch 52] forecast_loss = 0.05157, recon_loss = 0.06076, total_loss = 0.11232 ---- val_forecast_loss = 0.08344, val_recon_loss = 0.06322, val_total_loss = 0.14666 [4.7s]
# [Epoch 53] forecast_loss = 0.05127, recon_loss = 0.06007, total_loss = 0.11133 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.06189, val_total_loss = 0.14609 [4.7s]
# [Epoch 54] forecast_loss = 0.05042, recon_loss = 0.05961, total_loss = 0.11003 ---- val_forecast_loss = 0.08460, val_recon_loss = 0.05990, val_total_loss = 0.14450 [4.6s]
# [Epoch 55] forecast_loss = 0.04993, recon_loss = 0.05899, total_loss = 0.10892 ---- val_forecast_loss = 0.08270, val_recon_loss = 0.05960, val_total_loss = 0.14230 [4.6s]
# [Epoch 56] forecast_loss = 0.04969, recon_loss = 0.05818, total_loss = 0.10787 ---- val_forecast_loss = 0.08529, val_recon_loss = 0.05917, val_total_loss = 0.14446 [4.7s]
# [Epoch 57] forecast_loss = 0.04916, recon_loss = 0.05821, total_loss = 0.10736 ---- val_forecast_loss = 0.08304, val_recon_loss = 0.05908, val_total_loss = 0.14212 [4.6s]
# [Epoch 58] forecast_loss = 0.04861, recon_loss = 0.05747, total_loss = 0.10607 ---- val_forecast_loss = 0.08286, val_recon_loss = 0.05800, val_total_loss = 0.14086 [4.6s]
# [Epoch 59] forecast_loss = 0.04904, recon_loss = 0.05746, total_loss = 0.10650 ---- val_forecast_loss = 0.08260, val_recon_loss = 0.05675, val_total_loss = 0.13935 [4.8s]
# [Epoch 60] forecast_loss = 0.04729, recon_loss = 0.05641, total_loss = 0.10369 ---- val_forecast_loss = 0.08428, val_recon_loss = 0.05785, val_total_loss = 0.14213 [4.6s]
# [Epoch 61] forecast_loss = 0.04773, recon_loss = 0.05621, total_loss = 0.10393 ---- val_forecast_loss = 0.08414, val_recon_loss = 0.05742, val_total_loss = 0.14156 [4.6s]
# [Epoch 62] forecast_loss = 0.04708, recon_loss = 0.05587, total_loss = 0.10295 ---- val_forecast_loss = 0.08331, val_recon_loss = 0.05703, val_total_loss = 0.14035 [4.6s]
# [Epoch 63] forecast_loss = 0.04682, recon_loss = 0.05549, total_loss = 0.10231 ---- val_forecast_loss = 0.08333, val_recon_loss = 0.05628, val_total_loss = 0.13961 [4.9s]
# [Epoch 64] forecast_loss = 0.04632, recon_loss = 0.05522, total_loss = 0.10154 ---- val_forecast_loss = 0.08270, val_recon_loss = 0.05672, val_total_loss = 0.13942 [4.8s]
# [Epoch 65] forecast_loss = 0.04666, recon_loss = 0.05457, total_loss = 0.10122 ---- val_forecast_loss = 0.08248, val_recon_loss = 0.05515, val_total_loss = 0.13763 [4.6s]
# [Epoch 66] forecast_loss = 0.04570, recon_loss = 0.05425, total_loss = 0.09995 ---- val_forecast_loss = 0.08463, val_recon_loss = 0.05525, val_total_loss = 0.13987 [4.7s]
# [Epoch 67] forecast_loss = 0.04525, recon_loss = 0.05388, total_loss = 0.09913 ---- val_forecast_loss = 0.08227, val_recon_loss = 0.05605, val_total_loss = 0.13832 [4.6s]
# [Epoch 68] forecast_loss = 0.04589, recon_loss = 0.05439, total_loss = 0.10028 ---- val_forecast_loss = 0.08339, val_recon_loss = 0.05443, val_total_loss = 0.13782 [4.6s]
# [Epoch 69] forecast_loss = 0.04458, recon_loss = 0.05299, total_loss = 0.09757 ---- val_forecast_loss = 0.08330, val_recon_loss = 0.05388, val_total_loss = 0.13718 [4.6s]
# [Epoch 70] forecast_loss = 0.04416, recon_loss = 0.05296, total_loss = 0.09712 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.05380, val_total_loss = 0.13751 [4.6s]
# [Epoch 71] forecast_loss = 0.04419, recon_loss = 0.05266, total_loss = 0.09686 ---- val_forecast_loss = 0.08400, val_recon_loss = 0.05400, val_total_loss = 0.13800 [4.6s]
# [Epoch 72] forecast_loss = 0.04381, recon_loss = 0.05213, total_loss = 0.09594 ---- val_forecast_loss = 0.08362, val_recon_loss = 0.05396, val_total_loss = 0.13758 [4.7s]
# [Epoch 73] forecast_loss = 0.04356, recon_loss = 0.05194, total_loss = 0.09551 ---- val_forecast_loss = 0.08375, val_recon_loss = 0.05252, val_total_loss = 0.13627 [4.6s]
# [Epoch 74] forecast_loss = 0.04365, recon_loss = 0.05204, total_loss = 0.09569 ---- val_forecast_loss = 0.08416, val_recon_loss = 0.05329, val_total_loss = 0.13745 [4.7s]
# [Epoch 75] forecast_loss = 0.04373, recon_loss = 0.05156, total_loss = 0.09529 ---- val_forecast_loss = 0.08410, val_recon_loss = 0.05198, val_total_loss = 0.13608 [4.6s]
# [Epoch 76] forecast_loss = 0.04358, recon_loss = 0.05114, total_loss = 0.09472 ---- val_forecast_loss = 0.08514, val_recon_loss = 0.05310, val_total_loss = 0.13824 [4.6s]
# [Epoch 77] forecast_loss = 0.04234, recon_loss = 0.05087, total_loss = 0.09320 ---- val_forecast_loss = 0.08431, val_recon_loss = 0.05273, val_total_loss = 0.13704 [4.8s]
# [Epoch 78] forecast_loss = 0.04294, recon_loss = 0.05047, total_loss = 0.09341 ---- val_forecast_loss = 0.08478, val_recon_loss = 0.05250, val_total_loss = 0.13728 [4.7s]
# [Epoch 79] forecast_loss = 0.04183, recon_loss = 0.05019, total_loss = 0.09202 ---- val_forecast_loss = 0.08498, val_recon_loss = 0.05252, val_total_loss = 0.13750 [4.7s]
# [Epoch 80] forecast_loss = 0.04152, recon_loss = 0.05006, total_loss = 0.09158 ---- val_forecast_loss = 0.08320, val_recon_loss = 0.05096, val_total_loss = 0.13416 [4.6s]
# [Epoch 81] forecast_loss = 0.04256, recon_loss = 0.05019, total_loss = 0.09275 ---- val_forecast_loss = 0.08338, val_recon_loss = 0.05218, val_total_loss = 0.13556 [4.6s]
# [Epoch 82] forecast_loss = 0.04167, recon_loss = 0.04951, total_loss = 0.09118 ---- val_forecast_loss = 0.08338, val_recon_loss = 0.05055, val_total_loss = 0.13393 [4.7s]
# [Epoch 83] forecast_loss = 0.04080, recon_loss = 0.04907, total_loss = 0.08987 ---- val_forecast_loss = 0.08441, val_recon_loss = 0.05098, val_total_loss = 0.13539 [4.6s]
# [Epoch 84] forecast_loss = 0.04056, recon_loss = 0.04872, total_loss = 0.08927 ---- val_forecast_loss = 0.08452, val_recon_loss = 0.05038, val_total_loss = 0.13490 [4.6s]
# [Epoch 85] forecast_loss = 0.04170, recon_loss = 0.04872, total_loss = 0.09041 ---- val_forecast_loss = 0.08465, val_recon_loss = 0.05036, val_total_loss = 0.13501 [4.7s]
# [Epoch 86] forecast_loss = 0.04062, recon_loss = 0.04855, total_loss = 0.08917 ---- val_forecast_loss = 0.08428, val_recon_loss = 0.04947, val_total_loss = 0.13376 [4.6s]
# [Epoch 87] forecast_loss = 0.04095, recon_loss = 0.04834, total_loss = 0.08929 ---- val_forecast_loss = 0.08535, val_recon_loss = 0.04971, val_total_loss = 0.13506 [4.7s]
# [Epoch 88] forecast_loss = 0.04088, recon_loss = 0.04785, total_loss = 0.08873 ---- val_forecast_loss = 0.08462, val_recon_loss = 0.04923, val_total_loss = 0.13386 [4.6s]
# [Epoch 89] forecast_loss = 0.04076, recon_loss = 0.04792, total_loss = 0.08868 ---- val_forecast_loss = 0.08462, val_recon_loss = 0.04928, val_total_loss = 0.13390 [4.5s]
# [Epoch 90] forecast_loss = 0.04050, recon_loss = 0.04755, total_loss = 0.08805 ---- val_forecast_loss = 0.08385, val_recon_loss = 0.04905, val_total_loss = 0.13289 [4.6s]
# [Epoch 91] forecast_loss = 0.04036, recon_loss = 0.04730, total_loss = 0.08766 ---- val_forecast_loss = 0.08385, val_recon_loss = 0.04874, val_total_loss = 0.13259 [4.8s]
# [Epoch 92] forecast_loss = 0.04017, recon_loss = 0.04701, total_loss = 0.08718 ---- val_forecast_loss = 0.08359, val_recon_loss = 0.04968, val_total_loss = 0.13326 [4.6s]
# [Epoch 93] forecast_loss = 0.03908, recon_loss = 0.04663, total_loss = 0.08571 ---- val_forecast_loss = 0.08628, val_recon_loss = 0.04841, val_total_loss = 0.13469 [4.6s]
# [Epoch 94] forecast_loss = 0.03992, recon_loss = 0.04662, total_loss = 0.08654 ---- val_forecast_loss = 0.08331, val_recon_loss = 0.04832, val_total_loss = 0.13164 [4.7s]
# [Epoch 95] forecast_loss = 0.03868, recon_loss = 0.04631, total_loss = 0.08499 ---- val_forecast_loss = 0.08342, val_recon_loss = 0.04765, val_total_loss = 0.13106 [5.0s]
# [Epoch 96] forecast_loss = 0.03872, recon_loss = 0.04596, total_loss = 0.08468 ---- val_forecast_loss = 0.08584, val_recon_loss = 0.04791, val_total_loss = 0.13375 [4.7s]
# [Epoch 97] forecast_loss = 0.03932, recon_loss = 0.04576, total_loss = 0.08508 ---- val_forecast_loss = 0.08272, val_recon_loss = 0.04816, val_total_loss = 0.13088 [4.6s]
# [Epoch 98] forecast_loss = 0.03834, recon_loss = 0.04568, total_loss = 0.08403 ---- val_forecast_loss = 0.08380, val_recon_loss = 0.04702, val_total_loss = 0.13082 [4.7s]
# [Epoch 99] forecast_loss = 0.03879, recon_loss = 0.04518, total_loss = 0.08397 ---- val_forecast_loss = 0.08491, val_recon_loss = 0.04721, val_total_loss = 0.13212 [5.2s]
# [Epoch 100] forecast_loss = 0.03859, recon_loss = 0.04535, total_loss = 0.08394 ---- val_forecast_loss = 0.08334, val_recon_loss = 0.04640, val_total_loss = 0.12974 [4.7s]
# [Epoch 101] forecast_loss = 0.03812, recon_loss = 0.04509, total_loss = 0.08321 ---- val_forecast_loss = 0.08323, val_recon_loss = 0.04639, val_total_loss = 0.12962 [4.7s]
# [Epoch 102] forecast_loss = 0.03766, recon_loss = 0.04470, total_loss = 0.08236 ---- val_forecast_loss = 0.08289, val_recon_loss = 0.04674, val_total_loss = 0.12963 [4.6s]
# [Epoch 103] forecast_loss = 0.03743, recon_loss = 0.04465, total_loss = 0.08208 ---- val_forecast_loss = 0.08222, val_recon_loss = 0.04552, val_total_loss = 0.12774 [4.6s]
# [Epoch 104] forecast_loss = 0.03793, recon_loss = 0.04426, total_loss = 0.08218 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.04551, val_total_loss = 0.12922 [4.6s]
# [Epoch 105] forecast_loss = 0.03726, recon_loss = 0.04399, total_loss = 0.08125 ---- val_forecast_loss = 0.08326, val_recon_loss = 0.04504, val_total_loss = 0.12831 [4.7s]
# [Epoch 106] forecast_loss = 0.03784, recon_loss = 0.04380, total_loss = 0.08164 ---- val_forecast_loss = 0.08359, val_recon_loss = 0.04590, val_total_loss = 0.12949 [4.6s]
# [Epoch 107] forecast_loss = 0.03702, recon_loss = 0.04365, total_loss = 0.08067 ---- val_forecast_loss = 0.08353, val_recon_loss = 0.04496, val_total_loss = 0.12850 [4.6s]
# [Epoch 108] forecast_loss = 0.03729, recon_loss = 0.04335, total_loss = 0.08064 ---- val_forecast_loss = 0.08293, val_recon_loss = 0.04430, val_total_loss = 0.12723 [4.6s]
# [Epoch 109] forecast_loss = 0.03792, recon_loss = 0.04339, total_loss = 0.08130 ---- val_forecast_loss = 0.08335, val_recon_loss = 0.04474, val_total_loss = 0.12809 [4.7s]
# [Epoch 110] forecast_loss = 0.03737, recon_loss = 0.04311, total_loss = 0.08048 ---- val_forecast_loss = 0.08378, val_recon_loss = 0.04458, val_total_loss = 0.12836 [4.6s]
# [Epoch 111] forecast_loss = 0.03637, recon_loss = 0.04268, total_loss = 0.07905 ---- val_forecast_loss = 0.08494, val_recon_loss = 0.04410, val_total_loss = 0.12904 [4.7s]
# [Epoch 112] forecast_loss = 0.03691, recon_loss = 0.04280, total_loss = 0.07971 ---- val_forecast_loss = 0.08471, val_recon_loss = 0.04365, val_total_loss = 0.12837 [4.6s]
# [Epoch 113] forecast_loss = 0.03571, recon_loss = 0.04236, total_loss = 0.07807 ---- val_forecast_loss = 0.08376, val_recon_loss = 0.04495, val_total_loss = 0.12870 [4.6s]
# [Epoch 114] forecast_loss = 0.03729, recon_loss = 0.04236, total_loss = 0.07965 ---- val_forecast_loss = 0.08406, val_recon_loss = 0.04532, val_total_loss = 0.12938 [4.7s]
# [Epoch 115] forecast_loss = 0.03628, recon_loss = 0.04224, total_loss = 0.07852 ---- val_forecast_loss = 0.08328, val_recon_loss = 0.04458, val_total_loss = 0.12785 [4.6s]
# [Epoch 116] forecast_loss = 0.03542, recon_loss = 0.04220, total_loss = 0.07763 ---- val_forecast_loss = 0.08315, val_recon_loss = 0.04303, val_total_loss = 0.12618 [4.6s]
# [Epoch 117] forecast_loss = 0.03702, recon_loss = 0.04223, total_loss = 0.07926 ---- val_forecast_loss = 0.08318, val_recon_loss = 0.04338, val_total_loss = 0.12655 [4.6s]
# [Epoch 118] forecast_loss = 0.03580, recon_loss = 0.04161, total_loss = 0.07741 ---- val_forecast_loss = 0.08227, val_recon_loss = 0.04325, val_total_loss = 0.12552 [4.7s]
# [Epoch 119] forecast_loss = 0.03546, recon_loss = 0.04140, total_loss = 0.07686 ---- val_forecast_loss = 0.08353, val_recon_loss = 0.04356, val_total_loss = 0.12709 [4.7s]
# [Epoch 120] forecast_loss = 0.03537, recon_loss = 0.04120, total_loss = 0.07657 ---- val_forecast_loss = 0.08252, val_recon_loss = 0.04308, val_total_loss = 0.12560 [4.6s]
# [Epoch 121] forecast_loss = 0.03555, recon_loss = 0.04139, total_loss = 0.07695 ---- val_forecast_loss = 0.08344, val_recon_loss = 0.04286, val_total_loss = 0.12630 [4.6s]
# [Epoch 122] forecast_loss = 0.03539, recon_loss = 0.04108, total_loss = 0.07647 ---- val_forecast_loss = 0.08278, val_recon_loss = 0.04330, val_total_loss = 0.12609 [4.6s]
# [Epoch 123] forecast_loss = 0.03514, recon_loss = 0.04073, total_loss = 0.07588 ---- val_forecast_loss = 0.08285, val_recon_loss = 0.04213, val_total_loss = 0.12497 [4.8s]
# [Epoch 124] forecast_loss = 0.03586, recon_loss = 0.04069, total_loss = 0.07655 ---- val_forecast_loss = 0.08375, val_recon_loss = 0.04286, val_total_loss = 0.12661 [4.6s]
# [Epoch 125] forecast_loss = 0.03573, recon_loss = 0.04067, total_loss = 0.07640 ---- val_forecast_loss = 0.08264, val_recon_loss = 0.04140, val_total_loss = 0.12404 [4.5s]
# [Epoch 126] forecast_loss = 0.03526, recon_loss = 0.04040, total_loss = 0.07566 ---- val_forecast_loss = 0.08248, val_recon_loss = 0.04179, val_total_loss = 0.12427 [4.7s]
# [Epoch 127] forecast_loss = 0.03512, recon_loss = 0.04055, total_loss = 0.07568 ---- val_forecast_loss = 0.08233, val_recon_loss = 0.04174, val_total_loss = 0.12407 [4.9s]
# [Epoch 128] forecast_loss = 0.03493, recon_loss = 0.04011, total_loss = 0.07504 ---- val_forecast_loss = 0.08192, val_recon_loss = 0.04151, val_total_loss = 0.12343 [4.7s]
# [Epoch 129] forecast_loss = 0.03445, recon_loss = 0.03969, total_loss = 0.07413 ---- val_forecast_loss = 0.08259, val_recon_loss = 0.04168, val_total_loss = 0.12427 [4.7s]
# [Epoch 130] forecast_loss = 0.03508, recon_loss = 0.03970, total_loss = 0.07478 ---- val_forecast_loss = 0.08298, val_recon_loss = 0.04137, val_total_loss = 0.12434 [4.7s]
# [Epoch 131] forecast_loss = 0.03401, recon_loss = 0.03963, total_loss = 0.07364 ---- val_forecast_loss = 0.08330, val_recon_loss = 0.04123, val_total_loss = 0.12453 [4.7s]
# [Epoch 132] forecast_loss = 0.03443, recon_loss = 0.03953, total_loss = 0.07397 ---- val_forecast_loss = 0.08251, val_recon_loss = 0.04150, val_total_loss = 0.12401 [4.7s]
# [Epoch 133] forecast_loss = 0.03524, recon_loss = 0.03951, total_loss = 0.07474 ---- val_forecast_loss = 0.08364, val_recon_loss = 0.04112, val_total_loss = 0.12476 [4.6s]
# [Epoch 134] forecast_loss = 0.03384, recon_loss = 0.03916, total_loss = 0.07300 ---- val_forecast_loss = 0.08331, val_recon_loss = 0.04047, val_total_loss = 0.12378 [4.7s]
# [Epoch 135] forecast_loss = 0.03494, recon_loss = 0.03925, total_loss = 0.07419 ---- val_forecast_loss = 0.08244, val_recon_loss = 0.04086, val_total_loss = 0.12329 [4.7s]
# [Epoch 136] forecast_loss = 0.03434, recon_loss = 0.03872, total_loss = 0.07307 ---- val_forecast_loss = 0.08444, val_recon_loss = 0.04067, val_total_loss = 0.12510 [4.6s]
# [Epoch 137] forecast_loss = 0.03430, recon_loss = 0.03871, total_loss = 0.07301 ---- val_forecast_loss = 0.08295, val_recon_loss = 0.04008, val_total_loss = 0.12303 [4.7s]
# [Epoch 138] forecast_loss = 0.03392, recon_loss = 0.03859, total_loss = 0.07251 ---- val_forecast_loss = 0.08562, val_recon_loss = 0.04049, val_total_loss = 0.12610 [4.6s]
# [Epoch 139] forecast_loss = 0.03382, recon_loss = 0.03837, total_loss = 0.07220 ---- val_forecast_loss = 0.08465, val_recon_loss = 0.03999, val_total_loss = 0.12464 [4.6s]
# [Epoch 140] forecast_loss = 0.03454, recon_loss = 0.03813, total_loss = 0.07267 ---- val_forecast_loss = 0.08342, val_recon_loss = 0.03989, val_total_loss = 0.12331 [4.7s]
# [Epoch 141] forecast_loss = 0.03363, recon_loss = 0.03807, total_loss = 0.07170 ---- val_forecast_loss = 0.08353, val_recon_loss = 0.04003, val_total_loss = 0.12355 [4.8s]
# [Epoch 142] forecast_loss = 0.03356, recon_loss = 0.03804, total_loss = 0.07160 ---- val_forecast_loss = 0.08348, val_recon_loss = 0.03942, val_total_loss = 0.12290 [4.6s]
# [Epoch 143] forecast_loss = 0.03357, recon_loss = 0.03821, total_loss = 0.07178 ---- val_forecast_loss = 0.08284, val_recon_loss = 0.04014, val_total_loss = 0.12298 [4.7s]
# [Epoch 144] forecast_loss = 0.03412, recon_loss = 0.03782, total_loss = 0.07194 ---- val_forecast_loss = 0.08309, val_recon_loss = 0.03986, val_total_loss = 0.12294 [4.6s]
# [Epoch 145] forecast_loss = 0.03312, recon_loss = 0.03789, total_loss = 0.07101 ---- val_forecast_loss = 0.08322, val_recon_loss = 0.03930, val_total_loss = 0.12252 [4.7s]
# [Epoch 146] forecast_loss = 0.03266, recon_loss = 0.03754, total_loss = 0.07020 ---- val_forecast_loss = 0.08454, val_recon_loss = 0.03878, val_total_loss = 0.12333 [4.6s]
# [Epoch 147] forecast_loss = 0.03321, recon_loss = 0.03751, total_loss = 0.07072 ---- val_forecast_loss = 0.08377, val_recon_loss = 0.03908, val_total_loss = 0.12285 [4.6s]
# [Epoch 148] forecast_loss = 0.03303, recon_loss = 0.03723, total_loss = 0.07026 ---- val_forecast_loss = 0.08418, val_recon_loss = 0.03963, val_total_loss = 0.12381 [4.6s]
# [Epoch 149] forecast_loss = 0.03318, recon_loss = 0.03714, total_loss = 0.07032 ---- val_forecast_loss = 0.08450, val_recon_loss = 0.03871, val_total_loss = 0.12321 [4.7s]
# [Epoch 150] forecast_loss = 0.03253, recon_loss = 0.03703, total_loss = 0.06957 ---- val_forecast_loss = 0.08367, val_recon_loss = 0.03916, val_total_loss = 0.12283 [4.7s]
# [Epoch 151] forecast_loss = 0.03355, recon_loss = 0.03711, total_loss = 0.07067 ---- val_forecast_loss = 0.08207, val_recon_loss = 0.03848, val_total_loss = 0.12055 [4.6s]
# [Epoch 152] forecast_loss = 0.03343, recon_loss = 0.03682, total_loss = 0.07025 ---- val_forecast_loss = 0.08334, val_recon_loss = 0.03858, val_total_loss = 0.12192 [4.6s]
# [Epoch 153] forecast_loss = 0.03392, recon_loss = 0.03696, total_loss = 0.07087 ---- val_forecast_loss = 0.08350, val_recon_loss = 0.03822, val_total_loss = 0.12173 [4.6s]
# [Epoch 154] forecast_loss = 0.03269, recon_loss = 0.03656, total_loss = 0.06924 ---- val_forecast_loss = 0.08270, val_recon_loss = 0.03868, val_total_loss = 0.12137 [4.5s]
# [Epoch 155] forecast_loss = 0.03330, recon_loss = 0.03666, total_loss = 0.06996 ---- val_forecast_loss = 0.08251, val_recon_loss = 0.03870, val_total_loss = 0.12121 [4.7s]
# [Epoch 156] forecast_loss = 0.03299, recon_loss = 0.03617, total_loss = 0.06916 ---- val_forecast_loss = 0.08360, val_recon_loss = 0.03771, val_total_loss = 0.12131 [4.6s]
# [Epoch 157] forecast_loss = 0.03293, recon_loss = 0.03618, total_loss = 0.06911 ---- val_forecast_loss = 0.08308, val_recon_loss = 0.03710, val_total_loss = 0.12019 [4.5s]
# [Epoch 158] forecast_loss = 0.03233, recon_loss = 0.03611, total_loss = 0.06844 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.03720, val_total_loss = 0.12141 [4.8s]
# [Epoch 159] forecast_loss = 0.03237, recon_loss = 0.03579, total_loss = 0.06816 ---- val_forecast_loss = 0.08381, val_recon_loss = 0.03870, val_total_loss = 0.12252 [4.8s]
# [Epoch 160] forecast_loss = 0.03253, recon_loss = 0.03608, total_loss = 0.06861 ---- val_forecast_loss = 0.08319, val_recon_loss = 0.03705, val_total_loss = 0.12025 [4.6s]
# [Epoch 161] forecast_loss = 0.03247, recon_loss = 0.03599, total_loss = 0.06846 ---- val_forecast_loss = 0.08337, val_recon_loss = 0.03717, val_total_loss = 0.12054 [4.7s]
# [Epoch 162] forecast_loss = 0.03232, recon_loss = 0.03559, total_loss = 0.06791 ---- val_forecast_loss = 0.08248, val_recon_loss = 0.03745, val_total_loss = 0.11993 [4.6s]
# [Epoch 163] forecast_loss = 0.03284, recon_loss = 0.03577, total_loss = 0.06860 ---- val_forecast_loss = 0.08281, val_recon_loss = 0.03790, val_total_loss = 0.12071 [4.6s]
# [Epoch 164] forecast_loss = 0.03193, recon_loss = 0.03546, total_loss = 0.06739 ---- val_forecast_loss = 0.08396, val_recon_loss = 0.03715, val_total_loss = 0.12112 [4.6s]
# [Epoch 165] forecast_loss = 0.03152, recon_loss = 0.03523, total_loss = 0.06675 ---- val_forecast_loss = 0.08521, val_recon_loss = 0.03719, val_total_loss = 0.12240 [4.6s]
# [Epoch 166] forecast_loss = 0.03233, recon_loss = 0.03530, total_loss = 0.06763 ---- val_forecast_loss = 0.08396, val_recon_loss = 0.03686, val_total_loss = 0.12082 [4.7s]
# [Epoch 167] forecast_loss = 0.03253, recon_loss = 0.03532, total_loss = 0.06785 ---- val_forecast_loss = 0.08318, val_recon_loss = 0.03660, val_total_loss = 0.11978 [4.6s]
# [Epoch 168] forecast_loss = 0.03247, recon_loss = 0.03518, total_loss = 0.06765 ---- val_forecast_loss = 0.08398, val_recon_loss = 0.03744, val_total_loss = 0.12141 [4.6s]
# [Epoch 169] forecast_loss = 0.03217, recon_loss = 0.03507, total_loss = 0.06724 ---- val_forecast_loss = 0.08350, val_recon_loss = 0.03666, val_total_loss = 0.12016 [4.6s]
# [Epoch 170] forecast_loss = 0.03188, recon_loss = 0.03521, total_loss = 0.06708 ---- val_forecast_loss = 0.08389, val_recon_loss = 0.03675, val_total_loss = 0.12064 [4.6s]
# [Epoch 171] forecast_loss = 0.03206, recon_loss = 0.03487, total_loss = 0.06693 ---- val_forecast_loss = 0.08364, val_recon_loss = 0.03580, val_total_loss = 0.11943 [4.7s]
# [Epoch 172] forecast_loss = 0.03173, recon_loss = 0.03470, total_loss = 0.06643 ---- val_forecast_loss = 0.08391, val_recon_loss = 0.03669, val_total_loss = 0.12061 [4.6s]
# [Epoch 173] forecast_loss = 0.03203, recon_loss = 0.03501, total_loss = 0.06704 ---- val_forecast_loss = 0.08432, val_recon_loss = 0.03659, val_total_loss = 0.12092 [4.8s]
# [Epoch 174] forecast_loss = 0.03205, recon_loss = 0.03460, total_loss = 0.06666 ---- val_forecast_loss = 0.08305, val_recon_loss = 0.03608, val_total_loss = 0.11913 [4.6s]
# [Epoch 175] forecast_loss = 0.03178, recon_loss = 0.03447, total_loss = 0.06625 ---- val_forecast_loss = 0.08345, val_recon_loss = 0.03594, val_total_loss = 0.11940 [4.6s]
# [Epoch 176] forecast_loss = 0.03179, recon_loss = 0.03421, total_loss = 0.06600 ---- val_forecast_loss = 0.08295, val_recon_loss = 0.03571, val_total_loss = 0.11866 [4.6s]
# [Epoch 177] forecast_loss = 0.03139, recon_loss = 0.03424, total_loss = 0.06562 ---- val_forecast_loss = 0.08498, val_recon_loss = 0.03693, val_total_loss = 0.12191 [4.7s]
# [Epoch 178] forecast_loss = 0.03183, recon_loss = 0.03437, total_loss = 0.06620 ---- val_forecast_loss = 0.08412, val_recon_loss = 0.03563, val_total_loss = 0.11976 [4.7s]
# [Epoch 179] forecast_loss = 0.03317, recon_loss = 0.03439, total_loss = 0.06757 ---- val_forecast_loss = 0.08396, val_recon_loss = 0.03577, val_total_loss = 0.11974 [4.7s]
# [Epoch 180] forecast_loss = 0.03125, recon_loss = 0.03400, total_loss = 0.06524 ---- val_forecast_loss = 0.08429, val_recon_loss = 0.03529, val_total_loss = 0.11959 [4.6s]
# [Epoch 181] forecast_loss = 0.03131, recon_loss = 0.03385, total_loss = 0.06516 ---- val_forecast_loss = 0.08431, val_recon_loss = 0.03545, val_total_loss = 0.11975 [4.6s]
# [Epoch 182] forecast_loss = 0.03110, recon_loss = 0.03377, total_loss = 0.06487 ---- val_forecast_loss = 0.08411, val_recon_loss = 0.03547, val_total_loss = 0.11958 [4.7s]
# [Epoch 183] forecast_loss = 0.03164, recon_loss = 0.03374, total_loss = 0.06538 ---- val_forecast_loss = 0.08327, val_recon_loss = 0.03564, val_total_loss = 0.11890 [4.6s]
# [Epoch 184] forecast_loss = 0.03090, recon_loss = 0.03370, total_loss = 0.06461 ---- val_forecast_loss = 0.08483, val_recon_loss = 0.03543, val_total_loss = 0.12026 [4.7s]
# [Epoch 185] forecast_loss = 0.03170, recon_loss = 0.03392, total_loss = 0.06562 ---- val_forecast_loss = 0.08257, val_recon_loss = 0.03454, val_total_loss = 0.11710 [4.6s]
# [Epoch 186] forecast_loss = 0.03058, recon_loss = 0.03336, total_loss = 0.06394 ---- val_forecast_loss = 0.08453, val_recon_loss = 0.03468, val_total_loss = 0.11921 [4.6s]
# [Epoch 187] forecast_loss = 0.03103, recon_loss = 0.03351, total_loss = 0.06454 ---- val_forecast_loss = 0.08402, val_recon_loss = 0.03479, val_total_loss = 0.11881 [4.8s]
# [Epoch 188] forecast_loss = 0.03114, recon_loss = 0.03348, total_loss = 0.06462 ---- val_forecast_loss = 0.08326, val_recon_loss = 0.03541, val_total_loss = 0.11867 [4.6s]
# [Epoch 189] forecast_loss = 0.03083, recon_loss = 0.03342, total_loss = 0.06425 ---- val_forecast_loss = 0.08391, val_recon_loss = 0.03433, val_total_loss = 0.11823 [4.6s]
# [Epoch 190] forecast_loss = 0.03080, recon_loss = 0.03327, total_loss = 0.06407 ---- val_forecast_loss = 0.08344, val_recon_loss = 0.03482, val_total_loss = 0.11827 [4.7s]
# [Epoch 191] forecast_loss = 0.03072, recon_loss = 0.03333, total_loss = 0.06405 ---- val_forecast_loss = 0.08348, val_recon_loss = 0.03523, val_total_loss = 0.11871 [4.9s]
# [Epoch 192] forecast_loss = 0.03055, recon_loss = 0.03327, total_loss = 0.06382 ---- val_forecast_loss = 0.08378, val_recon_loss = 0.03507, val_total_loss = 0.11885 [4.7s]
# [Epoch 193] forecast_loss = 0.03064, recon_loss = 0.03302, total_loss = 0.06366 ---- val_forecast_loss = 0.08378, val_recon_loss = 0.03416, val_total_loss = 0.11794 [4.9s]
# [Epoch 194] forecast_loss = 0.03068, recon_loss = 0.03300, total_loss = 0.06368 ---- val_forecast_loss = 0.08392, val_recon_loss = 0.03420, val_total_loss = 0.11811 [4.8s]
# [Epoch 195] forecast_loss = 0.03022, recon_loss = 0.03261, total_loss = 0.06283 ---- val_forecast_loss = 0.08279, val_recon_loss = 0.03390, val_total_loss = 0.11669 [4.7s]
# [Epoch 196] forecast_loss = 0.03062, recon_loss = 0.03277, total_loss = 0.06340 ---- val_forecast_loss = 0.08392, val_recon_loss = 0.03571, val_total_loss = 0.11963 [4.6s]
# [Epoch 197] forecast_loss = 0.03067, recon_loss = 0.03279, total_loss = 0.06346 ---- val_forecast_loss = 0.08365, val_recon_loss = 0.03419, val_total_loss = 0.11784 [4.7s]
# [Epoch 198] forecast_loss = 0.03011, recon_loss = 0.03255, total_loss = 0.06266 ---- val_forecast_loss = 0.08351, val_recon_loss = 0.03404, val_total_loss = 0.11755 [4.7s]
# [Epoch 199] forecast_loss = 0.03046, recon_loss = 0.03247, total_loss = 0.06293 ---- val_forecast_loss = 0.08477, val_recon_loss = 0.03424, val_total_loss = 0.11901 [5.2s]
# [Epoch 200] forecast_loss = 0.03052, recon_loss = 0.03240, total_loss = 0.06293 ---- val_forecast_loss = 0.08407, val_recon_loss = 0.03448, val_total_loss = 0.11855 [4.7s]
# [Epoch 201] forecast_loss = 0.03052, recon_loss = 0.03226, total_loss = 0.06278 ---- val_forecast_loss = 0.08385, val_recon_loss = 0.03360, val_total_loss = 0.11745 [4.6s]
# [Epoch 202] forecast_loss = 0.03067, recon_loss = 0.03237, total_loss = 0.06303 ---- val_forecast_loss = 0.08353, val_recon_loss = 0.03325, val_total_loss = 0.11678 [4.6s]
# [Epoch 203] forecast_loss = 0.03011, recon_loss = 0.03224, total_loss = 0.06235 ---- val_forecast_loss = 0.08333, val_recon_loss = 0.03399, val_total_loss = 0.11732 [4.7s]
# [Epoch 204] forecast_loss = 0.03002, recon_loss = 0.03213, total_loss = 0.06215 ---- val_forecast_loss = 0.08456, val_recon_loss = 0.03393, val_total_loss = 0.11849 [4.6s]
# [Epoch 205] forecast_loss = 0.03055, recon_loss = 0.03233, total_loss = 0.06288 ---- val_forecast_loss = 0.08291, val_recon_loss = 0.03379, val_total_loss = 0.11669 [4.6s]
# [Epoch 206] forecast_loss = 0.03024, recon_loss = 0.03191, total_loss = 0.06215 ---- val_forecast_loss = 0.08351, val_recon_loss = 0.03451, val_total_loss = 0.11802 [4.5s]
# [Epoch 207] forecast_loss = 0.03015, recon_loss = 0.03232, total_loss = 0.06247 ---- val_forecast_loss = 0.08373, val_recon_loss = 0.03261, val_total_loss = 0.11633 [4.8s]
# [Epoch 208] forecast_loss = 0.03020, recon_loss = 0.03190, total_loss = 0.06210 ---- val_forecast_loss = 0.08406, val_recon_loss = 0.03340, val_total_loss = 0.11746 [4.6s]
# [Epoch 209] forecast_loss = 0.03072, recon_loss = 0.03193, total_loss = 0.06266 ---- val_forecast_loss = 0.08366, val_recon_loss = 0.03382, val_total_loss = 0.11748 [4.6s]
# [Epoch 210] forecast_loss = 0.03022, recon_loss = 0.03180, total_loss = 0.06202 ---- val_forecast_loss = 0.08378, val_recon_loss = 0.03365, val_total_loss = 0.11743 [4.6s]
# [Epoch 211] forecast_loss = 0.02958, recon_loss = 0.03173, total_loss = 0.06130 ---- val_forecast_loss = 0.08367, val_recon_loss = 0.03298, val_total_loss = 0.11666 [4.7s]
# [Epoch 212] forecast_loss = 0.02983, recon_loss = 0.03180, total_loss = 0.06162 ---- val_forecast_loss = 0.08443, val_recon_loss = 0.03286, val_total_loss = 0.11729 [4.7s]
# [Epoch 213] forecast_loss = 0.03064, recon_loss = 0.03161, total_loss = 0.06225 ---- val_forecast_loss = 0.08361, val_recon_loss = 0.03240, val_total_loss = 0.11601 [4.7s]
# [Epoch 214] forecast_loss = 0.02949, recon_loss = 0.03134, total_loss = 0.06082 ---- val_forecast_loss = 0.08410, val_recon_loss = 0.03325, val_total_loss = 0.11735 [4.6s]
# [Epoch 215] forecast_loss = 0.02984, recon_loss = 0.03145, total_loss = 0.06129 ---- val_forecast_loss = 0.08365, val_recon_loss = 0.03406, val_total_loss = 0.11771 [4.6s]
# [Epoch 216] forecast_loss = 0.03001, recon_loss = 0.03233, total_loss = 0.06234 ---- val_forecast_loss = 0.08374, val_recon_loss = 0.03315, val_total_loss = 0.11690 [4.7s]
# [Epoch 217] forecast_loss = 0.02997, recon_loss = 0.03130, total_loss = 0.06128 ---- val_forecast_loss = 0.08470, val_recon_loss = 0.03285, val_total_loss = 0.11755 [4.6s]
# [Epoch 218] forecast_loss = 0.02960, recon_loss = 0.03130, total_loss = 0.06091 ---- val_forecast_loss = 0.08348, val_recon_loss = 0.03330, val_total_loss = 0.11678 [4.7s]
# [Epoch 219] forecast_loss = 0.03001, recon_loss = 0.03145, total_loss = 0.06147 ---- val_forecast_loss = 0.08359, val_recon_loss = 0.03264, val_total_loss = 0.11623 [4.6s]
# [Epoch 220] forecast_loss = 0.03003, recon_loss = 0.03160, total_loss = 0.06163 ---- val_forecast_loss = 0.08491, val_recon_loss = 0.03299, val_total_loss = 0.11790 [4.6s]
# [Epoch 221] forecast_loss = 0.02983, recon_loss = 0.03123, total_loss = 0.06106 ---- val_forecast_loss = 0.08409, val_recon_loss = 0.03315, val_total_loss = 0.11725 [4.8s]
# [Epoch 222] forecast_loss = 0.02888, recon_loss = 0.03092, total_loss = 0.05980 ---- val_forecast_loss = 0.08364, val_recon_loss = 0.03155, val_total_loss = 0.11519 [4.6s]
# [Epoch 223] forecast_loss = 0.02938, recon_loss = 0.03099, total_loss = 0.06038 ---- val_forecast_loss = 0.08395, val_recon_loss = 0.03197, val_total_loss = 0.11592 [4.5s]
# [Epoch 224] forecast_loss = 0.02922, recon_loss = 0.03090, total_loss = 0.06012 ---- val_forecast_loss = 0.08340, val_recon_loss = 0.03329, val_total_loss = 0.11669 [4.7s]
# [Epoch 225] forecast_loss = 0.02913, recon_loss = 0.03067, total_loss = 0.05979 ---- val_forecast_loss = 0.08374, val_recon_loss = 0.03173, val_total_loss = 0.11546 [4.8s]
# [Epoch 226] forecast_loss = 0.02936, recon_loss = 0.03066, total_loss = 0.06002 ---- val_forecast_loss = 0.08312, val_recon_loss = 0.03225, val_total_loss = 0.11537 [4.7s]
# [Epoch 227] forecast_loss = 0.02946, recon_loss = 0.03072, total_loss = 0.06017 ---- val_forecast_loss = 0.08430, val_recon_loss = 0.03220, val_total_loss = 0.11650 [4.6s]
# [Epoch 228] forecast_loss = 0.02920, recon_loss = 0.03059, total_loss = 0.05979 ---- val_forecast_loss = 0.08317, val_recon_loss = 0.03193, val_total_loss = 0.11510 [4.6s]
# [Epoch 229] forecast_loss = 0.02923, recon_loss = 0.03060, total_loss = 0.05983 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.03275, val_total_loss = 0.11695 [4.7s]
# [Epoch 230] forecast_loss = 0.02940, recon_loss = 0.03063, total_loss = 0.06003 ---- val_forecast_loss = 0.08367, val_recon_loss = 0.03304, val_total_loss = 0.11671 [4.7s]
# [Epoch 231] forecast_loss = 0.02948, recon_loss = 0.03080, total_loss = 0.06028 ---- val_forecast_loss = 0.08405, val_recon_loss = 0.03225, val_total_loss = 0.11630 [4.6s]
# [Epoch 232] forecast_loss = 0.02890, recon_loss = 0.03055, total_loss = 0.05945 ---- val_forecast_loss = 0.08347, val_recon_loss = 0.03217, val_total_loss = 0.11564 [4.6s]
# [Epoch 233] forecast_loss = 0.02952, recon_loss = 0.03053, total_loss = 0.06005 ---- val_forecast_loss = 0.08243, val_recon_loss = 0.03271, val_total_loss = 0.11513 [4.6s]
# [Epoch 234] forecast_loss = 0.02927, recon_loss = 0.03037, total_loss = 0.05964 ---- val_forecast_loss = 0.08427, val_recon_loss = 0.03285, val_total_loss = 0.11712 [4.7s]
# [Epoch 235] forecast_loss = 0.02942, recon_loss = 0.03045, total_loss = 0.05987 ---- val_forecast_loss = 0.08368, val_recon_loss = 0.03198, val_total_loss = 0.11566 [4.6s]
# [Epoch 236] forecast_loss = 0.02948, recon_loss = 0.03028, total_loss = 0.05976 ---- val_forecast_loss = 0.08326, val_recon_loss = 0.03196, val_total_loss = 0.11521 [4.6s]
# [Epoch 237] forecast_loss = 0.02873, recon_loss = 0.03020, total_loss = 0.05893 ---- val_forecast_loss = 0.08408, val_recon_loss = 0.03126, val_total_loss = 0.11535 [4.7s]
# [Epoch 238] forecast_loss = 0.02905, recon_loss = 0.03020, total_loss = 0.05925 ---- val_forecast_loss = 0.08413, val_recon_loss = 0.03179, val_total_loss = 0.11591 [4.5s]
# [Epoch 239] forecast_loss = 0.02854, recon_loss = 0.02991, total_loss = 0.05845 ---- val_forecast_loss = 0.08333, val_recon_loss = 0.03078, val_total_loss = 0.11411 [4.8s]
# [Epoch 240] forecast_loss = 0.02879, recon_loss = 0.03022, total_loss = 0.05901 ---- val_forecast_loss = 0.08506, val_recon_loss = 0.03218, val_total_loss = 0.11724 [4.7s]
# [Epoch 241] forecast_loss = 0.02867, recon_loss = 0.03150, total_loss = 0.06017 ---- val_forecast_loss = 0.08324, val_recon_loss = 0.03272, val_total_loss = 0.11596 [4.6s]
# [Epoch 242] forecast_loss = 0.02842, recon_loss = 0.02991, total_loss = 0.05833 ---- val_forecast_loss = 0.08458, val_recon_loss = 0.03151, val_total_loss = 0.11609 [4.8s]
# [Epoch 243] forecast_loss = 0.02893, recon_loss = 0.02971, total_loss = 0.05864 ---- val_forecast_loss = 0.08357, val_recon_loss = 0.03065, val_total_loss = 0.11422 [4.6s]
# [Epoch 244] forecast_loss = 0.02911, recon_loss = 0.02976, total_loss = 0.05887 ---- val_forecast_loss = 0.08435, val_recon_loss = 0.03075, val_total_loss = 0.11510 [4.6s]
# [Epoch 245] forecast_loss = 0.02853, recon_loss = 0.02977, total_loss = 0.05831 ---- val_forecast_loss = 0.08324, val_recon_loss = 0.03070, val_total_loss = 0.11395 [4.7s]
# [Epoch 246] forecast_loss = 0.02852, recon_loss = 0.02984, total_loss = 0.05836 ---- val_forecast_loss = 0.08272, val_recon_loss = 0.04404, val_total_loss = 0.12676 [4.6s]
# [Epoch 247] forecast_loss = 0.02870, recon_loss = 0.03058, total_loss = 0.05928 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.03049, val_total_loss = 0.11421 [4.6s]
# [Epoch 248] forecast_loss = 0.02844, recon_loss = 0.02957, total_loss = 0.05800 ---- val_forecast_loss = 0.08398, val_recon_loss = 0.03108, val_total_loss = 0.11506 [4.6s]
# [Epoch 249] forecast_loss = 0.02853, recon_loss = 0.02931, total_loss = 0.05783 ---- val_forecast_loss = 0.08373, val_recon_loss = 0.03068, val_total_loss = 0.11441 [4.7s]
# [Epoch 250] forecast_loss = 0.02810, recon_loss = 0.02982, total_loss = 0.05792 ---- val_forecast_loss = 0.08613, val_recon_loss = 0.03075, val_total_loss = 0.11688 [4.7s]
# [Epoch 251] forecast_loss = 0.02875, recon_loss = 0.02954, total_loss = 0.05830 ---- val_forecast_loss = 0.08448, val_recon_loss = 0.03085, val_total_loss = 0.11533 [4.6s]
# [Epoch 252] forecast_loss = 0.02838, recon_loss = 0.02933, total_loss = 0.05771 ---- val_forecast_loss = 0.08320, val_recon_loss = 0.03141, val_total_loss = 0.11460 [4.5s]
# [Epoch 253] forecast_loss = 0.02864, recon_loss = 0.02938, total_loss = 0.05802 ---- val_forecast_loss = 0.08445, val_recon_loss = 0.03085, val_total_loss = 0.11529 [4.8s]
# [Epoch 254] forecast_loss = 0.02839, recon_loss = 0.02914, total_loss = 0.05752 ---- val_forecast_loss = 0.08410, val_recon_loss = 0.03040, val_total_loss = 0.11450 [4.6s]
# [Epoch 255] forecast_loss = 0.02829, recon_loss = 0.02901, total_loss = 0.05730 ---- val_forecast_loss = 0.08308, val_recon_loss = 0.03011, val_total_loss = 0.11319 [4.6s]
# [Epoch 256] forecast_loss = 0.02786, recon_loss = 0.02945, total_loss = 0.05731 ---- val_forecast_loss = 0.08450, val_recon_loss = 0.03012, val_total_loss = 0.11462 [4.6s]
# [Epoch 257] forecast_loss = 0.02814, recon_loss = 0.02913, total_loss = 0.05727 ---- val_forecast_loss = 0.08280, val_recon_loss = 0.03043, val_total_loss = 0.11323 [4.9s]
# [Epoch 258] forecast_loss = 0.02848, recon_loss = 0.02910, total_loss = 0.05759 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.03068, val_total_loss = 0.11488 [4.8s]
# [Epoch 259] forecast_loss = 0.02852, recon_loss = 0.02948, total_loss = 0.05800 ---- val_forecast_loss = 0.08275, val_recon_loss = 0.03129, val_total_loss = 0.11405 [4.6s]
# [Epoch 260] forecast_loss = 0.02824, recon_loss = 0.02895, total_loss = 0.05719 ---- val_forecast_loss = 0.08357, val_recon_loss = 0.03132, val_total_loss = 0.11489 [4.6s]
# [Epoch 261] forecast_loss = 0.02863, recon_loss = 0.02933, total_loss = 0.05796 ---- val_forecast_loss = 0.08354, val_recon_loss = 0.03004, val_total_loss = 0.11357 [4.7s]
# [Epoch 262] forecast_loss = 0.02813, recon_loss = 0.02907, total_loss = 0.05720 ---- val_forecast_loss = 0.08302, val_recon_loss = 0.02973, val_total_loss = 0.11275 [4.6s]
# [Epoch 263] forecast_loss = 0.02805, recon_loss = 0.02858, total_loss = 0.05663 ---- val_forecast_loss = 0.08318, val_recon_loss = 0.03049, val_total_loss = 0.11368 [4.8s]
# [Epoch 264] forecast_loss = 0.02747, recon_loss = 0.02896, total_loss = 0.05644 ---- val_forecast_loss = 0.08398, val_recon_loss = 0.03092, val_total_loss = 0.11490 [4.6s]
# [Epoch 265] forecast_loss = 0.02806, recon_loss = 0.02970, total_loss = 0.05776 ---- val_forecast_loss = 0.08450, val_recon_loss = 0.02976, val_total_loss = 0.11426 [4.6s]
# [Epoch 266] forecast_loss = 0.02787, recon_loss = 0.02858, total_loss = 0.05645 ---- val_forecast_loss = 0.08350, val_recon_loss = 0.02982, val_total_loss = 0.11332 [4.7s]
# [Epoch 267] forecast_loss = 0.02751, recon_loss = 0.02873, total_loss = 0.05624 ---- val_forecast_loss = 0.08536, val_recon_loss = 0.03083, val_total_loss = 0.11619 [4.6s]
# [Epoch 268] forecast_loss = 0.02796, recon_loss = 0.02862, total_loss = 0.05658 ---- val_forecast_loss = 0.08431, val_recon_loss = 0.02963, val_total_loss = 0.11394 [4.6s]
# [Epoch 269] forecast_loss = 0.02802, recon_loss = 0.02858, total_loss = 0.05660 ---- val_forecast_loss = 0.08415, val_recon_loss = 0.02950, val_total_loss = 0.11365 [4.6s]
# [Epoch 270] forecast_loss = 0.02757, recon_loss = 0.02841, total_loss = 0.05598 ---- val_forecast_loss = 0.08385, val_recon_loss = 0.03014, val_total_loss = 0.11399 [4.6s]
# [Epoch 271] forecast_loss = 0.02798, recon_loss = 0.02839, total_loss = 0.05637 ---- val_forecast_loss = 0.08415, val_recon_loss = 0.03000, val_total_loss = 0.11415 [4.8s]
# [Epoch 272] forecast_loss = 0.02788, recon_loss = 0.02851, total_loss = 0.05639 ---- val_forecast_loss = 0.08409, val_recon_loss = 0.03000, val_total_loss = 0.11409 [4.6s]
# [Epoch 273] forecast_loss = 0.02803, recon_loss = 0.02850, total_loss = 0.05653 ---- val_forecast_loss = 0.08405, val_recon_loss = 0.02963, val_total_loss = 0.11368 [4.6s]
# [Epoch 274] forecast_loss = 0.02747, recon_loss = 0.02799, total_loss = 0.05546 ---- val_forecast_loss = 0.08527, val_recon_loss = 0.02941, val_total_loss = 0.11469 [4.7s]
# [Epoch 275] forecast_loss = 0.02799, recon_loss = 0.02846, total_loss = 0.05645 ---- val_forecast_loss = 0.08429, val_recon_loss = 0.03071, val_total_loss = 0.11500 [4.6s]
# [Epoch 276] forecast_loss = 0.02724, recon_loss = 0.02843, total_loss = 0.05566 ---- val_forecast_loss = 0.08375, val_recon_loss = 0.02924, val_total_loss = 0.11298 [4.6s]
# [Epoch 277] forecast_loss = 0.02816, recon_loss = 0.02863, total_loss = 0.05679 ---- val_forecast_loss = 0.08509, val_recon_loss = 0.02983, val_total_loss = 0.11492 [4.7s]
# [Epoch 278] forecast_loss = 0.02818, recon_loss = 0.02836, total_loss = 0.05654 ---- val_forecast_loss = 0.08499, val_recon_loss = 0.03179, val_total_loss = 0.11677 [4.6s]
# [Epoch 279] forecast_loss = 0.02763, recon_loss = 0.02860, total_loss = 0.05623 ---- val_forecast_loss = 0.08403, val_recon_loss = 0.02954, val_total_loss = 0.11358 [4.7s]
# ...
# [Epoch 409] forecast_loss = 0.02482, recon_loss = 0.02453, total_loss = 0.04934 ---- val_forecast_loss = 0.08538, val_recon_loss = 0.02566, val_total_loss = 0.11104 [4.6s]
# [Epoch 410] forecast_loss = 0.02480, recon_loss = 0.02462, total_loss = 0.04943 ---- val_forecast_loss = 0.08466, val_recon_loss = 0.02582, val_total_loss = 0.11049 [4.6s]
# [Epoch 411] forecast_loss = 0.02470, recon_loss = 0.02456, total_loss = 0.04926 ---- val_forecast_loss = 0.08456, val_recon_loss = 0.02552, val_total_loss = 0.11008 [4.6s]
# [Epoch 412] forecast_loss = 0.02461, recon_loss = 0.02430, total_loss = 0.04891 ---- val_forecast_loss = 0.08406, val_recon_loss = 0.02521, val_total_loss = 0.10927 [4.9s]
# [Epoch 413] forecast_loss = 0.02483, recon_loss = 0.02585, total_loss = 0.05068 ---- val_forecast_loss = 0.08483, val_recon_loss = 0.02855, val_total_loss = 0.11338 [4.6s]
# [Epoch 414] forecast_loss = 0.02504, recon_loss = 0.02526, total_loss = 0.05030 ---- val_forecast_loss = 0.08356, val_recon_loss = 0.02525, val_total_loss = 0.10881 [4.6s]
# [Epoch 415] forecast_loss = 0.02457, recon_loss = 0.02425, total_loss = 0.04882 ---- val_forecast_loss = 0.08567, val_recon_loss = 0.02572, val_total_loss = 0.11139 [4.7s]
# [Epoch 416] forecast_loss = 0.02527, recon_loss = 0.02481, total_loss = 0.05008 ---- val_forecast_loss = 0.08357, val_recon_loss = 0.02623, val_total_loss = 0.10981 [4.9s]
# [Epoch 417] forecast_loss = 0.02449, recon_loss = 0.02474, total_loss = 0.04922 ---- val_forecast_loss = 0.08362, val_recon_loss = 0.02541, val_total_loss = 0.10903 [4.8s]
# [Epoch 418] forecast_loss = 0.02413, recon_loss = 0.02406, total_loss = 0.04819 ---- val_forecast_loss = 0.08356, val_recon_loss = 0.02544, val_total_loss = 0.10900 [4.7s]
# [Epoch 419] forecast_loss = 0.02482, recon_loss = 0.02436, total_loss = 0.04918 ---- val_forecast_loss = 0.08465, val_recon_loss = 0.02601, val_total_loss = 0.11066 [4.7s]
# [Epoch 420] forecast_loss = 0.02481, recon_loss = 0.02453, total_loss = 0.04933 ---- val_forecast_loss = 0.08393, val_recon_loss = 0.02542, val_total_loss = 0.10935 [4.7s]
# [Epoch 421] forecast_loss = 0.02506, recon_loss = 0.02739, total_loss = 0.05245 ---- val_forecast_loss = 0.08384, val_recon_loss = 0.03275, val_total_loss = 0.11658 [4.7s]
# [Epoch 422] forecast_loss = 0.02542, recon_loss = 0.02667, total_loss = 0.05209 ---- val_forecast_loss = 0.08437, val_recon_loss = 0.02662, val_total_loss = 0.11099 [4.6s]
# [Epoch 423] forecast_loss = 0.02497, recon_loss = 0.02442, total_loss = 0.04939 ---- val_forecast_loss = 0.08493, val_recon_loss = 0.02506, val_total_loss = 0.10999 [4.7s]
# [Epoch 424] forecast_loss = 0.02401, recon_loss = 0.02387, total_loss = 0.04788 ---- val_forecast_loss = 0.08515, val_recon_loss = 0.02532, val_total_loss = 0.11047 [4.6s]
# [Epoch 425] forecast_loss = 0.02431, recon_loss = 0.02569, total_loss = 0.05000 ---- val_forecast_loss = 0.08535, val_recon_loss = 0.02595, val_total_loss = 0.11130 [4.7s]
# [Epoch 426] forecast_loss = 0.02391, recon_loss = 0.02408, total_loss = 0.04800 ---- val_forecast_loss = 0.08450, val_recon_loss = 0.02606, val_total_loss = 0.11057 [4.7s]
# [Epoch 427] forecast_loss = 0.02414, recon_loss = 0.02381, total_loss = 0.04795 ---- val_forecast_loss = 0.08506, val_recon_loss = 0.02530, val_total_loss = 0.11036 [4.6s]
# [Epoch 428] forecast_loss = 0.02450, recon_loss = 0.02410, total_loss = 0.04860 ---- val_forecast_loss = 0.08425, val_recon_loss = 0.02547, val_total_loss = 0.10971 [4.6s]
# [Epoch 429] forecast_loss = 0.02430, recon_loss = 0.02398, total_loss = 0.04828 ---- val_forecast_loss = 0.08389, val_recon_loss = 0.02565, val_total_loss = 0.10954 [4.5s]
# [Epoch 430] forecast_loss = 0.02397, recon_loss = 0.02413, total_loss = 0.04810 ---- val_forecast_loss = 0.08471, val_recon_loss = 0.02551, val_total_loss = 0.11022 [4.8s]
# [Epoch 431] forecast_loss = 0.02485, recon_loss = 0.02405, total_loss = 0.04890 ---- val_forecast_loss = 0.08450, val_recon_loss = 0.02642, val_total_loss = 0.11092 [4.6s]
# [Epoch 432] forecast_loss = 0.02433, recon_loss = 0.02416, total_loss = 0.04849 ---- val_forecast_loss = 0.08547, val_recon_loss = 0.02608, val_total_loss = 0.11155 [4.6s]
# [Epoch 433] forecast_loss = 0.02421, recon_loss = 0.02421, total_loss = 0.04841 ---- val_forecast_loss = 0.08446, val_recon_loss = 0.02502, val_total_loss = 0.10948 [4.6s]
# [Epoch 434] forecast_loss = 0.02509, recon_loss = 0.02423, total_loss = 0.04932 ---- val_forecast_loss = 0.08437, val_recon_loss = 0.02551, val_total_loss = 0.10988 [4.7s]
# [Epoch 435] forecast_loss = 0.02446, recon_loss = 0.02521, total_loss = 0.04967 ---- val_forecast_loss = 0.08505, val_recon_loss = 0.02527, val_total_loss = 0.11033 [4.6s]
# [Epoch 436] forecast_loss = 0.02374, recon_loss = 0.02398, total_loss = 0.04772 ---- val_forecast_loss = 0.08501, val_recon_loss = 0.02713, val_total_loss = 0.11214 [4.7s]
# [Epoch 437] forecast_loss = 0.02473, recon_loss = 0.02440, total_loss = 0.04913 ---- val_forecast_loss = 0.08448, val_recon_loss = 0.02546, val_total_loss = 0.10994 [4.6s]
# [Epoch 438] forecast_loss = 0.02555, recon_loss = 0.02404, total_loss = 0.04959 ---- val_forecast_loss = 0.08500, val_recon_loss = 0.02512, val_total_loss = 0.11012 [4.7s]
# [Epoch 439] forecast_loss = 0.02402, recon_loss = 0.02377, total_loss = 0.04778 ---- val_forecast_loss = 0.08431, val_recon_loss = 0.02585, val_total_loss = 0.11016 [4.6s]
# [Epoch 440] forecast_loss = 0.02450, recon_loss = 0.02379, total_loss = 0.04829 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.02575, val_total_loss = 0.10947 [4.6s]
# [Epoch 441] forecast_loss = 0.02379, recon_loss = 0.02398, total_loss = 0.04777 ---- val_forecast_loss = 0.08384, val_recon_loss = 0.02517, val_total_loss = 0.10901 [4.6s]
# [Epoch 442] forecast_loss = 0.02422, recon_loss = 0.02386, total_loss = 0.04808 ---- val_forecast_loss = 0.08418, val_recon_loss = 0.02619, val_total_loss = 0.11037 [4.6s]
# [Epoch 443] forecast_loss = 0.02396, recon_loss = 0.02376, total_loss = 0.04771 ---- val_forecast_loss = 0.08468, val_recon_loss = 0.02516, val_total_loss = 0.10985 [4.6s]
# [Epoch 444] forecast_loss = 0.02369, recon_loss = 0.02359, total_loss = 0.04728 ---- val_forecast_loss = 0.08424, val_recon_loss = 0.02505, val_total_loss = 0.10929 [4.9s]
# [Epoch 445] forecast_loss = 0.02376, recon_loss = 0.02386, total_loss = 0.04762 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.02489, val_total_loss = 0.10862 [4.6s]
# [Epoch 446] forecast_loss = 0.02391, recon_loss = 0.02353, total_loss = 0.04744 ---- val_forecast_loss = 0.08574, val_recon_loss = 0.02646, val_total_loss = 0.11220 [4.6s]
# [Epoch 447] forecast_loss = 0.02642, recon_loss = 0.02471, total_loss = 0.05113 ---- val_forecast_loss = 0.08388, val_recon_loss = 0.02515, val_total_loss = 0.10903 [4.7s]
# [Epoch 448] forecast_loss = 0.02422, recon_loss = 0.02401, total_loss = 0.04823 ---- val_forecast_loss = 0.08537, val_recon_loss = 0.02539, val_total_loss = 0.11076 [4.8s]
# [Epoch 449] forecast_loss = 0.02418, recon_loss = 0.02367, total_loss = 0.04785 ---- val_forecast_loss = 0.08504, val_recon_loss = 0.02472, val_total_loss = 0.10976 [4.7s]
# [Epoch 450] forecast_loss = 0.02374, recon_loss = 0.02366, total_loss = 0.04740 ---- val_forecast_loss = 0.08364, val_recon_loss = 0.02468, val_total_loss = 0.10832 [4.6s]
# [Epoch 451] forecast_loss = 0.02388, recon_loss = 0.02344, total_loss = 0.04732 ---- val_forecast_loss = 0.08520, val_recon_loss = 0.02574, val_total_loss = 0.11095 [4.6s]
# [Epoch 452] forecast_loss = 0.02455, recon_loss = 0.02369, total_loss = 0.04824 ---- val_forecast_loss = 0.08444, val_recon_loss = 0.02480, val_total_loss = 0.10924 [4.6s]
# [Epoch 453] forecast_loss = 0.02425, recon_loss = 0.02379, total_loss = 0.04804 ---- val_forecast_loss = 0.08355, val_recon_loss = 0.02471, val_total_loss = 0.10826 [4.6s]
# [Epoch 454] forecast_loss = 0.02511, recon_loss = 0.02646, total_loss = 0.05157 ---- val_forecast_loss = 0.08395, val_recon_loss = 0.02478, val_total_loss = 0.10873 [4.6s]
# [Epoch 455] forecast_loss = 0.02397, recon_loss = 0.02368, total_loss = 0.04765 ---- val_forecast_loss = 0.08500, val_recon_loss = 0.02413, val_total_loss = 0.10913 [4.6s]
# [Epoch 456] forecast_loss = 0.02430, recon_loss = 0.02368, total_loss = 0.04798 ---- val_forecast_loss = 0.08444, val_recon_loss = 0.02511, val_total_loss = 0.10955 [4.6s]
# [Epoch 457] forecast_loss = 0.02399, recon_loss = 0.02343, total_loss = 0.04742 ---- val_forecast_loss = 0.08444, val_recon_loss = 0.02491, val_total_loss = 0.10935 [4.7s]
# [Epoch 458] forecast_loss = 0.02407, recon_loss = 0.02346, total_loss = 0.04754 ---- val_forecast_loss = 0.08486, val_recon_loss = 0.02482, val_total_loss = 0.10968 [4.6s]
# [Epoch 459] forecast_loss = 0.02466, recon_loss = 0.02445, total_loss = 0.04911 ---- val_forecast_loss = 0.08460, val_recon_loss = 0.02445, val_total_loss = 0.10905 [4.6s]
# [Epoch 460] forecast_loss = 0.02355, recon_loss = 0.02332, total_loss = 0.04687 ---- val_forecast_loss = 0.08473, val_recon_loss = 0.02593, val_total_loss = 0.11067 [4.6s]
# [Epoch 461] forecast_loss = 0.02450, recon_loss = 0.02368, total_loss = 0.04818 ---- val_forecast_loss = 0.08510, val_recon_loss = 0.02543, val_total_loss = 0.11054 [4.6s]
# [Epoch 462] forecast_loss = 0.02496, recon_loss = 0.02802, total_loss = 0.05298 ---- val_forecast_loss = 0.08396, val_recon_loss = 0.02515, val_total_loss = 0.10911 [4.8s]
# [Epoch 463] forecast_loss = 0.02357, recon_loss = 0.02321, total_loss = 0.04679 ---- val_forecast_loss = 0.08501, val_recon_loss = 0.02405, val_total_loss = 0.10906 [4.6s]
# [Epoch 464] forecast_loss = 0.02380, recon_loss = 0.02344, total_loss = 0.04724 ---- val_forecast_loss = 0.08437, val_recon_loss = 0.02434, val_total_loss = 0.10872 [4.6s]
# [Epoch 465] forecast_loss = 0.02386, recon_loss = 0.02314, total_loss = 0.04700 ---- val_forecast_loss = 0.08474, val_recon_loss = 0.02473, val_total_loss = 0.10947 [4.7s]
# [Epoch 466] forecast_loss = 0.02328, recon_loss = 0.02327, total_loss = 0.04656 ---- val_forecast_loss = 0.08394, val_recon_loss = 0.02438, val_total_loss = 0.10831 [4.6s]
# [Epoch 467] forecast_loss = 0.02453, recon_loss = 0.02321, total_loss = 0.04774 ---- val_forecast_loss = 0.08477, val_recon_loss = 0.02429, val_total_loss = 0.10906 [4.6s]
# [Epoch 468] forecast_loss = 0.02388, recon_loss = 0.02324, total_loss = 0.04712 ---- val_forecast_loss = 0.08506, val_recon_loss = 0.02455, val_total_loss = 0.10961 [4.6s]
# [Epoch 469] forecast_loss = 0.02374, recon_loss = 0.02300, total_loss = 0.04674 ---- val_forecast_loss = 0.08485, val_recon_loss = 0.02465, val_total_loss = 0.10951 [4.6s]
# [Epoch 470] forecast_loss = 0.02370, recon_loss = 0.02341, total_loss = 0.04711 ---- val_forecast_loss = 0.08516, val_recon_loss = 0.02460, val_total_loss = 0.10975 [4.7s]
# [Epoch 471] forecast_loss = 0.02403, recon_loss = 0.02781, total_loss = 0.05184 ---- val_forecast_loss = 0.08575, val_recon_loss = 0.05508, val_total_loss = 0.14083 [4.6s]
# [Epoch 472] forecast_loss = 0.02505, recon_loss = 0.03072, total_loss = 0.05578 ---- val_forecast_loss = 0.08463, val_recon_loss = 0.02604, val_total_loss = 0.11067 [4.6s]
# [Epoch 473] forecast_loss = 0.02387, recon_loss = 0.02431, total_loss = 0.04817 ---- val_forecast_loss = 0.08436, val_recon_loss = 0.02480, val_total_loss = 0.10916 [4.6s]
# [Epoch 474] forecast_loss = 0.02308, recon_loss = 0.02353, total_loss = 0.04661 ---- val_forecast_loss = 0.08509, val_recon_loss = 0.02427, val_total_loss = 0.10935 [4.6s]
# [Epoch 475] forecast_loss = 0.02386, recon_loss = 0.02363, total_loss = 0.04750 ---- val_forecast_loss = 0.08413, val_recon_loss = 0.02426, val_total_loss = 0.10839 [4.6s]
# [Epoch 476] forecast_loss = 0.02438, recon_loss = 0.02362, total_loss = 0.04800 ---- val_forecast_loss = 0.08413, val_recon_loss = 0.02769, val_total_loss = 0.11183 [4.7s]
# [Epoch 477] forecast_loss = 0.02504, recon_loss = 0.02414, total_loss = 0.04918 ---- val_forecast_loss = 0.08456, val_recon_loss = 0.02536, val_total_loss = 0.10992 [4.6s]
# [Epoch 478] forecast_loss = 0.02384, recon_loss = 0.02298, total_loss = 0.04681 ---- val_forecast_loss = 0.08470, val_recon_loss = 0.02415, val_total_loss = 0.10885 [4.6s]
# [Epoch 479] forecast_loss = 0.02285, recon_loss = 0.02300, total_loss = 0.04585 ---- val_forecast_loss = 0.08447, val_recon_loss = 0.02468, val_total_loss = 0.10915 [4.6s]
# [Epoch 480] forecast_loss = 0.02411, recon_loss = 0.02314, total_loss = 0.04725 ---- val_forecast_loss = 0.08446, val_recon_loss = 0.02480, val_total_loss = 0.10926 [4.9s]
# [Epoch 481] forecast_loss = 0.02344, recon_loss = 0.02342, total_loss = 0.04686 ---- val_forecast_loss = 0.08409, val_recon_loss = 0.02460, val_total_loss = 0.10869 [4.8s]
# [Epoch 482] forecast_loss = 0.02388, recon_loss = 0.02334, total_loss = 0.04722 ---- val_forecast_loss = 0.08487, val_recon_loss = 0.02453, val_total_loss = 0.10940 [4.6s]
# [Epoch 483] forecast_loss = 0.02415, recon_loss = 0.02723, total_loss = 0.05138 ---- val_forecast_loss = 0.08457, val_recon_loss = 0.02450, val_total_loss = 0.10907 [4.6s]
# [Epoch 484] forecast_loss = 0.02426, recon_loss = 0.02349, total_loss = 0.04775 ---- val_forecast_loss = 0.08382, val_recon_loss = 0.02406, val_total_loss = 0.10788 [4.7s]
# [Epoch 485] forecast_loss = 0.02443, recon_loss = 0.02313, total_loss = 0.04756 ---- val_forecast_loss = 0.08464, val_recon_loss = 0.02393, val_total_loss = 0.10857 [4.6s]
# [Epoch 486] forecast_loss = 0.02352, recon_loss = 0.02304, total_loss = 0.04656 ---- val_forecast_loss = 0.08532, val_recon_loss = 0.02450, val_total_loss = 0.10981 [4.7s]
# [Epoch 487] forecast_loss = 0.02387, recon_loss = 0.02276, total_loss = 0.04662 ---- val_forecast_loss = 0.08510, val_recon_loss = 0.02409, val_total_loss = 0.10919 [4.7s]
# [Epoch 488] forecast_loss = 0.02314, recon_loss = 0.02293, total_loss = 0.04606 ---- val_forecast_loss = 0.08346, val_recon_loss = 0.02487, val_total_loss = 0.10833 [4.6s]
# [Epoch 489] forecast_loss = 0.02324, recon_loss = 0.02327, total_loss = 0.04651 ---- val_forecast_loss = 0.08439, val_recon_loss = 0.02500, val_total_loss = 0.10939 [4.6s]
# [Epoch 490] forecast_loss = 0.02406, recon_loss = 0.02315, total_loss = 0.04721 ---- val_forecast_loss = 0.08639, val_recon_loss = 0.02523, val_total_loss = 0.11163 [4.6s]
# [Epoch 491] forecast_loss = 0.02343, recon_loss = 0.02286, total_loss = 0.04629 ---- val_forecast_loss = 0.08347, val_recon_loss = 0.02425, val_total_loss = 0.10771 [4.6s]
# [Epoch 492] forecast_loss = 0.02263, recon_loss = 0.02447, total_loss = 0.04711 ---- val_forecast_loss = 0.08496, val_recon_loss = 0.02743, val_total_loss = 0.11239 [4.6s]
# [Epoch 493] forecast_loss = 0.02325, recon_loss = 0.02351, total_loss = 0.04675 ---- val_forecast_loss = 0.08509, val_recon_loss = 0.02493, val_total_loss = 0.11002 [4.6s]
# [Epoch 494] forecast_loss = 0.02408, recon_loss = 0.02343, total_loss = 0.04751 ---- val_forecast_loss = 0.08414, val_recon_loss = 0.02545, val_total_loss = 0.10960 [5.5s]
# [Epoch 495] forecast_loss = 0.02407, recon_loss = 0.02332, total_loss = 0.04739 ---- val_forecast_loss = 0.08326, val_recon_loss = 0.02383, val_total_loss = 0.10709 [4.6s]
# [Epoch 496] forecast_loss = 0.02271, recon_loss = 0.02233, total_loss = 0.04504 ---- val_forecast_loss = 0.08482, val_recon_loss = 0.02378, val_total_loss = 0.10859 [4.7s]
# [Epoch 497] forecast_loss = 0.02301, recon_loss = 0.02291, total_loss = 0.04592 ---- val_forecast_loss = 0.08380, val_recon_loss = 0.02407, val_total_loss = 0.10787 [4.6s]
# [Epoch 498] forecast_loss = 0.02401, recon_loss = 0.02362, total_loss = 0.04763 ---- val_forecast_loss = 0.08458, val_recon_loss = 0.02441, val_total_loss = 0.10899 [4.6s]
# [Epoch 499] forecast_loss = 0.02339, recon_loss = 0.02280, total_loss = 0.04619 ---- val_forecast_loss = 0.08503, val_recon_loss = 0.02446, val_total_loss = 0.10949 [4.6s]
# [Epoch 500] forecast_loss = 0.02259, recon_loss = 0.02312, total_loss = 0.04571 ---- val_forecast_loss = 0.08433, val_recon_loss = 0.02435, val_total_loss = 0.10868 [4.7s]
# -- Training done in 2335s.
