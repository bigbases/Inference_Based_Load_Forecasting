# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/Capstone')

import pandas as pd
import numpy as np

import json
from datetime import datetime
import torch.nn as nn

from utils import *
from mtad_gat import MTAD_GAT

import os
import time
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
# Out:
# Mounted at /content/drive

# %%
class CustomDataset(Dataset):
    def __init__(self, data, target):
        self.data = data
        self.target = target

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index], self.target[index]

class Trainer:
    """Trainer class for MTAD-GAT model.

    :param model: MTAD-GAT model
    :param optimizer: Optimizer used to minimize the loss function
    :param window_size: Length of the input sequence
    :param n_features: Number of input features
    :param target_dims: dimension of input features to forecast and reconstruct
    :param n_epochs: Number of iterations/epochs
    :param batch_size: Number of windows in a single batch
    :param init_lr: Initial learning rate of the module
    :param forecast_criterion: Loss to be used for forecasting.
    :param recon_criterion: Loss to be used for reconstruction.
    :param boolean use_cuda: To be run on GPU or not
    :param dload: Download directory where models are to be dumped
    :param log_dir: Directory where SummaryWriter logs are written to
    :param print_every: At what epoch interval to print losses
    :param log_tensorboard: Whether to log loss++ to tensorboard
    :param args_summary: Summary of args that will also be written to tensorboard if log_tensorboard
    """

    def __init__(
        self,
        model,
        optimizer,
        window_size,
        n_features,
        target_dims=None,
        n_epochs=200,
        batch_size=32,
        init_lr=0.001,
        forecast_criterion=nn.MSELoss(),
        recon_criterion=nn.MSELoss(),
        use_cuda=True,
        dload="",
        log_dir="output/",
        print_every=1,
        log_tensorboard=True,
        args_summary="",
    ):

        self.model = model
        self.optimizer = optimizer
        self.window_size = window_size
        self.n_features = n_features
        self.target_dims = target_dims
        self.n_epochs = n_epochs
        self.batch_size = batch_size
        self.init_lr = init_lr
        self.forecast_criterion = forecast_criterion
        self.recon_criterion = recon_criterion
        self.device = "cuda" if use_cuda and torch.cuda.is_available() else "cpu"
        self.dload = dload
        self.log_dir = log_dir
        self.print_every = print_every
        self.log_tensorboard = log_tensorboard

        self.losses = {
            "train_total": [],
            "train_forecast": [],
            "train_recon": [],
            "val_total": [],
            "val_forecast": [],
            "val_recon": [],
        }
        self.epoch_times = []

        if self.device == "cuda":
            self.model.cuda()

        if self.log_tensorboard:
            self.writer = SummaryWriter(f"{log_dir}")
            self.writer.add_text("args_summary", args_summary)

    def fit(self, train_loader, val_loader=None):
        """Train model for self.n_epochs.
        Train and validation (if validation loader given) losses stored in self.losses

        :param train_loader: train loader of input data
        :param val_loader: validation loader of input data
        """

        init_train_loss = self.evaluate(train_loader)
        print(f"Init total train loss: {init_train_loss[2]:5f}")

        if val_loader is not None:
            init_val_loss = self.evaluate(val_loader)
            print(f"Init total val loss: {init_val_loss[2]:.5f}")

        print(f"Training model for {self.n_epochs} epochs..")
        train_start = time.time()
        for epoch in range(self.n_epochs):
            epoch_start = time.time()
            self.model.train()
            forecast_b_losses = []
            recon_b_losses = []

            for x, y in train_loader:
                x = x.to(self.device).float() # 32,56,1080?????
                y = y.to(self.device).float()
                self.optimizer.zero_grad()

                preds, recons, _, _ = self.model(x)
                # print('pp')
                if self.target_dims is not None:
                    x = x[:, :, self.target_dims]
                    y = y[:, :, self.target_dims].squeeze(-1)

                if preds.ndim == 3:
                    preds = preds.squeeze(1)
                if y.ndim == 3:
                    y = y.squeeze(1)

                forecast_loss = torch.sqrt(self.forecast_criterion(y, preds))
                recon_loss = torch.sqrt(self.recon_criterion(x, recons))
                loss = forecast_loss + recon_loss

                loss.backward()
                self.optimizer.step()

                forecast_b_losses.append(forecast_loss.item())
                recon_b_losses.append(recon_loss.item())

            forecast_b_losses = np.array(forecast_b_losses)
            recon_b_losses = np.array(recon_b_losses)

            forecast_epoch_loss = np.sqrt((forecast_b_losses ** 2).mean())
            recon_epoch_loss = np.sqrt((recon_b_losses ** 2).mean())

            total_epoch_loss = forecast_epoch_loss + recon_epoch_loss

            self.losses["train_forecast"].append(forecast_epoch_loss)
            self.losses["train_recon"].append(recon_epoch_loss)
            self.losses["train_total"].append(total_epoch_loss)

            # Evaluate on validation set
            forecast_val_loss, recon_val_loss, total_val_loss = "NA", "NA", "NA"
            if val_loader is not None:
                forecast_val_loss, recon_val_loss, total_val_loss = self.evaluate(val_loader)
                self.losses["val_forecast"].append(forecast_val_loss)
                self.losses["val_recon"].append(recon_val_loss)
                self.losses["val_total"].append(total_val_loss)

                if total_val_loss <= self.losses["val_total"][-1]:
                    self.save(f"model.pt")

            if self.log_tensorboard:
                self.write_loss(epoch)

            epoch_time = time.time() - epoch_start
            self.epoch_times.append(epoch_time)

            if epoch % self.print_every == 0:
                s = (
                    f"[Epoch {epoch + 1}] "
                    f"forecast_loss = {forecast_epoch_loss:.5f}, "
                    f"recon_loss = {recon_epoch_loss:.5f}, "
                    f"total_loss = {total_epoch_loss:.5f}"
                )

                if val_loader is not None:
                    s += (
                        f" ---- val_forecast_loss = {forecast_val_loss:.5f}, "
                        f"val_recon_loss = {recon_val_loss:.5f}, "
                        f"val_total_loss = {total_val_loss:.5f}"
                    )

                s += f" [{epoch_time:.1f}s]"
                print(s)

        if val_loader is None:
            self.save(f"model.pt")

        train_time = int(time.time() - train_start)
        if self.log_tensorboard:
            self.writer.add_text("total_train_time", str(train_time))
        print(f"-- Training done in {train_time}s.")

    def evaluate(self, data_loader):
        """Evaluate model

        :param data_loader: data loader of input data
        :return forecasting loss, reconstruction loss, total loss
        """

        self.model.eval()

        forecast_losses = []
        recon_losses = []

        with torch.no_grad():
            for x, y in data_loader:
                x = x.to(self.device)
                y = y.to(self.device)
                x = x.to(self.device).float() # 32,56,1080?????
                y = y.to(self.device).float()

                preds, recons, _, _ = self.model(x)

                if self.target_dims is not None:
                    x = x[:, :, self.target_dims]
                    y = y[:, :, self.target_dims].squeeze(-1)

                if preds.ndim == 3:
                    preds = preds.squeeze(1)
                if y.ndim == 3:
                    y = y.squeeze(1)
                # print('aa')
#                 print(y.shape, preds.shape)
#                 print(y.shape) # 32,1
#                 print(preds.shape) # 32,1
#                 print(recons.shape) # 32,28,3
                forecast_loss = torch.sqrt(self.forecast_criterion(y, preds))
                recon_loss = torch.sqrt(self.recon_criterion(x, recons))

                forecast_losses.append(forecast_loss.item())
                recon_losses.append(recon_loss.item())

        forecast_losses = np.array(forecast_losses)
        recon_losses = np.array(recon_losses)

        forecast_loss = np.sqrt((forecast_losses ** 2).mean())
        recon_loss = np.sqrt((recon_losses ** 2).mean())

        total_loss = forecast_loss + recon_loss

        return forecast_loss, recon_loss, total_loss

    def save(self, file_name):
        """
        Pickles the model parameters to be retrieved later
        :param file_name: the filename to be saved as,`dload` serves as the download directory
        """
        PATH = self.dload + "/" + file_name
        if os.path.exists(self.dload):
            pass
        else:
            os.mkdir(self.dload)
        torch.save(self.model.state_dict(), PATH)

    def load(self, PATH):
        """
        Loads the model's parameters from the path mentioned
        :param PATH: Should contain pickle file
        """
        self.model.load_state_dict(torch.load(PATH, map_location=self.device))

    def write_loss(self, epoch):
        for key, value in self.losses.items():
            if len(value) != 0:
                self.writer.add_scalar(key, value[-1], epoch)

# %%
# dataset load
# 전기
elec_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/elec_clustering_train.csv', index_col=0)
elec_train.index = pd.to_datetime(elec_train.index)
elec_train = elec_train.resample(rule='12H').sum()
elec_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/elec_clustering_test.csv', index_col=0)
elec_test.index = pd.to_datetime(elec_test.index)
elec_test = elec_test.resample(rule='12H').sum()
elec_total = pd.concat([elec_train,elec_test],axis=1)
# 수도
water_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/water_clustering_train.csv', index_col=0)
water_train.index = pd.to_datetime(water_train.index)
water_train = water_train.resample(rule='12H').sum()
water_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/water_clustering_test.csv', index_col=0)
water_test.index = pd.to_datetime(water_test.index)
water_test = water_test.resample(rule='12H').sum()
water_total = pd.concat([water_train,water_test],axis=1)
#가스
gas_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/gas_clustering_train.csv', index_col=0)
gas_train.index = pd.to_datetime(gas_train.index)
gas_train = gas_train.resample(rule='12H').sum()
gas_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/gas_clustering_test.csv', index_col=0)
gas_test.index = pd.to_datetime(gas_test.index)
gas_test = gas_test.resample(rule='12H').sum()
gas_total = pd.concat([gas_train,gas_test],axis=1)
#온수
hotwater_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/hotwater_clustering_train.csv', index_col=0)
hotwater_train.index = pd.to_datetime(hotwater_train.index)
hotwater_train = hotwater_train.resample(rule='12H').sum()
hotwater_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/data/hotwater_clustering_test.csv', index_col=0)
hotwater_test.index = pd.to_datetime(hotwater_test.index)
hotwater_test = hotwater_test.resample(rule='12H').sum()
hotwater_total = pd.concat([hotwater_train,hotwater_test],axis=1)

# %%
region_A = elec_train.columns
region_B = elec_test.columns

train_index = 504*2
test_index = (504+28)*2
cluster_index = (504+28+28)*2

energy_A = elec_total.reset_index(drop=True)
energy_B = water_total.reset_index(drop=True)
energy_C = hotwater_total.reset_index(drop=True)
energy_target = gas_total.reset_index(drop=True)

train_A = energy_A[:train_index]
train_B = energy_B[:train_index]
train_C = energy_C[:train_index]
train_target = energy_target[:train_index+1]
test_A = energy_A[train_index:test_index+1]
test_B = energy_B[train_index:test_index+1]
test_C = energy_C[train_index:test_index+1]
test_target = energy_target[train_index:test_index+1]
cluster_A = energy_A[test_index:cluster_index+1]
cluster_B = energy_B[test_index:cluster_index+1]
cluster_C = energy_C[test_index:cluster_index+1]
cluster_target = energy_target[test_index:cluster_index+1]

scaler_A = MinMaxScaler()
scaler_B = MinMaxScaler()
scaler_C = MinMaxScaler()
scaler_target = MinMaxScaler()
train_A = pd.DataFrame(scaler_A.fit_transform(train_A))
train_B = pd.DataFrame(scaler_B.fit_transform(train_B))
train_C = pd.DataFrame(scaler_C.fit_transform(train_C))
train_target = pd.DataFrame(scaler_target.fit_transform(train_target))
test_A = pd.DataFrame(scaler_A.transform(test_A))
test_B = pd.DataFrame(scaler_B.transform(test_B))
test_C = pd.DataFrame(scaler_C.transform(test_C))
test_target = pd.DataFrame(scaler_target.transform(test_target))
cluster_A = pd.DataFrame(scaler_A.transform(cluster_A))
cluster_B = pd.DataFrame(scaler_B.transform(cluster_B))
cluster_C = pd.DataFrame(scaler_C.transform(cluster_C))
cluster_target = pd.DataFrame(scaler_target.transform(cluster_target))

# 2-5 표현 생성
idx = 14
repr1_A = energy_A[train_index+idx:test_index+1+idx]
repr1_B = energy_B[train_index+idx:test_index+1+idx]
repr1_C = energy_C[train_index+idx:test_index+1+idx]
repr1_target = energy_target[train_index+idx:test_index+1+idx]

repr1_A = pd.DataFrame(scaler_A.transform(repr1_A))
repr1_B = pd.DataFrame(scaler_B.transform(repr1_B))
repr1_C = pd.DataFrame(scaler_C.transform(repr1_C))
repr1_target = pd.DataFrame(scaler_target.transform(repr1_target))

X_repr1 = []
y_repr1 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr1_A.iloc[period,user],repr1_B.iloc[period,user],repr1_C.iloc[period,user]])
        y_window.append(repr1_A.iloc[period+1,user])
        X_repr1.append(X_window)
        y_repr1.append(y_window)

# 3-6 표현 생성
repr2_A = energy_A[train_index+idx*2:test_index+1+idx*2]
repr2_B = energy_B[train_index+idx*2:test_index+1+idx*2]
repr2_C = energy_C[train_index+idx*2:test_index+1+idx*2]
repr2_target = energy_target[train_index+idx*2:test_index+1+idx*2]

repr2_A = pd.DataFrame(scaler_A.transform(repr2_A))
repr2_B = pd.DataFrame(scaler_B.transform(repr2_B))
repr2_C = pd.DataFrame(scaler_C.transform(repr2_C))
repr2_target = pd.DataFrame(scaler_target.transform(repr2_target))

X_repr2 = []
y_repr2 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr2_A.iloc[period,user],repr2_B.iloc[period,user],repr2_C.iloc[period,user]])
        y_window.append(repr2_A.iloc[period+1,user])
        X_repr2.append(X_window)
        y_repr2.append(y_window)

# 4-7 표현 생성
repr3_A = energy_A[train_index+idx*3:test_index+1+idx*3]
repr3_B = energy_B[train_index+idx*3:test_index+1+idx*3]
repr3_C = energy_C[train_index+idx*3:test_index+1+idx*3]
repr3_target = energy_target[train_index+idx*3:test_index+1+idx*3]

repr3_A = pd.DataFrame(scaler_A.transform(repr3_A))
repr3_B = pd.DataFrame(scaler_B.transform(repr3_B))
repr3_C = pd.DataFrame(scaler_C.transform(repr3_C))
repr3_target = pd.DataFrame(scaler_target.transform(repr3_target))

X_repr3 = []
y_repr3 = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([repr3_A.iloc[period,user],repr3_B.iloc[period,user],repr3_C.iloc[period,user]])
        y_window.append(repr3_A.iloc[period+1,user])
        X_repr3.append(X_window)
        y_repr3.append(y_window)

X_train = []
y_train = []
for user in range(elec_total.shape[1]):
    for index in range(0,elec_total.shape[0]//(28*2)-3):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([train_A.iloc[period,user],train_B.iloc[period,user],train_C.iloc[period,user]])
        y_window.append(train_A.iloc[period+1,user])
        X_train.append(X_window)
        y_train.append(y_window)

X_test = []
y_test = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([test_A.iloc[period,user],test_B.iloc[period,user],test_C.iloc[period,user]])
        y_window.append(test_A.iloc[period+1,user])
        X_test.append(X_window)
        y_test.append(y_window)

X_cluster = []
y_cluster = []
for user in range(elec_total.shape[1]):
    for index in range(0,1):
        X_window = []
        y_window = []
        for period in range(index*28*2,(index+1)*28*2):
            X_window.append([cluster_A.iloc[period,user],cluster_B.iloc[period,user],cluster_C.iloc[period,user]])
        y_window.append(cluster_A.iloc[period+1,user])
        X_cluster.append(X_window)
        y_cluster.append(y_window)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
X_cluster = np.array(X_cluster)
y_cluster = np.array(y_cluster)

X_repr1 = np.array(X_repr1)
y_repr1 = np.array(y_repr1)
X_repr2 = np.array(X_repr2)
y_repr2 = np.array(y_repr2)
X_repr3 = np.array(X_repr3)
y_repr3 = np.array(y_repr3)

train_ds = CustomDataset(X_train, y_train)
valid_ds = CustomDataset(X_test, y_test) # 이게 test set

train_loader, val_loader, test_loader = create_data_loaders(
        train_ds, batch_size=32, val_split=0.2, shuffle=False, test_dataset=valid_ds
    )

id = datetime.now().strftime("%d%m%Y_%H%M%S")
# Out:
# train_size: 14688
# validation_size: 3672
# test_size: 1080

# %%
window_size = 28*2
n_epochs = 500 #30
batch_size = 32
init_lr = 1e-3
print_every = 1
log_tensorboard = True

n_features=X_train.shape[2]
window_size=window_size
out_dim=X_train.shape[2]
kernel_size=3
use_gatv2=True
feat_gat_embed_dim=None
time_gat_embed_dim=None
gru_n_layers=1
gru_hid_dim=256
forecast_n_layers=2
forecast_hid_dim=512
recon_n_layers=2
recon_hid_dim=128
dropout=0.2
alpha=0.2

num = 0
model = MTAD_GAT(
    n_features=n_features,
    window_size=window_size,
    out_dim=out_dim,
    kernel_size=kernel_size,
    use_gatv2=True,
    feat_gat_embed_dim=None,
    time_gat_embed_dim=None,
    gru_n_layers=gru_n_layers,
    gru_hid_dim=gru_hid_dim,
    forecast_n_layers=forecast_n_layers,
    forecast_hid_dim=forecast_hid_dim,
    recon_n_layers=recon_n_layers,
    recon_hid_dim=recon_hid_dim,
    dropout=0.2,
    alpha=0.2
)

optimizer = torch.optim.Adam(model.parameters(), lr=init_lr)
forecast_criterion = nn.MSELoss()
recon_criterion = nn.MSELoss()

trainer = Trainer(
    model=model,
    optimizer=optimizer,
    window_size=window_size,
    n_features=n_features,
    n_epochs=n_epochs,
    batch_size=batch_size,
    init_lr=init_lr,
    forecast_criterion=forecast_criterion,
    recon_criterion=recon_criterion,
    use_cuda=True,
    print_every=1,
    log_dir="/logs",
    dload="/result"
)

trainer.fit(train_loader, val_loader)

# hidden representations생성
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
forecast_criterion=nn.MSELoss()
recon_criterion=nn.MSELoss()

repr1_ds = CustomDataset(X_repr1, y_repr1) # 이게 repr1 set
repr1set_loader = torch.utils.data.DataLoader(repr1_ds, batch_size=32)

repr2_ds = CustomDataset(X_repr2, y_repr2) # 이게 repr2 set
repr2set_loader = torch.utils.data.DataLoader(repr2_ds, batch_size=32)

repr3_ds = CustomDataset(X_repr3, y_repr3) # 이게 repr3 set
repr3set_loader = torch.utils.data.DataLoader(repr3_ds, batch_size=32)

for idx, loader in enumerate([repr1set_loader, repr2set_loader, repr3set_loader]):

    hidden_test = []
    h_r_test = []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device).float()
            y = y.to(device).float()

            preds, recons, h, h_r = model(x)

            if preds.ndim == 3:
                preds = preds.squeeze(1)
            if y.ndim == 3:
                y = y.squeeze(1)

            hidden_test.append(h.cpu())
            h_r_test.append(h_r.cpu())

    hidden_test_ = [np.array(i.cpu().squeeze()) for j in hidden_test for i in j]
    hidden_test_ = np.array(hidden_test_)
    hidden_test_ = pd.DataFrame(hidden_test_, index = elec_total.columns)
    h_r_test_ = [np.array(i.cpu().squeeze()) for j in h_r_test for i in j]
    h_r_test_ = np.array(h_r_test_).reshape(1080,-1)
    h_r_test_ = pd.DataFrame(h_r_test_, index = elec_total.columns)
    hidden_test_.to_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/result/graph_gas/arr_{}_{}.csv'.format(idx+1, num))
    h_r_test_.to_csv('/content/drive/MyDrive/Colab Notebooks/Capstone/result/graph_gas/h_r_{}_{}.csv'.format(idx+1, num))
# Out:
# Init total train loss: 0.479140
# Init total val loss: 0.48109
# Training model for 500 epochs..
# [Epoch 1] forecast_loss = 0.09618, recon_loss = 0.15436, total_loss = 0.25055 ---- val_forecast_loss = 0.08770, val_recon_loss = 0.14515, val_total_loss = 0.23285 [5.9s]
# [Epoch 2] forecast_loss = 0.08858, recon_loss = 0.13703, total_loss = 0.22562 ---- val_forecast_loss = 0.08842, val_recon_loss = 0.13465, val_total_loss = 0.22306 [4.6s]
# [Epoch 3] forecast_loss = 0.08619, recon_loss = 0.13048, total_loss = 0.21667 ---- val_forecast_loss = 0.08308, val_recon_loss = 0.12996, val_total_loss = 0.21304 [4.7s]
# [Epoch 4] forecast_loss = 0.08051, recon_loss = 0.12616, total_loss = 0.20667 ---- val_forecast_loss = 0.07990, val_recon_loss = 0.12778, val_total_loss = 0.20768 [4.5s]
# [Epoch 5] forecast_loss = 0.07941, recon_loss = 0.12320, total_loss = 0.20261 ---- val_forecast_loss = 0.07966, val_recon_loss = 0.12421, val_total_loss = 0.20387 [4.6s]
# [Epoch 6] forecast_loss = 0.07842, recon_loss = 0.12151, total_loss = 0.19993 ---- val_forecast_loss = 0.08062, val_recon_loss = 0.12140, val_total_loss = 0.20202 [4.7s]
# [Epoch 7] forecast_loss = 0.07797, recon_loss = 0.12000, total_loss = 0.19797 ---- val_forecast_loss = 0.07937, val_recon_loss = 0.12020, val_total_loss = 0.19957 [4.5s]
# [Epoch 8] forecast_loss = 0.07780, recon_loss = 0.11809, total_loss = 0.19589 ---- val_forecast_loss = 0.07945, val_recon_loss = 0.11878, val_total_loss = 0.19824 [4.6s]
# [Epoch 9] forecast_loss = 0.07707, recon_loss = 0.11645, total_loss = 0.19352 ---- val_forecast_loss = 0.08239, val_recon_loss = 0.11694, val_total_loss = 0.19933 [4.6s]
# [Epoch 10] forecast_loss = 0.07732, recon_loss = 0.11472, total_loss = 0.19204 ---- val_forecast_loss = 0.07879, val_recon_loss = 0.11577, val_total_loss = 0.19456 [4.5s]
# [Epoch 11] forecast_loss = 0.07690, recon_loss = 0.11307, total_loss = 0.18997 ---- val_forecast_loss = 0.08010, val_recon_loss = 0.11478, val_total_loss = 0.19488 [4.6s]
# [Epoch 12] forecast_loss = 0.07684, recon_loss = 0.11168, total_loss = 0.18852 ---- val_forecast_loss = 0.07857, val_recon_loss = 0.11173, val_total_loss = 0.19030 [4.5s]
# [Epoch 13] forecast_loss = 0.07609, recon_loss = 0.11113, total_loss = 0.18723 ---- val_forecast_loss = 0.08053, val_recon_loss = 0.11233, val_total_loss = 0.19285 [4.6s]
# [Epoch 14] forecast_loss = 0.07524, recon_loss = 0.10930, total_loss = 0.18454 ---- val_forecast_loss = 0.07880, val_recon_loss = 0.10949, val_total_loss = 0.18829 [4.6s]
# [Epoch 15] forecast_loss = 0.07489, recon_loss = 0.10794, total_loss = 0.18283 ---- val_forecast_loss = 0.07845, val_recon_loss = 0.10780, val_total_loss = 0.18624 [4.6s]
# [Epoch 16] forecast_loss = 0.07422, recon_loss = 0.10610, total_loss = 0.18031 ---- val_forecast_loss = 0.07793, val_recon_loss = 0.10567, val_total_loss = 0.18360 [4.6s]
# [Epoch 17] forecast_loss = 0.07302, recon_loss = 0.10478, total_loss = 0.17779 ---- val_forecast_loss = 0.07903, val_recon_loss = 0.10469, val_total_loss = 0.18372 [4.6s]
# [Epoch 18] forecast_loss = 0.07344, recon_loss = 0.10457, total_loss = 0.17801 ---- val_forecast_loss = 0.07944, val_recon_loss = 0.10395, val_total_loss = 0.18339 [4.6s]
# [Epoch 19] forecast_loss = 0.07331, recon_loss = 0.10485, total_loss = 0.17816 ---- val_forecast_loss = 0.07918, val_recon_loss = 0.10304, val_total_loss = 0.18222 [4.6s]
# [Epoch 20] forecast_loss = 0.07176, recon_loss = 0.10098, total_loss = 0.17274 ---- val_forecast_loss = 0.07916, val_recon_loss = 0.10145, val_total_loss = 0.18062 [4.5s]
# [Epoch 21] forecast_loss = 0.07117, recon_loss = 0.09977, total_loss = 0.17094 ---- val_forecast_loss = 0.07883, val_recon_loss = 0.10010, val_total_loss = 0.17892 [4.6s]
# [Epoch 22] forecast_loss = 0.07267, recon_loss = 0.09928, total_loss = 0.17195 ---- val_forecast_loss = 0.07922, val_recon_loss = 0.09859, val_total_loss = 0.17781 [4.6s]
# [Epoch 23] forecast_loss = 0.07087, recon_loss = 0.09728, total_loss = 0.16815 ---- val_forecast_loss = 0.07964, val_recon_loss = 0.09780, val_total_loss = 0.17743 [4.6s]
# [Epoch 24] forecast_loss = 0.06914, recon_loss = 0.09574, total_loss = 0.16489 ---- val_forecast_loss = 0.07892, val_recon_loss = 0.09500, val_total_loss = 0.17391 [4.6s]
# [Epoch 25] forecast_loss = 0.06934, recon_loss = 0.09425, total_loss = 0.16358 ---- val_forecast_loss = 0.08129, val_recon_loss = 0.09516, val_total_loss = 0.17646 [4.6s]
# [Epoch 26] forecast_loss = 0.06846, recon_loss = 0.09298, total_loss = 0.16144 ---- val_forecast_loss = 0.08038, val_recon_loss = 0.09222, val_total_loss = 0.17260 [4.6s]
# [Epoch 27] forecast_loss = 0.06723, recon_loss = 0.09142, total_loss = 0.15864 ---- val_forecast_loss = 0.08097, val_recon_loss = 0.09250, val_total_loss = 0.17346 [4.6s]
# [Epoch 28] forecast_loss = 0.06646, recon_loss = 0.09036, total_loss = 0.15682 ---- val_forecast_loss = 0.08127, val_recon_loss = 0.09032, val_total_loss = 0.17159 [4.6s]
# [Epoch 29] forecast_loss = 0.06577, recon_loss = 0.08917, total_loss = 0.15494 ---- val_forecast_loss = 0.08141, val_recon_loss = 0.08888, val_total_loss = 0.17029 [4.7s]
# [Epoch 30] forecast_loss = 0.06514, recon_loss = 0.08867, total_loss = 0.15380 ---- val_forecast_loss = 0.08011, val_recon_loss = 0.08915, val_total_loss = 0.16927 [4.6s]
# [Epoch 31] forecast_loss = 0.06477, recon_loss = 0.08660, total_loss = 0.15137 ---- val_forecast_loss = 0.07983, val_recon_loss = 0.08918, val_total_loss = 0.16901 [4.5s]
# [Epoch 32] forecast_loss = 0.06436, recon_loss = 0.08583, total_loss = 0.15019 ---- val_forecast_loss = 0.08098, val_recon_loss = 0.08710, val_total_loss = 0.16808 [4.6s]
# [Epoch 33] forecast_loss = 0.06249, recon_loss = 0.08391, total_loss = 0.14640 ---- val_forecast_loss = 0.08236, val_recon_loss = 0.08515, val_total_loss = 0.16752 [4.6s]
# [Epoch 34] forecast_loss = 0.06323, recon_loss = 0.08273, total_loss = 0.14596 ---- val_forecast_loss = 0.08318, val_recon_loss = 0.08366, val_total_loss = 0.16683 [4.6s]
# [Epoch 35] forecast_loss = 0.06225, recon_loss = 0.08180, total_loss = 0.14406 ---- val_forecast_loss = 0.08204, val_recon_loss = 0.08627, val_total_loss = 0.16831 [4.6s]
# [Epoch 36] forecast_loss = 0.06127, recon_loss = 0.08073, total_loss = 0.14200 ---- val_forecast_loss = 0.08224, val_recon_loss = 0.08215, val_total_loss = 0.16439 [4.5s]
# [Epoch 37] forecast_loss = 0.06024, recon_loss = 0.07955, total_loss = 0.13978 ---- val_forecast_loss = 0.08263, val_recon_loss = 0.08051, val_total_loss = 0.16314 [4.5s]
# [Epoch 38] forecast_loss = 0.06007, recon_loss = 0.07861, total_loss = 0.13868 ---- val_forecast_loss = 0.08223, val_recon_loss = 0.08014, val_total_loss = 0.16237 [4.6s]
# [Epoch 39] forecast_loss = 0.05875, recon_loss = 0.07715, total_loss = 0.13590 ---- val_forecast_loss = 0.08009, val_recon_loss = 0.07824, val_total_loss = 0.15833 [4.5s]
# [Epoch 40] forecast_loss = 0.05810, recon_loss = 0.07629, total_loss = 0.13439 ---- val_forecast_loss = 0.08218, val_recon_loss = 0.07803, val_total_loss = 0.16021 [4.6s]
# [Epoch 41] forecast_loss = 0.05767, recon_loss = 0.07589, total_loss = 0.13355 ---- val_forecast_loss = 0.08590, val_recon_loss = 0.07839, val_total_loss = 0.16430 [4.5s]
# [Epoch 42] forecast_loss = 0.05645, recon_loss = 0.07508, total_loss = 0.13153 ---- val_forecast_loss = 0.08272, val_recon_loss = 0.07632, val_total_loss = 0.15904 [4.6s]
# [Epoch 43] forecast_loss = 0.05613, recon_loss = 0.07437, total_loss = 0.13050 ---- val_forecast_loss = 0.08414, val_recon_loss = 0.07641, val_total_loss = 0.16055 [4.6s]
# [Epoch 44] forecast_loss = 0.05556, recon_loss = 0.07334, total_loss = 0.12890 ---- val_forecast_loss = 0.08167, val_recon_loss = 0.07499, val_total_loss = 0.15666 [4.9s]
# [Epoch 45] forecast_loss = 0.05444, recon_loss = 0.07266, total_loss = 0.12709 ---- val_forecast_loss = 0.08591, val_recon_loss = 0.07432, val_total_loss = 0.16023 [4.8s]
# [Epoch 46] forecast_loss = 0.05407, recon_loss = 0.07160, total_loss = 0.12567 ---- val_forecast_loss = 0.08261, val_recon_loss = 0.07381, val_total_loss = 0.15641 [4.6s]
# [Epoch 47] forecast_loss = 0.05397, recon_loss = 0.07140, total_loss = 0.12537 ---- val_forecast_loss = 0.08287, val_recon_loss = 0.07289, val_total_loss = 0.15576 [4.5s]
# [Epoch 48] forecast_loss = 0.05321, recon_loss = 0.07036, total_loss = 0.12357 ---- val_forecast_loss = 0.08267, val_recon_loss = 0.07271, val_total_loss = 0.15538 [4.6s]
# [Epoch 49] forecast_loss = 0.05294, recon_loss = 0.06943, total_loss = 0.12237 ---- val_forecast_loss = 0.08370, val_recon_loss = 0.07126, val_total_loss = 0.15497 [4.6s]
# [Epoch 50] forecast_loss = 0.05170, recon_loss = 0.06899, total_loss = 0.12068 ---- val_forecast_loss = 0.08302, val_recon_loss = 0.07065, val_total_loss = 0.15367 [4.6s]
# [Epoch 51] forecast_loss = 0.05191, recon_loss = 0.06836, total_loss = 0.12027 ---- val_forecast_loss = 0.08282, val_recon_loss = 0.06988, val_total_loss = 0.15270 [4.6s]
# [Epoch 52] forecast_loss = 0.05175, recon_loss = 0.06798, total_loss = 0.11974 ---- val_forecast_loss = 0.08495, val_recon_loss = 0.07063, val_total_loss = 0.15557 [4.7s]
# [Epoch 53] forecast_loss = 0.05018, recon_loss = 0.06733, total_loss = 0.11752 ---- val_forecast_loss = 0.08550, val_recon_loss = 0.06941, val_total_loss = 0.15491 [5.0s]
# [Epoch 54] forecast_loss = 0.05012, recon_loss = 0.06675, total_loss = 0.11688 ---- val_forecast_loss = 0.08269, val_recon_loss = 0.06909, val_total_loss = 0.15178 [4.6s]
# [Epoch 55] forecast_loss = 0.04936, recon_loss = 0.06621, total_loss = 0.11558 ---- val_forecast_loss = 0.08543, val_recon_loss = 0.06877, val_total_loss = 0.15419 [4.6s]
# [Epoch 56] forecast_loss = 0.04898, recon_loss = 0.06592, total_loss = 0.11490 ---- val_forecast_loss = 0.08506, val_recon_loss = 0.06815, val_total_loss = 0.15321 [4.6s]
# [Epoch 57] forecast_loss = 0.04817, recon_loss = 0.06524, total_loss = 0.11341 ---- val_forecast_loss = 0.08410, val_recon_loss = 0.06699, val_total_loss = 0.15110 [4.5s]
# [Epoch 58] forecast_loss = 0.04837, recon_loss = 0.06451, total_loss = 0.11288 ---- val_forecast_loss = 0.08335, val_recon_loss = 0.06651, val_total_loss = 0.14985 [4.6s]
# [Epoch 59] forecast_loss = 0.04730, recon_loss = 0.06407, total_loss = 0.11137 ---- val_forecast_loss = 0.08301, val_recon_loss = 0.06661, val_total_loss = 0.14962 [4.7s]
# [Epoch 60] forecast_loss = 0.04761, recon_loss = 0.06384, total_loss = 0.11145 ---- val_forecast_loss = 0.08350, val_recon_loss = 0.06590, val_total_loss = 0.14939 [4.5s]
# [Epoch 61] forecast_loss = 0.04693, recon_loss = 0.06334, total_loss = 0.11027 ---- val_forecast_loss = 0.08262, val_recon_loss = 0.06599, val_total_loss = 0.14861 [4.6s]
# [Epoch 62] forecast_loss = 0.04637, recon_loss = 0.06270, total_loss = 0.10908 ---- val_forecast_loss = 0.08368, val_recon_loss = 0.06467, val_total_loss = 0.14834 [4.6s]
# [Epoch 63] forecast_loss = 0.04578, recon_loss = 0.06246, total_loss = 0.10824 ---- val_forecast_loss = 0.08349, val_recon_loss = 0.06461, val_total_loss = 0.14810 [4.5s]
# [Epoch 64] forecast_loss = 0.04618, recon_loss = 0.06204, total_loss = 0.10821 ---- val_forecast_loss = 0.08419, val_recon_loss = 0.06383, val_total_loss = 0.14802 [4.6s]
# [Epoch 65] forecast_loss = 0.04638, recon_loss = 0.06210, total_loss = 0.10848 ---- val_forecast_loss = 0.08393, val_recon_loss = 0.06515, val_total_loss = 0.14908 [4.6s]
# [Epoch 66] forecast_loss = 0.04590, recon_loss = 0.06127, total_loss = 0.10718 ---- val_forecast_loss = 0.08424, val_recon_loss = 0.06451, val_total_loss = 0.14875 [4.6s]
# [Epoch 67] forecast_loss = 0.04510, recon_loss = 0.06088, total_loss = 0.10598 ---- val_forecast_loss = 0.08509, val_recon_loss = 0.06296, val_total_loss = 0.14805 [4.6s]
# [Epoch 68] forecast_loss = 0.04476, recon_loss = 0.06050, total_loss = 0.10526 ---- val_forecast_loss = 0.08314, val_recon_loss = 0.06281, val_total_loss = 0.14595 [4.5s]
# [Epoch 69] forecast_loss = 0.04428, recon_loss = 0.06005, total_loss = 0.10434 ---- val_forecast_loss = 0.08242, val_recon_loss = 0.06312, val_total_loss = 0.14554 [4.6s]
# [Epoch 70] forecast_loss = 0.04437, recon_loss = 0.05965, total_loss = 0.10403 ---- val_forecast_loss = 0.08634, val_recon_loss = 0.06311, val_total_loss = 0.14945 [4.6s]
# [Epoch 71] forecast_loss = 0.04353, recon_loss = 0.05931, total_loss = 0.10285 ---- val_forecast_loss = 0.08483, val_recon_loss = 0.06196, val_total_loss = 0.14680 [4.5s]
# [Epoch 72] forecast_loss = 0.04303, recon_loss = 0.05899, total_loss = 0.10202 ---- val_forecast_loss = 0.08439, val_recon_loss = 0.06159, val_total_loss = 0.14598 [4.7s]
# [Epoch 73] forecast_loss = 0.04360, recon_loss = 0.05884, total_loss = 0.10244 ---- val_forecast_loss = 0.08452, val_recon_loss = 0.06157, val_total_loss = 0.14609 [4.6s]
# [Epoch 74] forecast_loss = 0.04323, recon_loss = 0.05857, total_loss = 0.10180 ---- val_forecast_loss = 0.08392, val_recon_loss = 0.06218, val_total_loss = 0.14609 [4.6s]
# [Epoch 75] forecast_loss = 0.04188, recon_loss = 0.05823, total_loss = 0.10011 ---- val_forecast_loss = 0.08330, val_recon_loss = 0.06076, val_total_loss = 0.14406 [4.7s]
# [Epoch 76] forecast_loss = 0.04195, recon_loss = 0.05781, total_loss = 0.09977 ---- val_forecast_loss = 0.08414, val_recon_loss = 0.06022, val_total_loss = 0.14436 [4.5s]
# [Epoch 77] forecast_loss = 0.04208, recon_loss = 0.05746, total_loss = 0.09954 ---- val_forecast_loss = 0.08453, val_recon_loss = 0.05961, val_total_loss = 0.14414 [4.6s]
# [Epoch 78] forecast_loss = 0.04214, recon_loss = 0.05722, total_loss = 0.09936 ---- val_forecast_loss = 0.08436, val_recon_loss = 0.06028, val_total_loss = 0.14464 [4.5s]
# [Epoch 79] forecast_loss = 0.04188, recon_loss = 0.05717, total_loss = 0.09906 ---- val_forecast_loss = 0.08617, val_recon_loss = 0.06001, val_total_loss = 0.14617 [4.5s]
# [Epoch 80] forecast_loss = 0.04169, recon_loss = 0.05704, total_loss = 0.09873 ---- val_forecast_loss = 0.08397, val_recon_loss = 0.05926, val_total_loss = 0.14323 [4.6s]
# [Epoch 81] forecast_loss = 0.04036, recon_loss = 0.05630, total_loss = 0.09665 ---- val_forecast_loss = 0.08366, val_recon_loss = 0.05818, val_total_loss = 0.14184 [4.5s]
# [Epoch 82] forecast_loss = 0.04087, recon_loss = 0.05631, total_loss = 0.09718 ---- val_forecast_loss = 0.08358, val_recon_loss = 0.05913, val_total_loss = 0.14271 [4.6s]
# [Epoch 83] forecast_loss = 0.04012, recon_loss = 0.05571, total_loss = 0.09582 ---- val_forecast_loss = 0.08346, val_recon_loss = 0.05915, val_total_loss = 0.14261 [4.6s]
# [Epoch 84] forecast_loss = 0.03996, recon_loss = 0.05532, total_loss = 0.09529 ---- val_forecast_loss = 0.08362, val_recon_loss = 0.05830, val_total_loss = 0.14192 [4.5s]
# [Epoch 85] forecast_loss = 0.04063, recon_loss = 0.05551, total_loss = 0.09614 ---- val_forecast_loss = 0.08311, val_recon_loss = 0.05833, val_total_loss = 0.14144 [4.6s]
# [Epoch 86] forecast_loss = 0.04013, recon_loss = 0.05506, total_loss = 0.09519 ---- val_forecast_loss = 0.08449, val_recon_loss = 0.05729, val_total_loss = 0.14178 [4.5s]
# [Epoch 87] forecast_loss = 0.04003, recon_loss = 0.05489, total_loss = 0.09492 ---- val_forecast_loss = 0.08374, val_recon_loss = 0.05790, val_total_loss = 0.14164 [4.6s]
# [Epoch 88] forecast_loss = 0.03982, recon_loss = 0.05461, total_loss = 0.09443 ---- val_forecast_loss = 0.08400, val_recon_loss = 0.05743, val_total_loss = 0.14143 [4.6s]
# [Epoch 89] forecast_loss = 0.03964, recon_loss = 0.05463, total_loss = 0.09426 ---- val_forecast_loss = 0.08550, val_recon_loss = 0.05797, val_total_loss = 0.14347 [4.6s]
# [Epoch 90] forecast_loss = 0.03946, recon_loss = 0.05403, total_loss = 0.09349 ---- val_forecast_loss = 0.08472, val_recon_loss = 0.05651, val_total_loss = 0.14124 [4.6s]
# [Epoch 91] forecast_loss = 0.03862, recon_loss = 0.05375, total_loss = 0.09237 ---- val_forecast_loss = 0.08317, val_recon_loss = 0.05703, val_total_loss = 0.14019 [4.6s]
# [Epoch 92] forecast_loss = 0.03863, recon_loss = 0.05347, total_loss = 0.09210 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.05607, val_total_loss = 0.14027 [4.6s]
# [Epoch 93] forecast_loss = 0.03913, recon_loss = 0.05374, total_loss = 0.09287 ---- val_forecast_loss = 0.08429, val_recon_loss = 0.05599, val_total_loss = 0.14028 [4.6s]
# [Epoch 94] forecast_loss = 0.03805, recon_loss = 0.05319, total_loss = 0.09124 ---- val_forecast_loss = 0.08428, val_recon_loss = 0.05595, val_total_loss = 0.14022 [4.6s]
# [Epoch 95] forecast_loss = 0.03848, recon_loss = 0.05323, total_loss = 0.09171 ---- val_forecast_loss = 0.08329, val_recon_loss = 0.05547, val_total_loss = 0.13877 [4.6s]
# [Epoch 96] forecast_loss = 0.03814, recon_loss = 0.05294, total_loss = 0.09108 ---- val_forecast_loss = 0.08300, val_recon_loss = 0.05526, val_total_loss = 0.13826 [4.6s]
# [Epoch 97] forecast_loss = 0.03816, recon_loss = 0.05270, total_loss = 0.09085 ---- val_forecast_loss = 0.08343, val_recon_loss = 0.05583, val_total_loss = 0.13926 [4.6s]
# [Epoch 98] forecast_loss = 0.03762, recon_loss = 0.05233, total_loss = 0.08995 ---- val_forecast_loss = 0.08415, val_recon_loss = 0.05432, val_total_loss = 0.13847 [4.6s]
# [Epoch 99] forecast_loss = 0.03759, recon_loss = 0.05191, total_loss = 0.08950 ---- val_forecast_loss = 0.08398, val_recon_loss = 0.05494, val_total_loss = 0.13892 [4.6s]
# [Epoch 100] forecast_loss = 0.03753, recon_loss = 0.05208, total_loss = 0.08962 ---- val_forecast_loss = 0.08334, val_recon_loss = 0.05438, val_total_loss = 0.13773 [4.6s]
# [Epoch 101] forecast_loss = 0.03723, recon_loss = 0.05165, total_loss = 0.08888 ---- val_forecast_loss = 0.08587, val_recon_loss = 0.05481, val_total_loss = 0.14068 [4.6s]
# [Epoch 102] forecast_loss = 0.03749, recon_loss = 0.05156, total_loss = 0.08905 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.05349, val_total_loss = 0.13721 [5.2s]
# [Epoch 103] forecast_loss = 0.03695, recon_loss = 0.05131, total_loss = 0.08826 ---- val_forecast_loss = 0.08346, val_recon_loss = 0.05409, val_total_loss = 0.13755 [4.6s]
# [Epoch 104] forecast_loss = 0.03732, recon_loss = 0.05110, total_loss = 0.08842 ---- val_forecast_loss = 0.08365, val_recon_loss = 0.05371, val_total_loss = 0.13736 [4.7s]
# [Epoch 105] forecast_loss = 0.03618, recon_loss = 0.05075, total_loss = 0.08693 ---- val_forecast_loss = 0.08654, val_recon_loss = 0.05456, val_total_loss = 0.14111 [4.6s]
# [Epoch 106] forecast_loss = 0.03714, recon_loss = 0.05076, total_loss = 0.08789 ---- val_forecast_loss = 0.08404, val_recon_loss = 0.05447, val_total_loss = 0.13851 [4.6s]
# [Epoch 107] forecast_loss = 0.03738, recon_loss = 0.05020, total_loss = 0.08758 ---- val_forecast_loss = 0.08398, val_recon_loss = 0.05460, val_total_loss = 0.13858 [4.6s]
# [Epoch 108] forecast_loss = 0.03604, recon_loss = 0.05023, total_loss = 0.08627 ---- val_forecast_loss = 0.08541, val_recon_loss = 0.05269, val_total_loss = 0.13810 [4.5s]
# [Epoch 109] forecast_loss = 0.03605, recon_loss = 0.04988, total_loss = 0.08593 ---- val_forecast_loss = 0.08462, val_recon_loss = 0.05215, val_total_loss = 0.13677 [4.7s]
# [Epoch 110] forecast_loss = 0.03656, recon_loss = 0.04997, total_loss = 0.08653 ---- val_forecast_loss = 0.08266, val_recon_loss = 0.05260, val_total_loss = 0.13526 [4.6s]
# [Epoch 111] forecast_loss = 0.03634, recon_loss = 0.04989, total_loss = 0.08623 ---- val_forecast_loss = 0.08267, val_recon_loss = 0.05149, val_total_loss = 0.13416 [4.6s]
# [Epoch 112] forecast_loss = 0.03618, recon_loss = 0.04974, total_loss = 0.08592 ---- val_forecast_loss = 0.08495, val_recon_loss = 0.05176, val_total_loss = 0.13671 [4.6s]
# [Epoch 113] forecast_loss = 0.03573, recon_loss = 0.04921, total_loss = 0.08494 ---- val_forecast_loss = 0.08475, val_recon_loss = 0.05250, val_total_loss = 0.13725 [4.5s]
# [Epoch 114] forecast_loss = 0.03595, recon_loss = 0.04929, total_loss = 0.08524 ---- val_forecast_loss = 0.08441, val_recon_loss = 0.05177, val_total_loss = 0.13618 [4.6s]
# [Epoch 115] forecast_loss = 0.03586, recon_loss = 0.04905, total_loss = 0.08491 ---- val_forecast_loss = 0.08441, val_recon_loss = 0.05209, val_total_loss = 0.13650 [4.6s]
# [Epoch 116] forecast_loss = 0.03516, recon_loss = 0.04884, total_loss = 0.08400 ---- val_forecast_loss = 0.08417, val_recon_loss = 0.05066, val_total_loss = 0.13483 [4.6s]
# [Epoch 117] forecast_loss = 0.03538, recon_loss = 0.04878, total_loss = 0.08416 ---- val_forecast_loss = 0.08265, val_recon_loss = 0.05149, val_total_loss = 0.13414 [4.6s]
# [Epoch 118] forecast_loss = 0.03527, recon_loss = 0.04833, total_loss = 0.08359 ---- val_forecast_loss = 0.08526, val_recon_loss = 0.05106, val_total_loss = 0.13631 [4.6s]
# [Epoch 119] forecast_loss = 0.03506, recon_loss = 0.04797, total_loss = 0.08303 ---- val_forecast_loss = 0.08479, val_recon_loss = 0.05109, val_total_loss = 0.13587 [4.6s]
# [Epoch 120] forecast_loss = 0.03468, recon_loss = 0.04797, total_loss = 0.08265 ---- val_forecast_loss = 0.08326, val_recon_loss = 0.05115, val_total_loss = 0.13441 [4.6s]
# [Epoch 121] forecast_loss = 0.03576, recon_loss = 0.04832, total_loss = 0.08407 ---- val_forecast_loss = 0.08619, val_recon_loss = 0.05066, val_total_loss = 0.13685 [4.6s]
# [Epoch 122] forecast_loss = 0.03577, recon_loss = 0.04808, total_loss = 0.08386 ---- val_forecast_loss = 0.08671, val_recon_loss = 0.04991, val_total_loss = 0.13662 [4.7s]
# [Epoch 123] forecast_loss = 0.03523, recon_loss = 0.04765, total_loss = 0.08288 ---- val_forecast_loss = 0.08668, val_recon_loss = 0.05032, val_total_loss = 0.13700 [4.6s]
# [Epoch 124] forecast_loss = 0.03466, recon_loss = 0.04750, total_loss = 0.08216 ---- val_forecast_loss = 0.08283, val_recon_loss = 0.05031, val_total_loss = 0.13315 [4.6s]
# [Epoch 125] forecast_loss = 0.03445, recon_loss = 0.04726, total_loss = 0.08171 ---- val_forecast_loss = 0.08460, val_recon_loss = 0.05142, val_total_loss = 0.13602 [4.6s]
# [Epoch 126] forecast_loss = 0.03501, recon_loss = 0.04735, total_loss = 0.08236 ---- val_forecast_loss = 0.08401, val_recon_loss = 0.04949, val_total_loss = 0.13351 [4.6s]
# [Epoch 127] forecast_loss = 0.03506, recon_loss = 0.04689, total_loss = 0.08195 ---- val_forecast_loss = 0.08423, val_recon_loss = 0.04986, val_total_loss = 0.13409 [4.6s]
# [Epoch 128] forecast_loss = 0.03446, recon_loss = 0.04697, total_loss = 0.08143 ---- val_forecast_loss = 0.08448, val_recon_loss = 0.04993, val_total_loss = 0.13441 [4.6s]
# [Epoch 129] forecast_loss = 0.03426, recon_loss = 0.04670, total_loss = 0.08096 ---- val_forecast_loss = 0.08382, val_recon_loss = 0.04984, val_total_loss = 0.13365 [4.6s]
# [Epoch 130] forecast_loss = 0.03400, recon_loss = 0.04651, total_loss = 0.08051 ---- val_forecast_loss = 0.08287, val_recon_loss = 0.04892, val_total_loss = 0.13178 [4.6s]
# [Epoch 131] forecast_loss = 0.03400, recon_loss = 0.04640, total_loss = 0.08040 ---- val_forecast_loss = 0.08352, val_recon_loss = 0.04867, val_total_loss = 0.13219 [4.7s]
# [Epoch 132] forecast_loss = 0.03417, recon_loss = 0.04625, total_loss = 0.08041 ---- val_forecast_loss = 0.08281, val_recon_loss = 0.04837, val_total_loss = 0.13118 [4.6s]
# [Epoch 133] forecast_loss = 0.03343, recon_loss = 0.04616, total_loss = 0.07959 ---- val_forecast_loss = 0.08388, val_recon_loss = 0.04852, val_total_loss = 0.13241 [4.6s]
# [Epoch 134] forecast_loss = 0.03380, recon_loss = 0.04596, total_loss = 0.07976 ---- val_forecast_loss = 0.08362, val_recon_loss = 0.04856, val_total_loss = 0.13218 [4.6s]
# [Epoch 135] forecast_loss = 0.03432, recon_loss = 0.04612, total_loss = 0.08044 ---- val_forecast_loss = 0.08457, val_recon_loss = 0.04812, val_total_loss = 0.13269 [4.8s]
# [Epoch 136] forecast_loss = 0.03449, recon_loss = 0.04967, total_loss = 0.08416 ---- val_forecast_loss = 0.08604, val_recon_loss = 0.04874, val_total_loss = 0.13478 [4.6s]
# [Epoch 137] forecast_loss = 0.03456, recon_loss = 0.04575, total_loss = 0.08032 ---- val_forecast_loss = 0.08541, val_recon_loss = 0.04799, val_total_loss = 0.13340 [4.6s]
# [Epoch 138] forecast_loss = 0.03402, recon_loss = 0.04553, total_loss = 0.07954 ---- val_forecast_loss = 0.08350, val_recon_loss = 0.04718, val_total_loss = 0.13068 [4.6s]
# [Epoch 139] forecast_loss = 0.03386, recon_loss = 0.04546, total_loss = 0.07932 ---- val_forecast_loss = 0.08517, val_recon_loss = 0.04774, val_total_loss = 0.13292 [4.6s]
# [Epoch 140] forecast_loss = 0.03287, recon_loss = 0.04516, total_loss = 0.07803 ---- val_forecast_loss = 0.08465, val_recon_loss = 0.04763, val_total_loss = 0.13228 [4.6s]
# [Epoch 141] forecast_loss = 0.03261, recon_loss = 0.04498, total_loss = 0.07759 ---- val_forecast_loss = 0.08536, val_recon_loss = 0.04755, val_total_loss = 0.13291 [4.6s]
# [Epoch 142] forecast_loss = 0.03328, recon_loss = 0.04474, total_loss = 0.07802 ---- val_forecast_loss = 0.08422, val_recon_loss = 0.04724, val_total_loss = 0.13146 [4.5s]
# [Epoch 143] forecast_loss = 0.03356, recon_loss = 0.04485, total_loss = 0.07841 ---- val_forecast_loss = 0.08540, val_recon_loss = 0.04729, val_total_loss = 0.13269 [4.6s]
# [Epoch 144] forecast_loss = 0.03359, recon_loss = 0.04522, total_loss = 0.07880 ---- val_forecast_loss = 0.08386, val_recon_loss = 0.04705, val_total_loss = 0.13090 [4.6s]
# [Epoch 145] forecast_loss = 0.03338, recon_loss = 0.04453, total_loss = 0.07791 ---- val_forecast_loss = 0.08320, val_recon_loss = 0.04643, val_total_loss = 0.12963 [4.6s]
# [Epoch 146] forecast_loss = 0.03289, recon_loss = 0.04440, total_loss = 0.07728 ---- val_forecast_loss = 0.08512, val_recon_loss = 0.04590, val_total_loss = 0.13102 [4.6s]
# [Epoch 147] forecast_loss = 0.03288, recon_loss = 0.04450, total_loss = 0.07738 ---- val_forecast_loss = 0.08369, val_recon_loss = 0.04630, val_total_loss = 0.12998 [4.5s]
# [Epoch 148] forecast_loss = 0.03284, recon_loss = 0.04400, total_loss = 0.07685 ---- val_forecast_loss = 0.08392, val_recon_loss = 0.04628, val_total_loss = 0.13020 [4.6s]
# [Epoch 149] forecast_loss = 0.03251, recon_loss = 0.04380, total_loss = 0.07631 ---- val_forecast_loss = 0.08581, val_recon_loss = 0.04597, val_total_loss = 0.13178 [4.7s]
# [Epoch 150] forecast_loss = 0.03289, recon_loss = 0.04408, total_loss = 0.07697 ---- val_forecast_loss = 0.08338, val_recon_loss = 0.04608, val_total_loss = 0.12946 [4.6s]
# [Epoch 151] forecast_loss = 0.03257, recon_loss = 0.04368, total_loss = 0.07625 ---- val_forecast_loss = 0.08452, val_recon_loss = 0.04691, val_total_loss = 0.13143 [4.6s]
# [Epoch 152] forecast_loss = 0.03282, recon_loss = 0.04391, total_loss = 0.07673 ---- val_forecast_loss = 0.08446, val_recon_loss = 0.04673, val_total_loss = 0.13118 [4.5s]
# [Epoch 153] forecast_loss = 0.03249, recon_loss = 0.04345, total_loss = 0.07594 ---- val_forecast_loss = 0.08444, val_recon_loss = 0.04586, val_total_loss = 0.13030 [4.6s]
# [Epoch 154] forecast_loss = 0.03266, recon_loss = 0.04324, total_loss = 0.07590 ---- val_forecast_loss = 0.08416, val_recon_loss = 0.04550, val_total_loss = 0.12965 [4.6s]
# [Epoch 155] forecast_loss = 0.03240, recon_loss = 0.04315, total_loss = 0.07555 ---- val_forecast_loss = 0.08328, val_recon_loss = 0.04478, val_total_loss = 0.12807 [4.6s]
# [Epoch 156] forecast_loss = 0.03274, recon_loss = 0.04310, total_loss = 0.07584 ---- val_forecast_loss = 0.08442, val_recon_loss = 0.04595, val_total_loss = 0.13038 [4.6s]
# [Epoch 157] forecast_loss = 0.03290, recon_loss = 0.04332, total_loss = 0.07622 ---- val_forecast_loss = 0.08374, val_recon_loss = 0.04492, val_total_loss = 0.12866 [4.6s]
# [Epoch 158] forecast_loss = 0.03152, recon_loss = 0.04272, total_loss = 0.07424 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.04472, val_total_loss = 0.12843 [4.6s]
# [Epoch 159] forecast_loss = 0.03220, recon_loss = 0.04304, total_loss = 0.07525 ---- val_forecast_loss = 0.08361, val_recon_loss = 0.04504, val_total_loss = 0.12866 [4.6s]
# [Epoch 160] forecast_loss = 0.03211, recon_loss = 0.04253, total_loss = 0.07463 ---- val_forecast_loss = 0.08373, val_recon_loss = 0.04416, val_total_loss = 0.12788 [4.6s]
# [Epoch 161] forecast_loss = 0.03148, recon_loss = 0.04254, total_loss = 0.07403 ---- val_forecast_loss = 0.08366, val_recon_loss = 0.04464, val_total_loss = 0.12830 [4.6s]
# [Epoch 162] forecast_loss = 0.03186, recon_loss = 0.04261, total_loss = 0.07447 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.04476, val_total_loss = 0.12848 [4.7s]
# [Epoch 163] forecast_loss = 0.03240, recon_loss = 0.04227, total_loss = 0.07467 ---- val_forecast_loss = 0.08330, val_recon_loss = 0.04438, val_total_loss = 0.12768 [4.6s]
# [Epoch 164] forecast_loss = 0.03293, recon_loss = 0.04222, total_loss = 0.07515 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.04433, val_total_loss = 0.12805 [4.6s]
# [Epoch 165] forecast_loss = 0.03224, recon_loss = 0.04224, total_loss = 0.07449 ---- val_forecast_loss = 0.08336, val_recon_loss = 0.04420, val_total_loss = 0.12756 [4.6s]
# [Epoch 166] forecast_loss = 0.03174, recon_loss = 0.04208, total_loss = 0.07382 ---- val_forecast_loss = 0.08387, val_recon_loss = 0.04405, val_total_loss = 0.12791 [4.6s]
# [Epoch 167] forecast_loss = 0.03154, recon_loss = 0.04177, total_loss = 0.07331 ---- val_forecast_loss = 0.08339, val_recon_loss = 0.04505, val_total_loss = 0.12844 [4.6s]
# [Epoch 168] forecast_loss = 0.03128, recon_loss = 0.04164, total_loss = 0.07291 ---- val_forecast_loss = 0.08347, val_recon_loss = 0.04427, val_total_loss = 0.12775 [4.6s]
# [Epoch 169] forecast_loss = 0.03192, recon_loss = 0.04174, total_loss = 0.07366 ---- val_forecast_loss = 0.08450, val_recon_loss = 0.04394, val_total_loss = 0.12843 [4.6s]
# [Epoch 170] forecast_loss = 0.03213, recon_loss = 0.04163, total_loss = 0.07375 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.04325, val_total_loss = 0.12696 [4.6s]
# [Epoch 171] forecast_loss = 0.03189, recon_loss = 0.04168, total_loss = 0.07358 ---- val_forecast_loss = 0.08442, val_recon_loss = 0.04380, val_total_loss = 0.12822 [4.6s]
# [Epoch 172] forecast_loss = 0.03178, recon_loss = 0.04172, total_loss = 0.07350 ---- val_forecast_loss = 0.08444, val_recon_loss = 0.04398, val_total_loss = 0.12841 [4.6s]
# [Epoch 173] forecast_loss = 0.03153, recon_loss = 0.04211, total_loss = 0.07363 ---- val_forecast_loss = 0.08304, val_recon_loss = 0.04328, val_total_loss = 0.12631 [4.6s]
# [Epoch 174] forecast_loss = 0.03082, recon_loss = 0.04122, total_loss = 0.07204 ---- val_forecast_loss = 0.08436, val_recon_loss = 0.04419, val_total_loss = 0.12855 [4.5s]
# [Epoch 175] forecast_loss = 0.03185, recon_loss = 0.04133, total_loss = 0.07319 ---- val_forecast_loss = 0.08367, val_recon_loss = 0.04366, val_total_loss = 0.12733 [4.6s]
# [Epoch 176] forecast_loss = 0.03131, recon_loss = 0.04106, total_loss = 0.07237 ---- val_forecast_loss = 0.08545, val_recon_loss = 0.04352, val_total_loss = 0.12897 [4.6s]
# [Epoch 177] forecast_loss = 0.03068, recon_loss = 0.04094, total_loss = 0.07162 ---- val_forecast_loss = 0.08361, val_recon_loss = 0.04367, val_total_loss = 0.12728 [4.6s]
# [Epoch 178] forecast_loss = 0.03061, recon_loss = 0.04062, total_loss = 0.07124 ---- val_forecast_loss = 0.08396, val_recon_loss = 0.04336, val_total_loss = 0.12731 [4.6s]
# [Epoch 179] forecast_loss = 0.03041, recon_loss = 0.04080, total_loss = 0.07121 ---- val_forecast_loss = 0.08353, val_recon_loss = 0.04278, val_total_loss = 0.12631 [4.6s]
# [Epoch 180] forecast_loss = 0.03120, recon_loss = 0.04059, total_loss = 0.07179 ---- val_forecast_loss = 0.08480, val_recon_loss = 0.04283, val_total_loss = 0.12764 [4.6s]
# [Epoch 181] forecast_loss = 0.03131, recon_loss = 0.04063, total_loss = 0.07194 ---- val_forecast_loss = 0.08374, val_recon_loss = 0.04318, val_total_loss = 0.12691 [4.6s]
# [Epoch 182] forecast_loss = 0.03006, recon_loss = 0.04033, total_loss = 0.07039 ---- val_forecast_loss = 0.08365, val_recon_loss = 0.04335, val_total_loss = 0.12701 [4.6s]
# [Epoch 183] forecast_loss = 0.03043, recon_loss = 0.04044, total_loss = 0.07087 ---- val_forecast_loss = 0.08355, val_recon_loss = 0.04253, val_total_loss = 0.12607 [4.6s]
# [Epoch 184] forecast_loss = 0.03122, recon_loss = 0.04045, total_loss = 0.07167 ---- val_forecast_loss = 0.08530, val_recon_loss = 0.04272, val_total_loss = 0.12802 [4.7s]
# [Epoch 185] forecast_loss = 0.03058, recon_loss = 0.04011, total_loss = 0.07069 ---- val_forecast_loss = 0.08446, val_recon_loss = 0.04258, val_total_loss = 0.12704 [4.6s]
# [Epoch 186] forecast_loss = 0.03048, recon_loss = 0.04013, total_loss = 0.07061 ---- val_forecast_loss = 0.08364, val_recon_loss = 0.04279, val_total_loss = 0.12642 [4.6s]
# [Epoch 187] forecast_loss = 0.02985, recon_loss = 0.03998, total_loss = 0.06983 ---- val_forecast_loss = 0.08371, val_recon_loss = 0.04353, val_total_loss = 0.12725 [4.5s]
# [Epoch 188] forecast_loss = 0.02983, recon_loss = 0.04019, total_loss = 0.07003 ---- val_forecast_loss = 0.08278, val_recon_loss = 0.04177, val_total_loss = 0.12455 [4.6s]
# [Epoch 189] forecast_loss = 0.03057, recon_loss = 0.04055, total_loss = 0.07112 ---- val_forecast_loss = 0.08383, val_recon_loss = 0.04293, val_total_loss = 0.12676 [4.6s]
# [Epoch 190] forecast_loss = 0.03058, recon_loss = 0.04008, total_loss = 0.07066 ---- val_forecast_loss = 0.08511, val_recon_loss = 0.04243, val_total_loss = 0.12753 [4.5s]
# [Epoch 191] forecast_loss = 0.03009, recon_loss = 0.03981, total_loss = 0.06990 ---- val_forecast_loss = 0.08401, val_recon_loss = 0.04182, val_total_loss = 0.12582 [4.6s]
# [Epoch 192] forecast_loss = 0.03036, recon_loss = 0.03964, total_loss = 0.07000 ---- val_forecast_loss = 0.08432, val_recon_loss = 0.04235, val_total_loss = 0.12667 [4.6s]
# [Epoch 193] forecast_loss = 0.03080, recon_loss = 0.03960, total_loss = 0.07040 ---- val_forecast_loss = 0.08379, val_recon_loss = 0.04202, val_total_loss = 0.12580 [4.6s]
# [Epoch 194] forecast_loss = 0.03066, recon_loss = 0.03944, total_loss = 0.07010 ---- val_forecast_loss = 0.08313, val_recon_loss = 0.04171, val_total_loss = 0.12485 [4.6s]
# [Epoch 195] forecast_loss = 0.03068, recon_loss = 0.03946, total_loss = 0.07014 ---- val_forecast_loss = 0.08376, val_recon_loss = 0.04176, val_total_loss = 0.12552 [4.6s]
# [Epoch 196] forecast_loss = 0.03025, recon_loss = 0.03927, total_loss = 0.06952 ---- val_forecast_loss = 0.08320, val_recon_loss = 0.04073, val_total_loss = 0.12393 [4.6s]
# [Epoch 197] forecast_loss = 0.03044, recon_loss = 0.03942, total_loss = 0.06986 ---- val_forecast_loss = 0.08370, val_recon_loss = 0.04128, val_total_loss = 0.12498 [4.6s]
# [Epoch 198] forecast_loss = 0.02956, recon_loss = 0.03916, total_loss = 0.06871 ---- val_forecast_loss = 0.08478, val_recon_loss = 0.04129, val_total_loss = 0.12608 [4.6s]
# [Epoch 199] forecast_loss = 0.02990, recon_loss = 0.03920, total_loss = 0.06909 ---- val_forecast_loss = 0.08493, val_recon_loss = 0.04147, val_total_loss = 0.12640 [5.1s]
# [Epoch 200] forecast_loss = 0.02976, recon_loss = 0.03929, total_loss = 0.06905 ---- val_forecast_loss = 0.08283, val_recon_loss = 0.04084, val_total_loss = 0.12367 [4.5s]
# [Epoch 201] forecast_loss = 0.03013, recon_loss = 0.03898, total_loss = 0.06911 ---- val_forecast_loss = 0.08361, val_recon_loss = 0.04114, val_total_loss = 0.12476 [4.6s]
# [Epoch 202] forecast_loss = 0.03013, recon_loss = 0.03894, total_loss = 0.06907 ---- val_forecast_loss = 0.08334, val_recon_loss = 0.04018, val_total_loss = 0.12352 [4.7s]
# [Epoch 203] forecast_loss = 0.02980, recon_loss = 0.03874, total_loss = 0.06855 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.04095, val_total_loss = 0.12515 [4.6s]
# [Epoch 204] forecast_loss = 0.03039, recon_loss = 0.03884, total_loss = 0.06922 ---- val_forecast_loss = 0.08298, val_recon_loss = 0.04084, val_total_loss = 0.12381 [4.6s]
# [Epoch 205] forecast_loss = 0.02934, recon_loss = 0.03865, total_loss = 0.06800 ---- val_forecast_loss = 0.08366, val_recon_loss = 0.04061, val_total_loss = 0.12427 [4.6s]
# [Epoch 206] forecast_loss = 0.02992, recon_loss = 0.03871, total_loss = 0.06863 ---- val_forecast_loss = 0.08442, val_recon_loss = 0.04070, val_total_loss = 0.12512 [4.6s]
# [Epoch 207] forecast_loss = 0.03035, recon_loss = 0.03849, total_loss = 0.06885 ---- val_forecast_loss = 0.08382, val_recon_loss = 0.04039, val_total_loss = 0.12421 [4.6s]
# [Epoch 208] forecast_loss = 0.02932, recon_loss = 0.03855, total_loss = 0.06787 ---- val_forecast_loss = 0.08372, val_recon_loss = 0.04079, val_total_loss = 0.12452 [4.6s]
# [Epoch 209] forecast_loss = 0.03012, recon_loss = 0.03853, total_loss = 0.06866 ---- val_forecast_loss = 0.08457, val_recon_loss = 0.04065, val_total_loss = 0.12522 [4.5s]
# [Epoch 210] forecast_loss = 0.02933, recon_loss = 0.03913, total_loss = 0.06846 ---- val_forecast_loss = 0.08326, val_recon_loss = 0.04208, val_total_loss = 0.12534 [4.6s]
# [Epoch 211] forecast_loss = 0.02985, recon_loss = 0.03861, total_loss = 0.06845 ---- val_forecast_loss = 0.08307, val_recon_loss = 0.04033, val_total_loss = 0.12340 [4.6s]
# [Epoch 212] forecast_loss = 0.02916, recon_loss = 0.03813, total_loss = 0.06729 ---- val_forecast_loss = 0.08445, val_recon_loss = 0.04103, val_total_loss = 0.12548 [4.6s]
# [Epoch 213] forecast_loss = 0.02987, recon_loss = 0.03828, total_loss = 0.06815 ---- val_forecast_loss = 0.08335, val_recon_loss = 0.04024, val_total_loss = 0.12359 [4.6s]
# [Epoch 214] forecast_loss = 0.02918, recon_loss = 0.03808, total_loss = 0.06726 ---- val_forecast_loss = 0.08424, val_recon_loss = 0.04018, val_total_loss = 0.12442 [4.6s]
# [Epoch 215] forecast_loss = 0.02936, recon_loss = 0.03776, total_loss = 0.06713 ---- val_forecast_loss = 0.08289, val_recon_loss = 0.03966, val_total_loss = 0.12256 [4.6s]
# [Epoch 216] forecast_loss = 0.03021, recon_loss = 0.03795, total_loss = 0.06816 ---- val_forecast_loss = 0.08433, val_recon_loss = 0.04085, val_total_loss = 0.12518 [4.6s]
# [Epoch 217] forecast_loss = 0.02983, recon_loss = 0.03800, total_loss = 0.06783 ---- val_forecast_loss = 0.08430, val_recon_loss = 0.03974, val_total_loss = 0.12404 [4.6s]
# [Epoch 218] forecast_loss = 0.02903, recon_loss = 0.03786, total_loss = 0.06689 ---- val_forecast_loss = 0.08534, val_recon_loss = 0.03977, val_total_loss = 0.12511 [4.6s]
# [Epoch 219] forecast_loss = 0.02975, recon_loss = 0.03779, total_loss = 0.06754 ---- val_forecast_loss = 0.08439, val_recon_loss = 0.04029, val_total_loss = 0.12468 [4.6s]
# [Epoch 220] forecast_loss = 0.02960, recon_loss = 0.03779, total_loss = 0.06739 ---- val_forecast_loss = 0.08397, val_recon_loss = 0.04004, val_total_loss = 0.12401 [4.5s]
# [Epoch 221] forecast_loss = 0.02906, recon_loss = 0.03769, total_loss = 0.06675 ---- val_forecast_loss = 0.08394, val_recon_loss = 0.03919, val_total_loss = 0.12313 [4.6s]
# [Epoch 222] forecast_loss = 0.02902, recon_loss = 0.03748, total_loss = 0.06651 ---- val_forecast_loss = 0.08369, val_recon_loss = 0.03921, val_total_loss = 0.12290 [4.6s]
# [Epoch 223] forecast_loss = 0.02931, recon_loss = 0.03726, total_loss = 0.06657 ---- val_forecast_loss = 0.08364, val_recon_loss = 0.03903, val_total_loss = 0.12267 [4.6s]
# [Epoch 224] forecast_loss = 0.02885, recon_loss = 0.03724, total_loss = 0.06609 ---- val_forecast_loss = 0.08448, val_recon_loss = 0.03899, val_total_loss = 0.12347 [4.6s]
# [Epoch 225] forecast_loss = 0.02967, recon_loss = 0.03755, total_loss = 0.06722 ---- val_forecast_loss = 0.08379, val_recon_loss = 0.03967, val_total_loss = 0.12346 [4.6s]
# [Epoch 226] forecast_loss = 0.02839, recon_loss = 0.03716, total_loss = 0.06554 ---- val_forecast_loss = 0.08467, val_recon_loss = 0.03947, val_total_loss = 0.12413 [4.7s]
# [Epoch 227] forecast_loss = 0.02883, recon_loss = 0.03719, total_loss = 0.06601 ---- val_forecast_loss = 0.08399, val_recon_loss = 0.03913, val_total_loss = 0.12312 [4.6s]
# [Epoch 228] forecast_loss = 0.02906, recon_loss = 0.03715, total_loss = 0.06622 ---- val_forecast_loss = 0.08486, val_recon_loss = 0.03854, val_total_loss = 0.12340 [4.6s]
# [Epoch 229] forecast_loss = 0.02862, recon_loss = 0.03730, total_loss = 0.06592 ---- val_forecast_loss = 0.08375, val_recon_loss = 0.03917, val_total_loss = 0.12291 [4.7s]
# [Epoch 230] forecast_loss = 0.02819, recon_loss = 0.03714, total_loss = 0.06533 ---- val_forecast_loss = 0.08308, val_recon_loss = 0.03950, val_total_loss = 0.12258 [4.6s]
# [Epoch 231] forecast_loss = 0.02891, recon_loss = 0.03735, total_loss = 0.06626 ---- val_forecast_loss = 0.08278, val_recon_loss = 0.03908, val_total_loss = 0.12186 [4.6s]
# [Epoch 232] forecast_loss = 0.02831, recon_loss = 0.03696, total_loss = 0.06528 ---- val_forecast_loss = 0.08302, val_recon_loss = 0.03933, val_total_loss = 0.12235 [4.6s]
# [Epoch 233] forecast_loss = 0.02866, recon_loss = 0.03692, total_loss = 0.06557 ---- val_forecast_loss = 0.08408, val_recon_loss = 0.03866, val_total_loss = 0.12274 [4.6s]
# [Epoch 234] forecast_loss = 0.02848, recon_loss = 0.03668, total_loss = 0.06517 ---- val_forecast_loss = 0.08380, val_recon_loss = 0.03872, val_total_loss = 0.12252 [4.6s]
# [Epoch 235] forecast_loss = 0.02876, recon_loss = 0.03656, total_loss = 0.06531 ---- val_forecast_loss = 0.08310, val_recon_loss = 0.03878, val_total_loss = 0.12188 [4.6s]
# [Epoch 236] forecast_loss = 0.02828, recon_loss = 0.03665, total_loss = 0.06492 ---- val_forecast_loss = 0.08321, val_recon_loss = 0.03864, val_total_loss = 0.12185 [4.6s]
# [Epoch 237] forecast_loss = 0.02817, recon_loss = 0.03657, total_loss = 0.06474 ---- val_forecast_loss = 0.08377, val_recon_loss = 0.03904, val_total_loss = 0.12281 [4.7s]
# [Epoch 238] forecast_loss = 0.02916, recon_loss = 0.03662, total_loss = 0.06578 ---- val_forecast_loss = 0.08306, val_recon_loss = 0.03986, val_total_loss = 0.12291 [4.6s]
# [Epoch 239] forecast_loss = 0.02808, recon_loss = 0.03646, total_loss = 0.06454 ---- val_forecast_loss = 0.08370, val_recon_loss = 0.03850, val_total_loss = 0.12220 [4.6s]
# [Epoch 240] forecast_loss = 0.02835, recon_loss = 0.03670, total_loss = 0.06505 ---- val_forecast_loss = 0.08443, val_recon_loss = 0.03907, val_total_loss = 0.12350 [4.6s]
# [Epoch 241] forecast_loss = 0.02823, recon_loss = 0.03649, total_loss = 0.06472 ---- val_forecast_loss = 0.08398, val_recon_loss = 0.03898, val_total_loss = 0.12295 [4.6s]
# [Epoch 242] forecast_loss = 0.02828, recon_loss = 0.03633, total_loss = 0.06461 ---- val_forecast_loss = 0.08318, val_recon_loss = 0.03852, val_total_loss = 0.12171 [4.6s]
# [Epoch 243] forecast_loss = 0.02889, recon_loss = 0.03621, total_loss = 0.06509 ---- val_forecast_loss = 0.08379, val_recon_loss = 0.03907, val_total_loss = 0.12286 [4.6s]
# [Epoch 244] forecast_loss = 0.02916, recon_loss = 0.03659, total_loss = 0.06575 ---- val_forecast_loss = 0.08427, val_recon_loss = 0.03845, val_total_loss = 0.12273 [4.5s]
# [Epoch 245] forecast_loss = 0.02791, recon_loss = 0.03623, total_loss = 0.06414 ---- val_forecast_loss = 0.08413, val_recon_loss = 0.03778, val_total_loss = 0.12192 [4.6s]
# [Epoch 246] forecast_loss = 0.02834, recon_loss = 0.03633, total_loss = 0.06467 ---- val_forecast_loss = 0.08445, val_recon_loss = 0.03837, val_total_loss = 0.12281 [4.6s]
# [Epoch 247] forecast_loss = 0.02816, recon_loss = 0.03597, total_loss = 0.06413 ---- val_forecast_loss = 0.08438, val_recon_loss = 0.03827, val_total_loss = 0.12264 [4.6s]
# [Epoch 248] forecast_loss = 0.02826, recon_loss = 0.03632, total_loss = 0.06458 ---- val_forecast_loss = 0.08367, val_recon_loss = 0.03869, val_total_loss = 0.12236 [4.6s]
# [Epoch 249] forecast_loss = 0.02871, recon_loss = 0.03622, total_loss = 0.06493 ---- val_forecast_loss = 0.08268, val_recon_loss = 0.03868, val_total_loss = 0.12136 [4.6s]
# [Epoch 250] forecast_loss = 0.02864, recon_loss = 0.03604, total_loss = 0.06469 ---- val_forecast_loss = 0.08404, val_recon_loss = 0.03778, val_total_loss = 0.12182 [4.6s]
# [Epoch 251] forecast_loss = 0.02816, recon_loss = 0.03584, total_loss = 0.06400 ---- val_forecast_loss = 0.08420, val_recon_loss = 0.03824, val_total_loss = 0.12245 [4.6s]
# [Epoch 252] forecast_loss = 0.02867, recon_loss = 0.03590, total_loss = 0.06457 ---- val_forecast_loss = 0.08409, val_recon_loss = 0.03756, val_total_loss = 0.12165 [4.6s]
# [Epoch 253] forecast_loss = 0.02729, recon_loss = 0.03577, total_loss = 0.06306 ---- val_forecast_loss = 0.08390, val_recon_loss = 0.03826, val_total_loss = 0.12217 [4.6s]
# [Epoch 254] forecast_loss = 0.02803, recon_loss = 0.03556, total_loss = 0.06359 ---- val_forecast_loss = 0.08500, val_recon_loss = 0.03792, val_total_loss = 0.12292 [4.5s]
# [Epoch 255] forecast_loss = 0.02798, recon_loss = 0.03550, total_loss = 0.06348 ---- val_forecast_loss = 0.08434, val_recon_loss = 0.03815, val_total_loss = 0.12249 [4.6s]
# [Epoch 256] forecast_loss = 0.02809, recon_loss = 0.03564, total_loss = 0.06373 ---- val_forecast_loss = 0.08401, val_recon_loss = 0.03790, val_total_loss = 0.12191 [4.6s]
# [Epoch 257] forecast_loss = 0.02745, recon_loss = 0.03555, total_loss = 0.06299 ---- val_forecast_loss = 0.08475, val_recon_loss = 0.03719, val_total_loss = 0.12194 [4.6s]
# [Epoch 258] forecast_loss = 0.02764, recon_loss = 0.03533, total_loss = 0.06296 ---- val_forecast_loss = 0.08425, val_recon_loss = 0.03706, val_total_loss = 0.12131 [4.6s]
# [Epoch 259] forecast_loss = 0.02859, recon_loss = 0.03526, total_loss = 0.06385 ---- val_forecast_loss = 0.08400, val_recon_loss = 0.03722, val_total_loss = 0.12122 [4.5s]
# [Epoch 260] forecast_loss = 0.02801, recon_loss = 0.03543, total_loss = 0.06344 ---- val_forecast_loss = 0.08359, val_recon_loss = 0.03697, val_total_loss = 0.12055 [4.6s]
# [Epoch 261] forecast_loss = 0.02726, recon_loss = 0.03519, total_loss = 0.06245 ---- val_forecast_loss = 0.08499, val_recon_loss = 0.03724, val_total_loss = 0.12223 [4.6s]
# [Epoch 262] forecast_loss = 0.02831, recon_loss = 0.03536, total_loss = 0.06367 ---- val_forecast_loss = 0.08353, val_recon_loss = 0.03809, val_total_loss = 0.12163 [4.6s]
# [Epoch 263] forecast_loss = 0.02794, recon_loss = 0.03521, total_loss = 0.06315 ---- val_forecast_loss = 0.08409, val_recon_loss = 0.03793, val_total_loss = 0.12202 [4.6s]
# [Epoch 264] forecast_loss = 0.02899, recon_loss = 0.03529, total_loss = 0.06428 ---- val_forecast_loss = 0.08336, val_recon_loss = 0.03763, val_total_loss = 0.12099 [4.6s]
# [Epoch 265] forecast_loss = 0.02805, recon_loss = 0.03496, total_loss = 0.06300 ---- val_forecast_loss = 0.08337, val_recon_loss = 0.03703, val_total_loss = 0.12041 [4.6s]
# [Epoch 266] forecast_loss = 0.02750, recon_loss = 0.03495, total_loss = 0.06245 ---- val_forecast_loss = 0.08417, val_recon_loss = 0.03689, val_total_loss = 0.12106 [4.6s]
# [Epoch 267] forecast_loss = 0.02781, recon_loss = 0.03508, total_loss = 0.06289 ---- val_forecast_loss = 0.08445, val_recon_loss = 0.03704, val_total_loss = 0.12149 [4.6s]
# [Epoch 268] forecast_loss = 0.02752, recon_loss = 0.03495, total_loss = 0.06247 ---- val_forecast_loss = 0.08412, val_recon_loss = 0.03697, val_total_loss = 0.12109 [4.6s]
# [Epoch 269] forecast_loss = 0.02747, recon_loss = 0.03529, total_loss = 0.06276 ---- val_forecast_loss = 0.08421, val_recon_loss = 0.03655, val_total_loss = 0.12076 [4.6s]
# [Epoch 270] forecast_loss = 0.02812, recon_loss = 0.03505, total_loss = 0.06318 ---- val_forecast_loss = 0.08288, val_recon_loss = 0.03742, val_total_loss = 0.12030 [4.5s]
# [Epoch 271] forecast_loss = 0.02708, recon_loss = 0.03460, total_loss = 0.06168 ---- val_forecast_loss = 0.08344, val_recon_loss = 0.03674, val_total_loss = 0.12018 [4.6s]
# [Epoch 272] forecast_loss = 0.02773, recon_loss = 0.03493, total_loss = 0.06266 ---- val_forecast_loss = 0.08333, val_recon_loss = 0.03674, val_total_loss = 0.12007 [4.6s]
# [Epoch 273] forecast_loss = 0.02786, recon_loss = 0.03494, total_loss = 0.06281 ---- val_forecast_loss = 0.08494, val_recon_loss = 0.03733, val_total_loss = 0.12228 [4.6s]
# [Epoch 274] forecast_loss = 0.02785, recon_loss = 0.03483, total_loss = 0.06267 ---- val_forecast_loss = 0.08404, val_recon_loss = 0.03694, val_total_loss = 0.12098 [4.6s]
# [Epoch 275] forecast_loss = 0.02776, recon_loss = 0.03486, total_loss = 0.06262 ---- val_forecast_loss = 0.08467, val_recon_loss = 0.03806, val_total_loss = 0.12274 [4.6s]
# [Epoch 276] forecast_loss = 0.02782, recon_loss = 0.03466, total_loss = 0.06248 ---- val_forecast_loss = 0.08461, val_recon_loss = 0.03623, val_total_loss = 0.12083 [4.6s]
# [Epoch 277] forecast_loss = 0.02704, recon_loss = 0.03447, total_loss = 0.06151 ---- val_forecast_loss = 0.08374, val_recon_loss = 0.03651, val_total_loss = 0.12025 [4.6s]
# [Epoch 278] forecast_loss = 0.02726, recon_loss = 0.03439, total_loss = 0.06165 ---- val_forecast_loss = 0.08488, val_recon_loss = 0.03724, val_total_loss = 0.12212 [4.6s]
# [Epoch 279] forecast_loss = 0.02755, recon_loss = 0.03450, total_loss = 0.06206 ---- val_forecast_loss = 0.08376, val_recon_loss = 0.03608, val_total_loss = 0.11985 [4.6s]
# ...
# [Epoch 409] forecast_loss = 0.02461, recon_loss = 0.02983, total_loss = 0.05444 ---- val_forecast_loss = 0.08484, val_recon_loss = 0.03208, val_total_loss = 0.11692 [4.6s]
# [Epoch 410] forecast_loss = 0.02427, recon_loss = 0.03018, total_loss = 0.05445 ---- val_forecast_loss = 0.08411, val_recon_loss = 0.03249, val_total_loss = 0.11661 [4.6s]
# [Epoch 411] forecast_loss = 0.02438, recon_loss = 0.02996, total_loss = 0.05434 ---- val_forecast_loss = 0.08415, val_recon_loss = 0.03178, val_total_loss = 0.11593 [4.6s]
# [Epoch 412] forecast_loss = 0.02532, recon_loss = 0.02975, total_loss = 0.05507 ---- val_forecast_loss = 0.08435, val_recon_loss = 0.03153, val_total_loss = 0.11589 [4.6s]
# [Epoch 413] forecast_loss = 0.02529, recon_loss = 0.02984, total_loss = 0.05513 ---- val_forecast_loss = 0.08419, val_recon_loss = 0.03171, val_total_loss = 0.11589 [4.6s]
# [Epoch 414] forecast_loss = 0.02401, recon_loss = 0.02958, total_loss = 0.05360 ---- val_forecast_loss = 0.08463, val_recon_loss = 0.03121, val_total_loss = 0.11584 [4.6s]
# [Epoch 415] forecast_loss = 0.02498, recon_loss = 0.02986, total_loss = 0.05484 ---- val_forecast_loss = 0.08449, val_recon_loss = 0.03178, val_total_loss = 0.11627 [4.6s]
# [Epoch 416] forecast_loss = 0.02426, recon_loss = 0.02976, total_loss = 0.05401 ---- val_forecast_loss = 0.08497, val_recon_loss = 0.03155, val_total_loss = 0.11652 [4.6s]
# [Epoch 417] forecast_loss = 0.02420, recon_loss = 0.02987, total_loss = 0.05407 ---- val_forecast_loss = 0.08513, val_recon_loss = 0.03150, val_total_loss = 0.11663 [4.6s]
# [Epoch 418] forecast_loss = 0.02538, recon_loss = 0.02983, total_loss = 0.05522 ---- val_forecast_loss = 0.08340, val_recon_loss = 0.03165, val_total_loss = 0.11506 [4.6s]
# [Epoch 419] forecast_loss = 0.02396, recon_loss = 0.02960, total_loss = 0.05356 ---- val_forecast_loss = 0.08483, val_recon_loss = 0.03164, val_total_loss = 0.11646 [4.6s]
# [Epoch 420] forecast_loss = 0.02423, recon_loss = 0.02984, total_loss = 0.05407 ---- val_forecast_loss = 0.08310, val_recon_loss = 0.03086, val_total_loss = 0.11397 [4.6s]
# [Epoch 421] forecast_loss = 0.02482, recon_loss = 0.02958, total_loss = 0.05439 ---- val_forecast_loss = 0.08365, val_recon_loss = 0.03072, val_total_loss = 0.11437 [4.6s]
# [Epoch 422] forecast_loss = 0.02435, recon_loss = 0.02946, total_loss = 0.05381 ---- val_forecast_loss = 0.08376, val_recon_loss = 0.03189, val_total_loss = 0.11564 [4.6s]
# [Epoch 423] forecast_loss = 0.02443, recon_loss = 0.02997, total_loss = 0.05440 ---- val_forecast_loss = 0.08409, val_recon_loss = 0.03082, val_total_loss = 0.11491 [4.6s]
# [Epoch 424] forecast_loss = 0.02443, recon_loss = 0.02961, total_loss = 0.05404 ---- val_forecast_loss = 0.08354, val_recon_loss = 0.03206, val_total_loss = 0.11559 [4.5s]
# [Epoch 425] forecast_loss = 0.02479, recon_loss = 0.02950, total_loss = 0.05429 ---- val_forecast_loss = 0.08601, val_recon_loss = 0.03095, val_total_loss = 0.11696 [4.6s]
# [Epoch 426] forecast_loss = 0.02450, recon_loss = 0.02958, total_loss = 0.05408 ---- val_forecast_loss = 0.08435, val_recon_loss = 0.03314, val_total_loss = 0.11749 [4.6s]
# [Epoch 427] forecast_loss = 0.02450, recon_loss = 0.02989, total_loss = 0.05439 ---- val_forecast_loss = 0.08417, val_recon_loss = 0.03086, val_total_loss = 0.11503 [4.6s]
# [Epoch 428] forecast_loss = 0.02430, recon_loss = 0.02943, total_loss = 0.05373 ---- val_forecast_loss = 0.08374, val_recon_loss = 0.03173, val_total_loss = 0.11547 [4.6s]
# [Epoch 429] forecast_loss = 0.02431, recon_loss = 0.02940, total_loss = 0.05372 ---- val_forecast_loss = 0.08529, val_recon_loss = 0.03143, val_total_loss = 0.11672 [4.6s]
# [Epoch 430] forecast_loss = 0.02439, recon_loss = 0.02961, total_loss = 0.05400 ---- val_forecast_loss = 0.08489, val_recon_loss = 0.03117, val_total_loss = 0.11607 [4.7s]
# [Epoch 431] forecast_loss = 0.02387, recon_loss = 0.03031, total_loss = 0.05417 ---- val_forecast_loss = 0.08397, val_recon_loss = 0.03106, val_total_loss = 0.11504 [4.5s]
# [Epoch 432] forecast_loss = 0.02360, recon_loss = 0.02889, total_loss = 0.05250 ---- val_forecast_loss = 0.08481, val_recon_loss = 0.03070, val_total_loss = 0.11551 [4.5s]
# [Epoch 433] forecast_loss = 0.02501, recon_loss = 0.02920, total_loss = 0.05421 ---- val_forecast_loss = 0.08556, val_recon_loss = 0.03138, val_total_loss = 0.11694 [4.6s]
# [Epoch 434] forecast_loss = 0.02421, recon_loss = 0.02910, total_loss = 0.05331 ---- val_forecast_loss = 0.08520, val_recon_loss = 0.03063, val_total_loss = 0.11583 [4.5s]
# [Epoch 435] forecast_loss = 0.02409, recon_loss = 0.02922, total_loss = 0.05331 ---- val_forecast_loss = 0.08486, val_recon_loss = 0.03107, val_total_loss = 0.11593 [4.6s]
# [Epoch 436] forecast_loss = 0.02478, recon_loss = 0.02929, total_loss = 0.05407 ---- val_forecast_loss = 0.08501, val_recon_loss = 0.03071, val_total_loss = 0.11572 [4.6s]
# [Epoch 437] forecast_loss = 0.02464, recon_loss = 0.02956, total_loss = 0.05421 ---- val_forecast_loss = 0.08399, val_recon_loss = 0.03217, val_total_loss = 0.11616 [4.6s]
# [Epoch 438] forecast_loss = 0.02384, recon_loss = 0.02997, total_loss = 0.05381 ---- val_forecast_loss = 0.08389, val_recon_loss = 0.03017, val_total_loss = 0.11407 [4.6s]
# [Epoch 439] forecast_loss = 0.02397, recon_loss = 0.02925, total_loss = 0.05322 ---- val_forecast_loss = 0.08416, val_recon_loss = 0.03063, val_total_loss = 0.11480 [4.6s]
# [Epoch 440] forecast_loss = 0.02447, recon_loss = 0.02925, total_loss = 0.05372 ---- val_forecast_loss = 0.08450, val_recon_loss = 0.03098, val_total_loss = 0.11549 [4.6s]
# [Epoch 441] forecast_loss = 0.02453, recon_loss = 0.02927, total_loss = 0.05381 ---- val_forecast_loss = 0.08425, val_recon_loss = 0.03095, val_total_loss = 0.11520 [4.6s]
# [Epoch 442] forecast_loss = 0.02373, recon_loss = 0.02894, total_loss = 0.05267 ---- val_forecast_loss = 0.08486, val_recon_loss = 0.03173, val_total_loss = 0.11659 [4.6s]
# [Epoch 443] forecast_loss = 0.02467, recon_loss = 0.02909, total_loss = 0.05376 ---- val_forecast_loss = 0.08456, val_recon_loss = 0.03128, val_total_loss = 0.11585 [4.7s]
# [Epoch 444] forecast_loss = 0.02437, recon_loss = 0.02887, total_loss = 0.05324 ---- val_forecast_loss = 0.08404, val_recon_loss = 0.03024, val_total_loss = 0.11428 [4.5s]
# [Epoch 445] forecast_loss = 0.02415, recon_loss = 0.02898, total_loss = 0.05313 ---- val_forecast_loss = 0.08379, val_recon_loss = 0.03046, val_total_loss = 0.11425 [4.5s]
# [Epoch 446] forecast_loss = 0.02385, recon_loss = 0.02879, total_loss = 0.05264 ---- val_forecast_loss = 0.08539, val_recon_loss = 0.02996, val_total_loss = 0.11536 [4.6s]
# [Epoch 447] forecast_loss = 0.02380, recon_loss = 0.02910, total_loss = 0.05290 ---- val_forecast_loss = 0.08325, val_recon_loss = 0.03067, val_total_loss = 0.11391 [4.6s]
# [Epoch 448] forecast_loss = 0.02419, recon_loss = 0.02899, total_loss = 0.05319 ---- val_forecast_loss = 0.08441, val_recon_loss = 0.03050, val_total_loss = 0.11491 [4.6s]
# [Epoch 449] forecast_loss = 0.02477, recon_loss = 0.02929, total_loss = 0.05406 ---- val_forecast_loss = 0.08438, val_recon_loss = 0.03006, val_total_loss = 0.11445 [4.6s]
# [Epoch 450] forecast_loss = 0.02433, recon_loss = 0.02881, total_loss = 0.05314 ---- val_forecast_loss = 0.08485, val_recon_loss = 0.03055, val_total_loss = 0.11540 [4.6s]
# [Epoch 451] forecast_loss = 0.02374, recon_loss = 0.02887, total_loss = 0.05261 ---- val_forecast_loss = 0.08497, val_recon_loss = 0.03075, val_total_loss = 0.11571 [4.7s]
# [Epoch 452] forecast_loss = 0.02415, recon_loss = 0.02873, total_loss = 0.05288 ---- val_forecast_loss = 0.08469, val_recon_loss = 0.03038, val_total_loss = 0.11507 [4.6s]
# [Epoch 453] forecast_loss = 0.02362, recon_loss = 0.02872, total_loss = 0.05234 ---- val_forecast_loss = 0.08447, val_recon_loss = 0.02968, val_total_loss = 0.11415 [4.6s]
# [Epoch 454] forecast_loss = 0.02429, recon_loss = 0.02878, total_loss = 0.05308 ---- val_forecast_loss = 0.08540, val_recon_loss = 0.03100, val_total_loss = 0.11641 [4.6s]
# [Epoch 455] forecast_loss = 0.02385, recon_loss = 0.02891, total_loss = 0.05276 ---- val_forecast_loss = 0.08395, val_recon_loss = 0.03012, val_total_loss = 0.11407 [4.6s]
# [Epoch 456] forecast_loss = 0.02387, recon_loss = 0.02920, total_loss = 0.05307 ---- val_forecast_loss = 0.08502, val_recon_loss = 0.03088, val_total_loss = 0.11591 [4.6s]
# [Epoch 457] forecast_loss = 0.02402, recon_loss = 0.02870, total_loss = 0.05272 ---- val_forecast_loss = 0.08549, val_recon_loss = 0.03086, val_total_loss = 0.11635 [4.6s]
# [Epoch 458] forecast_loss = 0.02390, recon_loss = 0.02843, total_loss = 0.05232 ---- val_forecast_loss = 0.08476, val_recon_loss = 0.02981, val_total_loss = 0.11457 [4.5s]
# [Epoch 459] forecast_loss = 0.02407, recon_loss = 0.02855, total_loss = 0.05263 ---- val_forecast_loss = 0.08460, val_recon_loss = 0.03002, val_total_loss = 0.11463 [4.6s]
# [Epoch 460] forecast_loss = 0.02393, recon_loss = 0.02855, total_loss = 0.05248 ---- val_forecast_loss = 0.08484, val_recon_loss = 0.03011, val_total_loss = 0.11494 [4.6s]
# [Epoch 461] forecast_loss = 0.02426, recon_loss = 0.02848, total_loss = 0.05274 ---- val_forecast_loss = 0.08448, val_recon_loss = 0.02949, val_total_loss = 0.11396 [4.6s]
# [Epoch 462] forecast_loss = 0.02400, recon_loss = 0.02851, total_loss = 0.05252 ---- val_forecast_loss = 0.08522, val_recon_loss = 0.03064, val_total_loss = 0.11586 [4.6s]
# [Epoch 463] forecast_loss = 0.02465, recon_loss = 0.02851, total_loss = 0.05316 ---- val_forecast_loss = 0.08519, val_recon_loss = 0.03026, val_total_loss = 0.11545 [4.6s]
# [Epoch 464] forecast_loss = 0.02549, recon_loss = 0.02892, total_loss = 0.05441 ---- val_forecast_loss = 0.08431, val_recon_loss = 0.03023, val_total_loss = 0.11454 [4.6s]
# [Epoch 465] forecast_loss = 0.02413, recon_loss = 0.02844, total_loss = 0.05257 ---- val_forecast_loss = 0.08466, val_recon_loss = 0.02977, val_total_loss = 0.11443 [4.6s]
# [Epoch 466] forecast_loss = 0.02341, recon_loss = 0.02824, total_loss = 0.05165 ---- val_forecast_loss = 0.08520, val_recon_loss = 0.03037, val_total_loss = 0.11557 [4.6s]
# [Epoch 467] forecast_loss = 0.02351, recon_loss = 0.02832, total_loss = 0.05183 ---- val_forecast_loss = 0.08470, val_recon_loss = 0.02945, val_total_loss = 0.11415 [4.6s]
# [Epoch 468] forecast_loss = 0.02413, recon_loss = 0.02922, total_loss = 0.05335 ---- val_forecast_loss = 0.08517, val_recon_loss = 0.03086, val_total_loss = 0.11603 [4.6s]
# [Epoch 469] forecast_loss = 0.02369, recon_loss = 0.02834, total_loss = 0.05203 ---- val_forecast_loss = 0.08507, val_recon_loss = 0.03028, val_total_loss = 0.11535 [4.6s]
# [Epoch 470] forecast_loss = 0.02331, recon_loss = 0.02829, total_loss = 0.05160 ---- val_forecast_loss = 0.08461, val_recon_loss = 0.03050, val_total_loss = 0.11511 [4.7s]
# [Epoch 471] forecast_loss = 0.02368, recon_loss = 0.02832, total_loss = 0.05199 ---- val_forecast_loss = 0.08470, val_recon_loss = 0.03004, val_total_loss = 0.11473 [4.6s]
# [Epoch 472] forecast_loss = 0.02430, recon_loss = 0.02881, total_loss = 0.05312 ---- val_forecast_loss = 0.08411, val_recon_loss = 0.02990, val_total_loss = 0.11401 [4.6s]
# [Epoch 473] forecast_loss = 0.02428, recon_loss = 0.02845, total_loss = 0.05273 ---- val_forecast_loss = 0.08491, val_recon_loss = 0.02932, val_total_loss = 0.11423 [4.6s]
# [Epoch 474] forecast_loss = 0.02383, recon_loss = 0.02796, total_loss = 0.05179 ---- val_forecast_loss = 0.08523, val_recon_loss = 0.02985, val_total_loss = 0.11509 [4.6s]
# [Epoch 475] forecast_loss = 0.02424, recon_loss = 0.02870, total_loss = 0.05294 ---- val_forecast_loss = 0.08306, val_recon_loss = 0.02956, val_total_loss = 0.11263 [4.6s]
# [Epoch 476] forecast_loss = 0.02384, recon_loss = 0.02800, total_loss = 0.05184 ---- val_forecast_loss = 0.08403, val_recon_loss = 0.02930, val_total_loss = 0.11332 [4.5s]
# [Epoch 477] forecast_loss = 0.02388, recon_loss = 0.02807, total_loss = 0.05195 ---- val_forecast_loss = 0.08427, val_recon_loss = 0.02994, val_total_loss = 0.11421 [4.5s]
# [Epoch 478] forecast_loss = 0.02318, recon_loss = 0.02793, total_loss = 0.05111 ---- val_forecast_loss = 0.08503, val_recon_loss = 0.02986, val_total_loss = 0.11489 [4.6s]
# [Epoch 479] forecast_loss = 0.02431, recon_loss = 0.02815, total_loss = 0.05246 ---- val_forecast_loss = 0.08523, val_recon_loss = 0.03011, val_total_loss = 0.11533 [4.6s]
# [Epoch 480] forecast_loss = 0.02386, recon_loss = 0.02820, total_loss = 0.05207 ---- val_forecast_loss = 0.08570, val_recon_loss = 0.03305, val_total_loss = 0.11875 [4.5s]
# [Epoch 481] forecast_loss = 0.02461, recon_loss = 0.02821, total_loss = 0.05282 ---- val_forecast_loss = 0.08476, val_recon_loss = 0.02966, val_total_loss = 0.11441 [4.6s]
# [Epoch 482] forecast_loss = 0.02351, recon_loss = 0.02828, total_loss = 0.05180 ---- val_forecast_loss = 0.08547, val_recon_loss = 0.02941, val_total_loss = 0.11487 [4.6s]
# [Epoch 483] forecast_loss = 0.02343, recon_loss = 0.02786, total_loss = 0.05130 ---- val_forecast_loss = 0.08476, val_recon_loss = 0.02953, val_total_loss = 0.11428 [4.6s]
# [Epoch 484] forecast_loss = 0.02373, recon_loss = 0.02797, total_loss = 0.05170 ---- val_forecast_loss = 0.08470, val_recon_loss = 0.02878, val_total_loss = 0.11348 [4.6s]
# [Epoch 485] forecast_loss = 0.02306, recon_loss = 0.02790, total_loss = 0.05096 ---- val_forecast_loss = 0.08578, val_recon_loss = 0.03108, val_total_loss = 0.11686 [4.5s]
# [Epoch 486] forecast_loss = 0.02320, recon_loss = 0.02805, total_loss = 0.05126 ---- val_forecast_loss = 0.08555, val_recon_loss = 0.02888, val_total_loss = 0.11443 [4.6s]
# [Epoch 487] forecast_loss = 0.02373, recon_loss = 0.02784, total_loss = 0.05158 ---- val_forecast_loss = 0.08512, val_recon_loss = 0.02964, val_total_loss = 0.11476 [4.5s]
# [Epoch 488] forecast_loss = 0.02320, recon_loss = 0.02786, total_loss = 0.05106 ---- val_forecast_loss = 0.08656, val_recon_loss = 0.02936, val_total_loss = 0.11592 [4.5s]
# [Epoch 489] forecast_loss = 0.02381, recon_loss = 0.02772, total_loss = 0.05153 ---- val_forecast_loss = 0.08577, val_recon_loss = 0.02989, val_total_loss = 0.11566 [4.6s]
# [Epoch 490] forecast_loss = 0.02440, recon_loss = 0.02803, total_loss = 0.05243 ---- val_forecast_loss = 0.08428, val_recon_loss = 0.02905, val_total_loss = 0.11332 [4.6s]
# [Epoch 491] forecast_loss = 0.02356, recon_loss = 0.02815, total_loss = 0.05171 ---- val_forecast_loss = 0.08516, val_recon_loss = 0.03076, val_total_loss = 0.11592 [4.6s]
# [Epoch 492] forecast_loss = 0.02364, recon_loss = 0.02808, total_loss = 0.05173 ---- val_forecast_loss = 0.08486, val_recon_loss = 0.02871, val_total_loss = 0.11357 [4.6s]
# [Epoch 493] forecast_loss = 0.02333, recon_loss = 0.02759, total_loss = 0.05092 ---- val_forecast_loss = 0.08500, val_recon_loss = 0.02889, val_total_loss = 0.11389 [4.6s]
# [Epoch 494] forecast_loss = 0.02281, recon_loss = 0.02756, total_loss = 0.05036 ---- val_forecast_loss = 0.08419, val_recon_loss = 0.02872, val_total_loss = 0.11291 [4.6s]
# [Epoch 495] forecast_loss = 0.02362, recon_loss = 0.02785, total_loss = 0.05147 ---- val_forecast_loss = 0.08482, val_recon_loss = 0.02904, val_total_loss = 0.11386 [4.6s]
# [Epoch 496] forecast_loss = 0.02335, recon_loss = 0.02775, total_loss = 0.05111 ---- val_forecast_loss = 0.08445, val_recon_loss = 0.02928, val_total_loss = 0.11373 [4.7s]
# [Epoch 497] forecast_loss = 0.02364, recon_loss = 0.02768, total_loss = 0.05132 ---- val_forecast_loss = 0.08531, val_recon_loss = 0.02959, val_total_loss = 0.11490 [5.2s]
# [Epoch 498] forecast_loss = 0.02432, recon_loss = 0.02777, total_loss = 0.05208 ---- val_forecast_loss = 0.08503, val_recon_loss = 0.02868, val_total_loss = 0.11371 [4.6s]
# [Epoch 499] forecast_loss = 0.02327, recon_loss = 0.02761, total_loss = 0.05088 ---- val_forecast_loss = 0.08584, val_recon_loss = 0.03096, val_total_loss = 0.11680 [4.6s]
# [Epoch 500] forecast_loss = 0.02373, recon_loss = 0.02786, total_loss = 0.05159 ---- val_forecast_loss = 0.08506, val_recon_loss = 0.02894, val_total_loss = 0.11400 [4.6s]
# -- Training done in 2299s.
